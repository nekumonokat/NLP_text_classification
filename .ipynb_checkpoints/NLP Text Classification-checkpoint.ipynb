# %% [markdown]
# <h2><center>NLP Text Classification</h2>

# %% [markdown]
# ## I. Introduction

# %% [markdown]
# ### 1.1 Domain-specific area
# This project provides an analysis of textual data on Twitter to accurately detect and classify threatening or harmful content using sentiment analysis techniques. This would provide the cybersecurity industry a tool that takes in a corpus of text for training to develop a strong detection system.

# %% [markdown]
# ### 1.2 Objectives
# Due to popular algorithms being centered around the detection of cyberbullying on social media (Cynthia Van Hee et al., 2018), it is important for this project to widen the scope of detection. While the general detection algorithms focus mainly on terrorism and cyberbullying, it is a known fact that cybersecurity encompasses more than those 2 focuses. (Khairy, Mahmoud and Abd-El-Hafeez, 2021) While full security and safety of users cannot be ensured, making these adjustments would contribute valuable insights for future development.

# %% [markdown]
# ### 1.3 Dataset
# To begin this project, an extensive amount of textual data corpora is required. After researching large datasets of Tweets, Sentiment140 Kaggle was proven to be the best for this project. With 1.6 million tweets extracted using the Twitter API, the authors have categorised each tweet to have either a positive, neutral or negative sentiment, which is beneficial for the algorithm in categorising harmful texts.
#
# The dataset consists of the target (defined as the sentiment of the text), the tweet IDs, date, flags (possible queries, which would be removed in the initialisation phase of extracting the data), the username, and the text of the tweet.

# %% [markdown]
# ### 1.4 Evaluation methodology

# %% [markdown]
# ## II. Implementation

# %% [markdown]
# ### 2.1 Pre-processing
# (writeup not needed)
# <br>Convert/store the dataset locally and preprocess the data. Describe the text representation
# (e.g., bag of words, word embedding, etc.) and any pre-processing steps you have applied
# and why they were needed (e.g. tokenization, lemmatization). Describe the vocabulary and
# file type/format, e.g. CSV file.

# %% [markdown]
# #### Acquiring dataset
# The dataset on the collection of Tweets were acquired from Kaggle by downloading the CSV file. The author of this dataset is Μαριος Μιχαηλιδης KazAnova. The code for importing the dataset is shown below:

# %% [markdown]
# #### 2.1.1 Importing libraries
# - <b>pandas library</b> was imported to process and handle datasets in Python. It is used to help write and read from CSV files while handling real-world messy data and processing them into a proper format
#
# - <b>numpy library</b> was imported to handle calculations and use numpy arrays for statistical calculations
#
# - <b>matplotlib library</b> was imported to plot the data and represent it graphically
#
# - <b>os library</b> was imported to have a way of using the operating system dependent functionalities, more specifically to save the dataset as a CSV
#
# - <b>word_tokenize library</b> divides strings into lists of substrings, this aids in regular expression
#
# - <b>stopwords library</b> was imported to have a library of the most common words in data to aid in stopwords removal
#
# - <b>string library</b> contains all ASCII characters considered as whitespace to aid in stopwords removal
#
# - <b>re library</b> specifies a set of strings that matches it and checks if a string matches a given regular expression

# %%
# dataframes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# text processing and analysis
import nltk
nltk.download("punkt")
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sbgka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### 2.1.2 Creating helper functions
# - <b>displaysetsH</b> takes in a list of datasets and an optional number of rows to display the head of each dataset
#
# - <b>displaysetsT</b> takes in a list of datasets and an optional number of rows to display the tail of each dataset
#
# - <b>resetidx</b> takes in a list of datasets to reset the indexes of each dataset

# %%
def displaysetsH(datasets, amt = 5):
    for dataset in datasets:
        display(dataset.head(amt))
        
def displaysetsT(datasets, amt = 5):
    for dataset in datasets:
        display(dataset.head(amt))
        
def resetidx(datasets):
    for dataset in datasets:
        dataset.reset_index(drop = True, inplace = True)

# %% [markdown]
# #### 2.1.3 Importing dataset
# Due to the dataset being too large for analysis, we will analyse the first 1000 textual data corpora.

# %%
df = pd.read_csv("datasets/sentiment140_dataset.csv", nrows = 1000)
df
# Out:
#      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY _TheSpecialOne_  \
# 0    0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY   scotthamilton
# 1    0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY        mattycus
# 2    0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         ElleCTF
# 3    0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          Karoli
# 4    0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY        joy_wolf
# ..  ..         ...                           ...       ...             ...
# 995  0  1468055266  Mon Apr 06 23:28:41 PDT 2009  NO_QUERY  ohmigosh_dusti
# 996  0  1468055472  Mon Apr 06 23:28:43 PDT 2009  NO_QUERY  tiphaniebrooke
# 997  0  1468055604  Mon Apr 06 23:28:45 PDT 2009  NO_QUERY      rinahannah
# 998  0  1468055791  Mon Apr 06 23:28:49 PDT 2009  NO_QUERY            ecjc
# 999  0  1468055852  Mon Apr 06 23:28:50 PDT 2009  NO_QUERY     Saphyre1969
#
#     @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0    is upset that he can't update his Facebook by ...
# 1    @Kenichan I dived many times for the ball. Man...
# 2      my whole body feels itchy and like its on fire
# 3    @nationwideclass no, it's not behaving at all....
# 4                        @Kwesidei not the whole crew
# ..                                                 ...
# 995  @t_wolfe  i miss u too. i'm totally comin back...
# 996  @sniffinglue ohhh. I love it. ps I'm sad we di...
# 997          And somehow I still end up in this place
# 998         @kisluvkis oh that is very sad, poor boy.
# 999  @JonathanRKnight @silver_tulip27 Um, that woul...
#
# [1000 rows x 6 columns]

# %% [markdown]
# #### 2.1.4 Adding headers
# Based on analysing tweets_df.head(), it is seen that the dataset does not have any headers. As such, the first process would be to add the headers to aid in future analysis. The columns 'tweet_id', 'date', 'flag' and 'user' will then be removed as the project focus is on the sentiment analysis. This modified dataset will then be stored as a new CSV file.
#
# (<i>the headers are modified based on looking at the contents from Kaggle</i>)

# %%
headers = ['sentiment', 'tweet_id', 'date', 'flag', 'user', 'tweet']
tweets_df = pd.read_csv("datasets/sentiment140_dataset.csv", nrows = 1000, names = headers)
columns_to_drop = ['tweet_id', 'date', 'flag', 'user']
tweets_df.drop(columns = columns_to_drop, inplace = True)
tweets_df
# Out:
#      sentiment                                              tweet
# 0            0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1            0  is upset that he can't update his Facebook by ...
# 2            0  @Kenichan I dived many times for the ball. Man...
# 3            0    my whole body feels itchy and like its on fire
# 4            0  @nationwideclass no, it's not behaving at all....
# ..         ...                                                ...
# 995          0  @dkoenigs thanks man.  I'm so very grateful.  ...
# 996          0  @t_wolfe  i miss u too. i'm totally comin back...
# 997          0  @sniffinglue ohhh. I love it. ps I'm sad we di...
# 998          0          And somehow I still end up in this place
# 999          0         @kisluvkis oh that is very sad, poor boy.
#
# [1000 rows x 2 columns]

# %%
file_path = 'datasets/expanded_sentiment140_dataset.csv'

if not os.path.exists(file_path):
    tweets_df.to_csv(file_path, index = False)
    print('File saved successfully.')
else:
    print('File already exists.')
   
tweets_df = pd.read_csv("datasets/expanded_sentiment140_dataset.csv")
# Out:
# File already exists.

# %% [markdown]
# #### 2.1.5 Checking for duplicates and null entries
# To ensure that the analysis is beneficial, all 1000 entries that were chosen should be unique. To do so, a 'duplicated' column will be added to the a temporary copy of the dataset which is the output of df.duplicated() and we will print only columns where the 'duplicated' column is True.
#
# Based on the output, it is seen that there are no duplicated Tweets.
#
# After ensuring that all entries are unique, a check that all entries do not have NULL entries will be done. This is because sentiment analysis cannot be done on empty texts.
#
# Based on the output, it is seen that there are no NULL entries.

# %%
dupe_checker = tweets_df.copy()
duplicates = dupe_checker.duplicated()
dupe_checker['duplicated'] = duplicates
duplicated = dupe_checker[dupe_checker['duplicated'] == True]
duplicated
# Out:
# Empty DataFrame
# Columns: [sentiment, tweet, duplicated]
# Index: []

# %%
null_checker = tweets_df.copy()
null_checker.isnull().sum()
# Out:
# sentiment    0
# tweet        0
# dtype: int64

# %% [markdown]
# #### 2.1.6 Basic statistics
# To ensure that the data is good for analysis, the amount of positive, neutral and negative sentiments should be as balanced as possible (sentiment values: 0 = negative, 2 = neutral, 4 = positive)
#
# Based on the output, it is seen that the dataset has been skewed. However, due to the focus on the project being the detection of threatful comments, the skewed focus on negative sentiments should be sufficient enough for detection.

# %% [markdown]
# ** Second option: Based on the output, it is seen that the dataset has been skewed. Due to this, a new collation of the first and last 1000 entries will be used.

# %%
temp = tweets_df.copy()
print("Number of positive sentiments:", temp[temp['sentiment'] == 4].count())
print("Number of neutral sentiments:", temp[temp['sentiment'] == 2].count())
print("Number of negative sentiments:", temp[temp['sentiment'] == 0].count())
# Out:
# Number of positive sentiments: sentiment    0
# tweet        0
# dtype: int64
# Number of neutral sentiments: sentiment    0
# tweet        0
# dtype: int64
# Number of negative sentiments: sentiment    1000
# tweet        1000
# dtype: int64

# %% [markdown]
# #### 2.1.7 Basic text processing
# To begin the process of analysing the text, we would require conducting basic text processing methods.
#
# TO DO LIST:
# - Describe the text representation (e.g., bag of words, word embedding, etc.) **[not done]**
# - Describe the vocabulary and file type/format, e.g. CSV file. [**not done**]
# - any pre-processing steps you have applied and why they were needed (e.g. tokenization [**done**], lemmatization [**did regex**]).

# %% [markdown]
# - <b>Removing stop words</b>: In human language, it is very common for stop words to be present. These words, including **determiners** (eg: the, a, this, my), **conjunctions** (eg: and, or, nor, but, whereas) and **prepositions** (eg: against, along, at, before), are used to connect thoughts and speech to form grammatically accurate sentences or structural cohesion. While important during communication amongst one another, they do not carry importance or sentiments that would be valuable to this project, thus introducing noise. The removal would help to streamline the process to focus on words that would contribute more meaning to the sentiment of Tweets.
#
# * Tokenisation will be done in lowercase as all stopwords are in lowercase.

# %%
# Downloading stopword corpus
nltk.download("stopwords")
# Get stopword list
stop_words = set(stopwords.words("english"))
print("stop_words", stop_words)
# Out:
# stop_words {"isn't", 'our', 'having', 'shouldn', 'above', 'from', 'he', 'after', 'didn', 'we', 'over', 'aren', 'yourself', 'needn', 'were', "that'll", "couldn't", 'have', 'ma', 'those', 're', 'not', "doesn't", 'just', 'hasn', 'has', 'themselves', 'about', "she's", 'at', 'once', 'such', 'don', 'd', 'while', 'their', 'if', 'than', 'hadn', 'by', 'yourselves', 'of', 't', 'itself', 'until', "won't", 'on', 'she', 'same', 'theirs', 'down', 'is', 'most', 'with', 'mustn', 'whom', 'isn', 'doing', "shouldn't", "aren't", 'any', 'as', 'to', 'a', 'further', 'there', 'did', 'was', 'other', 'your', 'some', 'and', 'do', 'you', 'my', 'so', 'me', 'then', 'why', 'in', 'mightn', 'himself', 'off', "hasn't", 'her', 'all', 'can', 'during', 'yours', 'these', 'below', 'll', "shan't", 'own', 'am', 'against', 'or', 'because', 'how', 'couldn', 'through', 'haven', 'o', 'it', 'him', "you're", 'but', 's', 'what', 'very', 'm', 'won', 'now', 'between', 'hers', 'both', 'into', "don't", 'its', 'herself', 'out', "weren't", 'which', 'doesn', "hadn't", 'wouldn', "wouldn't", "mightn't", "mustn't", 'they', 'myself', 've', 'ourselves', 'too', 'been', 'should', 'nor', 'each', 'ain', "needn't", 'who', "didn't", "should've", 'the', "you'll", 'had', 'again', "it's", "haven't", 'i', 'few', 'before', 'only', 'that', 'ours', 'will', "you've", 'where', 'be', 'weren', 'an', 'no', 'wasn', "wasn't", 'them', 'here', 'more', 'when', 'y', 'are', 'for', 'under', 'up', 'being', 'his', "you'd", 'shan', 'does', 'this'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sbgka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Checking removal works on a test text
test_tweet = ["This is a test that Stopword removal works."]

def filter_text(tweets):
    for tweet in tweets:
        tokens = tweet.lower().split()
        # Removing each token if part of stop_words
        filtered_tokens = [token for token in tokens if token not in stop_words]
        print("filtered_tokens", filtered_tokens)
        
filter_text(test_tweet)
# Out:
# filtered_tokens ['test', 'stopword', 'removal', 'works.']

# %%
# Before improvement of stopwords
tweets = tweets_df["tweet"].tolist()
filter_text(tweets)
# Out:
# filtered_tokens ['@switchfoot', 'http://twitpic.com/2y1zl', '-', 'awww,', "that's", 'bummer.', 'shoulda', 'got', 'david', 'carr', 'third', 'day', 'it.', ';d']
# filtered_tokens ['upset', "can't", 'update', 'facebook', 'texting', 'it...', 'might', 'cry', 'result', 'school', 'today', 'also.', 'blah!']
# filtered_tokens ['@kenichan', 'dived', 'many', 'times', 'ball.', 'managed', 'save', '50%', 'rest', 'go', 'bounds']
# filtered_tokens ['whole', 'body', 'feels', 'itchy', 'like', 'fire']
# filtered_tokens ['@nationwideclass', 'no,', 'behaving', 'all.', "i'm", 'mad.', 'here?', "can't", 'see', 'there.']
# filtered_tokens ['@kwesidei', 'whole', 'crew']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['@loltrish', 'hey', 'long', 'time', 'see!', 'yes..', 'rains', 'bit', ',only', 'bit', 'lol', ',', "i'm", 'fine', 'thanks', ',', "how's", '?']
# filtered_tokens ['@tatiana_k', 'nope']
# filtered_tokens ['@twittera', 'que', 'muera', '?']
# filtered_tokens ['spring', 'break', 'plain', 'city...', 'snowing']
# filtered_tokens ['re-pierced', 'ears']
# filtered_tokens ['@caregiving', 'bear', 'watch', 'it.', 'thought', 'ua', 'loss', 'embarrassing', '.', '.', '.', '.', '.']
# filtered_tokens ['@octolinz16', 'counts,', 'idk', 'either.', 'never', 'talk', 'anymore']
# filtered_tokens ['@smarrison', "would've", 'first,', 'gun.', 'really', 'though,', 'zac', "snyder's", 'doucheclown.']
# filtered_tokens ['@iamjazzyfizzle', 'wish', 'got', 'watch', 'you!!', 'miss', '@iamlilnicki', 'premiere?!']
# filtered_tokens ["hollis'", 'death', 'scene', 'hurt', 'severely', 'watch', 'film', 'wry', 'directors', 'cut', 'now?']
# filtered_tokens ['file', 'taxes']
# filtered_tokens ['@lettya', 'ahh', 'ive', 'always', 'wanted', 'see', 'rent', 'love', 'soundtrack!!']
# filtered_tokens ['@fakerpattypattz', 'oh', 'dear.', 'drinking', 'forgotten', 'table', 'drinks?']
# filtered_tokens ['@alydesigns', 'day', 'get', 'much', 'done']
# filtered_tokens ['one', 'friend', 'called', 'me,', 'asked', 'meet', 'mid', 'valley', 'today...but', "i've", 'time', '*sigh*']
# filtered_tokens ['@angry_barista', 'baked', 'cake', 'ated']
# filtered_tokens ['week', 'going', 'hoped']
# filtered_tokens ['blagh', 'class', '8', 'tomorrow']
# filtered_tokens ['hate', 'call', 'wake', 'people']
# filtered_tokens ['going', 'cry', 'sleep', 'watching', 'marley', 'me.']
# filtered_tokens ['im', 'sad', 'miss.lilly']
# filtered_tokens ['ooooh....', 'lol', 'leslie....', 'ok', 'leslie', 'get', 'mad']
# filtered_tokens ['meh...', 'almost', 'lover', 'exception...', 'track', 'gets', 'depressed', 'every', 'time.']
# filtered_tokens ['some1', 'hacked', 'account', 'aim', 'make', 'new', 'one']
# filtered_tokens ['@alielayus', 'want', 'go', 'promote', 'gear', 'groove', 'unfornately', 'ride', 'may', 'b', 'going', 'one', 'anaheim', 'may', 'though']
# filtered_tokens ['thought', 'sleeping', 'option', 'tomorrow', 'realizing', 'not.', 'evaluations', 'morning', 'work', 'afternoon!']
# filtered_tokens ['@julieebaby', 'awe', 'love', 'too!!!!', '1', 'miss']
# filtered_tokens ['@humpninja', 'cry', 'asian', 'eyes', 'sleep', 'night']
# filtered_tokens ['ok', "i'm", 'sick', 'spent', 'hour', 'sitting', 'shower', 'cause', 'sick', 'stand', 'held', 'back', 'puke', 'like', 'champ.', 'bed']
# filtered_tokens ['@cocomix04', 'ill', 'tell', 'ya', 'story', 'later', 'good', 'day', 'ill', 'workin', 'like', 'three', 'hours...']
# filtered_tokens ['@missxu', 'sorry!', 'bed', 'time', 'came', '(gmt+1)', 'http://is.gd/fnge']
# filtered_tokens ['@fleurylis', 'either.', 'depressing.', 'think', 'even', 'want', 'know', 'kids', 'suitcases.']
# filtered_tokens ['bed.', 'class', '8-12.', 'work', '12-3.', 'gym', '3-5', '6.', 'class', '6-10.', 'another', 'day', "that's", 'gonna', 'fly', 'by.', 'miss', 'girlfriend']
# filtered_tokens ['really', 'feel', 'like', 'getting', 'today...', 'got', 'study', 'tomorrows', 'practical', 'exam...']
# filtered_tokens ["he's", 'reason', 'teardrops', 'guitar', 'one', 'enough', 'break', 'heart']
# filtered_tokens ['sad,', 'sad,', 'sad.', 'know', 'hate', 'feeling', 'wanna', 'sleep', 'still', "can't!"]
# filtered_tokens ['@jonathanrknight', 'awww', 'soo', 'wish', 'see', 'finally', 'comfortable!', 'im', 'sad', 'missed']
# filtered_tokens ['falling', 'asleep.', 'heard', 'tracy', "girl's", 'body', 'found.', 'sad', 'heart', 'breaks', 'family.']
# filtered_tokens ['@viennah', 'yay!', "i'm", 'happy', 'job!', 'also', 'means', 'less', 'time', 'you...']
# filtered_tokens ['checked', 'user', 'timeline', 'blackberry,', 'looks', 'like', 'twanking', 'still', 'happening', 'ppl', 'still', 'probs', 'w/', 'bgs', 'uids?']
# filtered_tokens ['oh', 'man...was', 'ironing', "@jeancjumbe's", 'fave', 'top', 'wear', 'meeting.', 'burnt']
# filtered_tokens ['strangely', 'sad', 'lilo', 'samro', 'breaking', 'up.']
# filtered_tokens ['@tea', 'oh!', "i'm", 'sorry', 'think', 'retweeting.']
# filtered_tokens ['broadband', 'plan', "'a", 'massive', 'broken', "promise'", 'http://tinyurl.com/dcuc33', 'via', 'www.diigo.com/~tautao', 'still', 'waiting', 'broadband']
# filtered_tokens ['@localtweeps', 'wow,', 'tons', 'replies', 'you,', 'may', 'unfollow', 'see', "friends'", 'tweets,', 'scrolling', 'feed', 'lot.']
# filtered_tokens ['duck', 'chicken', 'taking', 'wayyy', 'long', 'hatch']
# filtered_tokens ['put', 'vacation', 'photos', 'online', 'yrs', 'ago.', 'pc', 'crashed,', 'forget', 'name', 'site.']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['@andywana', 'sure', 'are,', 'pos!', 'much', 'want', 'to,', 'dont', 'think', 'trade', 'away', 'company', 'assets', 'sorry', 'andy!']
# filtered_tokens ['@oanhlove', 'hate', 'happens...']
# filtered_tokens ['sad', 'feeling', 'dallas', 'going', 'show', 'gotta', 'say', 'though,', 'think', 'shows', 'would', 'use', 'music', 'game.', 'mmm']
# filtered_tokens ['ugh....92', 'degrees', 'tomorrow']
# filtered_tokens ['u', 'move', 'to?', 'thought', 'u', 'already', 'sd.', '??', 'hmmm.', 'random', 'u', 'found', 'me.', 'glad', 'hear', 'yer', 'well.']
# filtered_tokens ['@batmanyng', 'miss', 'ps3,', 'commission', 'wutcha', 'playing?', 'copped', "'blood", "sand'?"]
# filtered_tokens ['leaving', 'parking', 'lot', 'work!']
# filtered_tokens ['life', 'cool.', 'me.']
# filtered_tokens ['sadly', 'though,', "i've", 'never', 'gotten', 'experience', 'post', 'coitus', 'cigarette', 'before,', 'never', 'will.']
# filtered_tokens ['nice', 'day.', 'bad', 'rain', 'comes', 'tomorrow', '5am']
# filtered_tokens ['@starrbby', 'bad', 'around', 'lost', 'job', "can't", 'even', 'pay', 'phone', 'bill', 'lmao', 'aw', 'shucks']
# filtered_tokens ['damm', 'back', 'school', 'tomorrow']
# filtered_tokens ['mo', 'jobs,', 'money.', 'hell', 'min', 'wage', '4', "f'n", 'clams', 'hour?']
# filtered_tokens ['@katortiz', 'forever...', 'see', 'soon!']
# filtered_tokens ['@lt_algonquin', 'agreed,', 'saw', 'failwhale', 'allllll', 'day', 'today.']
# filtered_tokens ['@jdarter', 'oh!', 'haha...', 'dude', 'dont', 'really', 'look', 'em', 'unless', 'someone', 'says', 'hey', 'added', 'you.', 'sorry', "i'm", 'terrible', 'that.', 'need', 'pop', 'up!']
# filtered_tokens ['@ninjen', "i'm", 'sure', 'right...', 'need', 'start', 'working', 'nikster...', 'jared', 'least!']
# filtered_tokens ['really', 'hate', 'people', 'diss', 'bands!', 'trace', 'clearly', 'ugly!']
# filtered_tokens ['gym', 'attire', 'today', 'was:', 'puma', 'singlet,', 'adidas', 'shorts.......and', 'black', 'business', 'socks', 'leather', 'shoes', 'lucky', 'run', 'cute', 'girls.']
# filtered_tokens ['show', 'location?!', 'http://twitpic.com/2y2es']
# filtered_tokens ['picnic', 'phone', 'smells', 'like', 'citrus.']
# filtered_tokens ['@ashleyac', 'donkey', 'sensitive', 'comments.', 'nevertheless,', "he'd", '(and', "me'd)", 'glad', 'see', 'mug', 'asap.', 'charger', 'still', 'awol.']
# filtered_tokens ['new', 'csi', 'tonight.', 'fml']
# filtered_tokens ['think', 'arms', 'sore', 'tennis']
# filtered_tokens ['wonders', 'someone', 'u', 'like', 'much', 'make', 'unhappy', 'split', 'seccond', '.', 'depressed', '.']
# filtered_tokens ['sleep', 'soon...', 'hate', 'saying', 'bye', 'see', 'tomorrow', 'night.']
# filtered_tokens ['@statravelau', 'got', 'ur', 'newsletter,', 'fares', 'really', 'unbelievable,', 'shame', 'already', 'booked', 'paid', 'mine']
# filtered_tokens ["missin'", 'boo']
# filtered_tokens ['@markhardy1974', '#itm']
# filtered_tokens ['damn...', 'chalk!', 'chalkboard', 'useless']
# filtered_tokens ['blast', 'getty', 'villa,', 'hates', 'sore', 'throat', 'day.', 'getting', 'worse']
# filtered_tokens ['@msdrama', 'hey', 'missed', 'ya', 'meeting', 'sup', 'mama']
# filtered_tokens ['tummy', 'hurts.', 'wonder', 'hypnosis', 'anything', 'it?', 'so,', 'working,', 'get', 'it,', 'stop', 'smoking!!!']
# filtered_tokens ['always', 'fat', 'ones?!']
# filtered_tokens ['@januarycrimson', 'sorry,', 'babe!!', 'fam', 'annoys', 'too.', 'thankfully,', "they're", 'asleep', 'right', 'now.', 'muahaha.', '*evil', 'laugh*']
# filtered_tokens ['@hollywoodheat', 'paid', 'attention', 'covered', 'photoshop', 'webpage', 'design', 'class', 'undergrad']
# filtered_tokens ['wednesday', 'b-day!', 'know', '2', 'do!!']
# filtered_tokens ['poor', 'cameron', '(the', 'hills)']
# filtered_tokens ['pray', 'please,', 'ex', 'threatening', 'start', 'sh**', 'my/our', 'babies', '1st', 'birthday', 'party.', 'jerk.', 'still', 'headache']
# filtered_tokens ['@makeherfamous', 'hmm', ',', 'u', 'really', 'enjoy', '?', 'problems', 'constants', 'u', 'think', 'things', ',', 'find', 'someone', 'ulike']
# filtered_tokens ['strider', 'sick', 'little', 'puppy', 'http://apps.facebook.com/dogbook/profile/view/5248435']
# filtered_tokens ['rylee,grace...wana', 'go', "steve's", 'party', 'not??', 'sadly', 'since', 'easter', 'wnt', 'b', 'able', '2', 'much', 'ohh', 'well.....']
# filtered_tokens ['hey,', 'actually', 'one', 'bracket', 'pools!', 'bad', 'one', 'money']
# filtered_tokens ['@stark', 'follow', 'me,', 'either', 'work', 'you!']
# filtered_tokens ['bad', 'nite', 'favorite', 'teams:', 'astros', 'spartans', 'lose.', 'nite', 't.w.', 'good.']
# filtered_tokens ['body', 'missing', 'northern', 'calif.', 'girl', 'found:', 'police', 'found', 'remains', 'missing', 'northern', 'california', 'girl', '..', 'http://tr.im/imji']
# filtered_tokens ['@mangaaa', 'hope', 'increase', 'capacity', 'fast,', 'yesterday', 'pain.', 'got', 'fail', 'whale', '+15', 'times', '2', 'hours....']
# filtered_tokens ['behind', 'classes', 'work']
# filtered_tokens ['watching', '&quot;house&quot;']
# filtered_tokens ['@kpreyes', 'remember', 'bum', 'leg?', 'strikes', 'back', 'time', 'serious']
# filtered_tokens ['@paradisej', 'cool,', 'will.', 'kinds', 'complaints', 'laptop', 'online', 'overheating,', 'recalls']
# filtered_tokens ['emily', 'glad', 'mommy', 'done', 'training', 'new', 'job.', 'misses', 'her.', 'http://apps.facebook.com/dogbook/profile/view/6176014']
# filtered_tokens ['would', 'rather', 'first', 'party', 'send', 'bad', 'messages', '3rd', 'party', 'send', 'mixed', 'ones', 'sophmore', 'year', 'again?']
# filtered_tokens ['@henkuyinepu', 'overrated']
# filtered_tokens ['@marykatherine_q', 'know!', 'heard', 'afternoon', 'wondered', 'thing.', 'moscow', 'behind', 'times']
# filtered_tokens ['laying', 'bed', 'voice..']
# filtered_tokens ["i'm", 'sooo', 'sad!!!', 'killed', 'kutner', 'house', 'whyyyyyyyy']
# filtered_tokens ['@jacobsummers', 'sorry', 'tell', 'mea', 'culpa', 'really', 'sorry.']
# filtered_tokens ['@alliana07', 'make', 'sense', 'me,', 'suicide', 'thing.', 'refuse', 'believe', 'actually', 'happened.']
# filtered_tokens ['@salancaster', 'hope', 'ok.']
# filtered_tokens ['@mercedesashley', 'damn!', 'grind', 'inspirational', 'saddening', 'time.', 'want', 'stop', 'cuz', 'like', 'u', 'do!', 'much', 'love']
# filtered_tokens ['@hibanick', 'yeah', 'aw', 'know', 'wudnt', 'stand', 'chance']
# filtered_tokens ['ugh.', 'cant', 'sleep.', '1:30am.']
# filtered_tokens ['hanging', 'crooners.', 'wanna', 'sing.', "can't.", 'sucks.']
# filtered_tokens ['@erre_sc', 'aaw', 'miss', 'ya', 'too..', 'im', 'leaving', 'bh', 'tomorrow', '&quot;morning&quot;', 'think..', 'aww', 'wanna', 'go', 'beach', 'w', 'u', 'girls!!']
# filtered_tokens ['pissed', "there's", "asba's", 'radio', 'station.']
# filtered_tokens ['wednesday', 'b-day', 'n', 'know', '2', 'do!']
# filtered_tokens ['know', 'life', 'flipped', 'upside', 'thought', 'head', 'ramen', 'sounds', 'good.']
# filtered_tokens ['pain.', 'back', 'sides', 'hurt.', 'mention', 'crying', 'made', 'fail.']
# filtered_tokens ['late', 'night', 'snack,', 'glass', 'oj', 'b/c', "i'm", '&quot;down', 'sickness&quot;,', 'back', 'sleep...ugh', 'hate', 'getting', 'sick...']
# filtered_tokens ['@allyheman', 'but..', 'but..', 'but..', "i'm", 'big', 'fan', 'camilla', 'belle']
# filtered_tokens ['@grum', 'wah', "can't", 'see', 'clip,', 'must', 'el-stupido', 'work', 'filters.', "can't", 'wait', "'till", 'get', "'puter.", 'something', 'else', '2', 'blame', 'ex', '4.', 'broke', 'mine']
# filtered_tokens ['week', 'seems', 'get', 'longer', 'longer', 'terms', 'much', 'need', 'do..', 'much', "i'm", 'actually', 'going', 'get', 'done']
# filtered_tokens ["i'm", 'cold']
# filtered_tokens ['@thecoolestout', 'ehhh', "don't.", "weather's", 'gonna', 'take', 'turn', 'ugly', 'tomorrow']
# filtered_tokens ['@chelserlynn', 'haha', 'cooooold', 'd!', 'still', 'go', 'show.', 'incredible', 'stuff']
# filtered_tokens ['hoping', 'tummy', 'rumbles', 'go', 'away', 'soon']
# filtered_tokens ['@knights_', 'no,', 'notice.', 'told', "i'd", 'working', 'tomorrow,', 'called', 'agency', 'follow', 'said', 'over.']
# filtered_tokens ['almost', 'bedtime']
# filtered_tokens ["i'm", 'missing', 'babe..', 'long', 'alive', "i'm", 'happy..', 'yawwwnn..', "i'm", 'tired', 'love', 'imma', 'try', 'sleep', 'hopefully', 'headstart']
# filtered_tokens ['agh...snow!!!']
# filtered_tokens ['miss', 'kenny', 'powers']
# filtered_tokens ['@bridgetsbeaches', 'thank', 'letting', 'people', 'know,', "i'm", 'sad', 'direct', 'message', 'got', 'actually', 'bridget']
# filtered_tokens ['...and,', 'india', 'missed', '100th', 'test', 'victory', 'n', '10th', 'consecutive', 'win', 'without', 'loss.']
# filtered_tokens ['@jonathanrknight', 'guess', "that's", 'then.']
# filtered_tokens ['sadly', 'going', 'bed.']
# filtered_tokens ['@ozesteph1992', 'shame', 'hear', 'stephan']
# filtered_tokens ['@mrsaintnick', 'hey!', "i'm", 'leavin', 'morning...']
# filtered_tokens ['intending', 'finish', 'editing', '536-page', 'novel', 'manuscript', 'tonight,', 'probably', 'happen.', '12', 'pages', 'left']
# filtered_tokens ['laid', 'around', 'much', 'today...', 'head', 'hurts']
# filtered_tokens ['@twista202', 'still', 'read', '9th&amp;10th', 'princess', 'diaries', 'saving', 'francesca', 'made', 'cry', 'end.', 'hmm', 'easy', 'books.']
# filtered_tokens ['nokia', '1110', 'died..']
# filtered_tokens ['mom', 'might', 'breast', 'cancer', 'find', 'anything', 'for.', 'like', 'week', "i'm", 'worried!']
# filtered_tokens ['going', 'sleep.', 'hoping', 'tomorrow', 'better', 'day.']
# filtered_tokens ['@rumblepurr', 'lol..', 'wish', 'understood', 'daylight', 'savings', 'ended', 'though', 'breakfast', 'hour', 'later', 'keep', 'waking', 'kids']
# filtered_tokens ['@onemoreproject', 'lame']
# filtered_tokens ['understand...', 'really']
# filtered_tokens ['heroes', 'season...']
# filtered_tokens ['living', 'downtown', 'sure', 'much', 'fun.']
# filtered_tokens ['@jonathanchard', 'calorie', 'wise', 'wish', 'junk', 'food', 'calorie', 'free!', 'ate', 'thing', 'sour', 'skittles', 'big', 'ass', 'cherry', 'coke!']
# filtered_tokens ['man', 'work', 'hard']
# filtered_tokens ['getting', 'sick', 'time', 'hot', 'tea,', 'studying,', 'sleeeep']
# filtered_tokens ['getting', 'eyebrows', 'waxed.', 'pain']
# filtered_tokens ['phantasy', 'star', 'yesterday', 'going', 'work...']
# filtered_tokens ['oh', '-', 'got', 'macheist', '3.0', 'apps', '-', 'sweet.', 'get', 'espresso', 'serial', 'though', 'although', 'said', 'sent', '-', 'oh', 'well']
# filtered_tokens ['picked', 'mich', 'st', 'win', 'get', 'go.', 'feeling', 'pretty', 'good', 'pick', 'way', 'until......tonight.', "a's", 'lost']
# filtered_tokens ['alone', 'downstairs...working']
# filtered_tokens ['feel', 'bad']
# filtered_tokens ['@ryanseacrest', 'me,', 'hates', 'anoop.', 'mean', 'seriously,', 'kinda', 'mean', 'him.']
# filtered_tokens ['@pinkserendipity', 'yes', 'sprint', '4g', 'baltimore', 'chicago', 'far']
# filtered_tokens ["i'm", 'stuck', 'awake', 'middle', 'night', 'second', 'day', 'row.', 'felt', 'terrible', 'yesterday.']
# filtered_tokens ['thanks', 'bursting', 'bubble']
# filtered_tokens ['going', 'school', 'soon...', "can't", 'find', 'anything', 'wear!!', 'gosh', 'hard']
# filtered_tokens ['@marieclr', 'serious', 'lol']
# filtered_tokens ['@naughtyhaughty', 'page', 'sooooo', 'long!!!', 'got', 'deleted', 'sad', 'day', 'history']
# filtered_tokens ['crazy', 'wind', 'today', '=', 'birding', 'http://ff.im/1xtti']
# filtered_tokens ['currently', 'work..']
# filtered_tokens ['grrr..', 'ipods', 'acting', 'weird', 'too!', 'jai', 'ho', 'thinking', 'playing', 'full', 'songs..', 'ughh.']
# filtered_tokens ['@penndbad', 'send', 'dvd', 'cos', 'missed', 'heaps', 'happy', 'that!']
# filtered_tokens ['see', 'big', 'deal', 'website']
# filtered_tokens ['@machineplay', "i'm", 'sorry', 'go', 'this.', 'again.', '#therapyfail']
# filtered_tokens ['@colindemar', 'far', 'way', 'rail.', 'tips?']
# filtered_tokens ["i'm", 'still', 'swear.', 'keep', 'losing.', 'gaining.', 'losing.', 'gaining.', 'tweeps?', 'heart', 'wrenching.']
# filtered_tokens ['today', 'realized', 'good', 'hiding', 'things,', 'even', "can't", 'find']
# filtered_tokens ['staying', 'friends', 'house...house', 'sitting,', 'neighbors', 'loud-having', 'party']
# filtered_tokens ['@dannyvegasbaby', 'danny', 'im', 'upset', 'wasnt', 'watch', 'live', 'chat', 'car.', '3', 'hours', 'trip', 'im', 'soooo', 'upset!!']
# filtered_tokens ['check', 'mug', 'http://www.erika-obscura.blogspot.com']
# filtered_tokens ['borders', 'closed', '10']
# filtered_tokens ['downloading', "nin's", 'new', 'album', '&quot;the', 'slip&quot;', '-', 'hell', 'come', 'out?', "i'm", 'behind', 'times', 'days']
# filtered_tokens ['woke', 'already', 'written', 'e-mail...', "i've", 'go', 'early', 'university', 'today', 'teach', '8:30', 'am!']
# filtered_tokens ['watching', 'hill', '.', '.', '.and', 'making', 'sad']
# filtered_tokens ['many', 'channels....', 'yet', 'boring...', 'lazy', 'day', 'may', 'find', 'hobby']
# filtered_tokens ['@supersport', 'miss', 'buddy', 'ill', 'ny', '25th']
# filtered_tokens ['@robluketic', 'love', 'french.', 'tell', 'people', 'south', "i'm", 'qtr.', 'french', 'snarl', 'me.', 'french', 'beautiful', 'people']
# filtered_tokens ['opps..', 'said..', 'still', 'got', 'one', 'day', 'remain', 'problem', 'come']
# filtered_tokens ['activated', 'selfcontrol', 'block', 'early,', 'meaning', "can't", 'check', 'new', 'qc.', 'regularizing', 'internal', 'clock', 'might', 'difficult.', '#fb']
# filtered_tokens ['@hillydop', 'oh']
# filtered_tokens ['spencer', 'good', 'guy.']
# filtered_tokens ['@goodlaura', 'reese', 'dying', '#ttsc?', 'season', 'finale', 'next', 'week.', '#24', 'boring,', 'madame', 'president', 'crazy', 'woman.']
# filtered_tokens ['@jonathanrknight', 'hate', 'limited', 'letters,too.hope', 'guys', 'fine?i', 'pray', 'dog,she�s', 'well']
# filtered_tokens ['get', 'shit', 'done', 'today', '~', "i'm", 'screwed']
# filtered_tokens ['wanttss', 'go']
# filtered_tokens ['going', 'sleep', 'tonite.']
# filtered_tokens ['worried', 'tired', 'post', 'tonight']
# filtered_tokens ['get', 'shit', 'done', 'today', '~', "i'm", 'screwed']
# filtered_tokens ['job', 'interview', 'cardiff', 'today,', 'wish', 'luck!', 'got', '3', 'hours', 'sleep']
# filtered_tokens ['@stustone', 'show', 'whack.', 'way', 'worse', 'whack,', 'wiggety-whack.', ':*(:*(:*(']
# filtered_tokens ['@djalizay', 'really', 'think', 'people', 'choose', 'way.', 'think', 'chose', 'accept', "family's", 'help', 'might', 'dead']
# filtered_tokens ['@eloquentembrace', 'going', 'kill', 'me,', "i've", 'seen', 'ds9.', "i've", 'waiting', 'till', 'one', 'solid', 'week', 'sitting.']
# filtered_tokens ['@cheechbud', 'think', 'ur', 'right!!', 'hahaha!!', '4.5', 'hrs', 'now!!']
# filtered_tokens ['hate', 'see', 'spartans', 'sad']
# filtered_tokens ['mind', 'body', 'severely', 'protesting', '&quot;getting', 'up&quot;', 'thing.', 'nightmares', 'boot']
# filtered_tokens ['@mysteezradio', "i'm", "goin'", 'follow', 'u,', 'since', 'u', 'lol', 'go', 'angels!']
# filtered_tokens ['@mandayyy']
# filtered_tokens ['@twista202', 'think', 'want', 'read', 'books', 'library']
# filtered_tokens ['nap', 'interrupted', 'many', 'times', 'today', 'going', 'japanese', "'rents", 'again...']
# filtered_tokens ['kind', 'longs', 'bus', 'shows', 'end', 'ghost', 'world', 'right', 'now.', 'ugh.']
# filtered_tokens ['@gurumn', 'canada', 'canada', 'weird.', "we're", 'supposed', 'get', 'snow', 'wednesday.', 'ugh.']
# filtered_tokens ['awwh', 'babs...', 'look', 'sad', 'underneith', 'shop', 'entrance', "&quot;yesterday's", 'musik&quot;', 'o-:', 'like', 'look', 'new', 'transformer', 'movie']
# filtered_tokens ['sad', "'feet'", 'macbook', 'fell']
# filtered_tokens ["i'm", 'gonna', 'get', 'late', 'tomorrow', '132am', 'here.', 'gonna', 'get', 'tipsy', 'lonesome.', "that's...that's", 'sad']
# filtered_tokens ["i'm", 'sweating', 'forthcoming', 'trip', 'e3.', "can't", 'find', 'someone', 'crash', "i'm", 'there,', 'may', 'screwed.']
# filtered_tokens ['gotten', 'somebody', 'read', 'tweets,', 'cant', 'get', 'make', 'account.']
# filtered_tokens ['@infinitydefines', 'omgawd', 'couldnt', 'handle', 'cat', 'heat', 'time', 'd:', 'd:']
# filtered_tokens ['@donniewahlberg', 'hope', 'make', 'auburn', 'show.', 'looking', 'good']
# filtered_tokens ['@david_henrie', '*thats', 'people', 'mag', 'haha', 'couldnt', 'fit', 'in..', 'dont', 'think', 'pictures', 'ever', 'made', 'magazine', 'tho!', 'haha']
# filtered_tokens ['@breadandbadger', 'congrats!!', 'totally', 'forgot', 'submit', 'photos']
# filtered_tokens ['@paulaabdul', 'awww,', 'good', 'luck', 'paula!!', 'please', 'work', 'hard', 'hope', 'fun', 'new', 'album', 'gonna', 'amazing!', 'xxx']
# filtered_tokens ['@imaginarypeach', 'leaving', '....', '-gets', 'sad-']
# filtered_tokens ['miss', 'twitter.', 'phone', 'broke,', "i'm", 'using', 'stupid', 'nokia', 'phone.', 'ughhh,', 'miss', 'advance', 'phone.']
# filtered_tokens ['shooting', 'outside', 'house', ':o', 'kidding!', 'scared']
# filtered_tokens ['tuesday�ll', 'start', 'reflection', '�n', 'lecture', 'stress', 'reducing', 'techniques.', 'sure', 'might', 'become', 'useful', 'us', 'accompaniers']
# filtered_tokens ['tragedy', 'disaster', 'news', 'week']
# filtered_tokens ['yes', 'yes', 'still', 'trying', 'find', 'picture', 'upload', 'correclty..']
# filtered_tokens ['oh', 'red', 'sox', 'game', 'rained', 'out?', 'looking', 'forward', 'opening', 'day']
# filtered_tokens ['still', "can't", 'find', 'keys.']
# filtered_tokens ['@charlietm', 'know', 'right.', 'dunno', 'going', 'twitter.']
# filtered_tokens ['might', 'getting', 'sore', 'throat']
# filtered_tokens ['@labelsnotlove', 'home', 'town.', 'mammy', 'called', 'depressd.', 'pls', 'explain', 'parent', 'let', '8yr', 'old', 'child', 'walk', 'alone?', 'hello?', '2009!']
# filtered_tokens ['@ircmaxell', '-', 'think', 'need', 'find', 'better', 'anti-depressants.', 'think', 'paxil/wellbutrin', 'combo', 'losing', 'efficacy.']
# filtered_tokens ['@myconnecticut', 'restaurant', 'called', 'woodntap', 'competitive', 'eating', 'tourney', 'round', 'tourney', 'time.', 'place', '2nd']
# filtered_tokens ['bathroom...', 'wake', 'lakin.']
# filtered_tokens ['@caitlinoconnor', 'want', 'tacos', 'margarhitas', 'telll', 'gay', 'say', 'hello&lt;3']
# filtered_tokens ['im', 'lonely', 'keep', 'company!', '22', 'female,', 'california']
# filtered_tokens ['bad', 'day', 'betfair', 'office']
# filtered_tokens ['miss', 'him.', "can't", 'wait', 'celebrate', 'tar', 'heel', 'win', 'weekend', 'though!!']
# filtered_tokens ["i'm", 'really', 'cold.', 'want', 'go', 'sleep', 'yet', "there's", 'nothing']
# filtered_tokens ['@kristencampisi', '4', 'u?', "'", 'officially', "'", '4', 'go', 'round!']
# filtered_tokens ['monkeys???', 'found', 'twin', 'wont', 'even', 'write', 'back.', "i'm", 'heartbroken']
# filtered_tokens ['@miss_om', 'aww', 'know', 'felt', 'like', 'yesterday', 'work']
# filtered_tokens ['@sarahreedsc', 'treaty', 'defined']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['@jpfurry', 'poor', 'john', 'happens', 'play', 'fruit', 'microwave!', 'seriously', 'though', 'seen', 'doctor??', 'xxx']
# filtered_tokens ['missing', 'bff', 'watching', 'home', 'away', 'reminds', '&lt;3', 'it.', 'shout', 'u', 'courts']
# filtered_tokens ['@mandayyy']
# filtered_tokens ['new', 'video', 'card', 'doa.']
# filtered_tokens ['feeling', 'lost,', 'naked', 'confused', '(jk,', 'sort', 'of).....no', 'iphone', 'me.']
# filtered_tokens ['damn', 'late', 'filling', 'appraisal', 'form,', 'people', 'almost', 'sent', '..', 'occupied', 'work']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['think', 'much', 'past.', 'cant', 'change', 'it.', 'deserved', 'much', 'wat', 'got.', '..but', 'still', 'thinking', 'gah']
# filtered_tokens ['lost', 'ring.', 'no-where', 'seen']
# filtered_tokens ['@burgaw', 'ooooooh!', '*sealclap*', 'see,', 'download', 'shitloads', 'zip', 'folders', '4chan.', 'internet', 'moneys.', 'fuck', 'yeah', 'alicia', '&amp;', 'mikey.']
# filtered_tokens ['still', 'nursing', 'nile', 'glad', 'feeling', 'better.', 'hate', 'baby', 'sick']
# filtered_tokens ['fucked', 'go', 'back', 'ic']
# filtered_tokens ['@brandizzzle08', 'yoyoyo.', 'internet', 'rude', 'tonight.', 'reconnected', "i'm", 'go', 'bed.']
# filtered_tokens ['@jemcam', 'well', 'uni', 'stuff', 'netball', 'netbal', "i've", 'done', 'uni', 'stuff']
# filtered_tokens ['@kissability', 'poor']
# filtered_tokens ['help', 'forget', '8th', 'april', '&amp;', '13th', 'july!']
# filtered_tokens ['dierks', 'bentley', "comin'", 'columbus,', 'oh!!', 'wanna', 'go', 'bad']
# filtered_tokens ['take', 'sidekick', 'back.']
# filtered_tokens ['@chriscantore', 'congrats!', "i'm", 'totally', 'jealous!', 'wish', 'xm', 'working']
# filtered_tokens ['gr8t', 'face', 'itchy']
# filtered_tokens ['poor', 'socks', 'luvvvvv', 'golden', 'retriever!!', 'want', 'one', 'sighhhh']
# filtered_tokens ['saw', 'found', 'tracy', 'girl', 'piece', 'luggage...', 'fucking', 'terrible']
# filtered_tokens ['aaaaand', 'nausea', 'back.']
# filtered_tokens ['@donniewahlberg', 'ooh', 'i�m', 'excited', 'even', 'going', '2', 'long', 'love', 'youtube!']
# filtered_tokens ['spent', '1', 'hour', 'reach', 'axis', 'bank', 'find', 'today', 'holiday', 'mahavir', 'jayanti', 'contd..']
# filtered_tokens ['@mathewsmichael', 'agree...', 'jobros', 'dont', 'update', 'theres', 'often']
# filtered_tokens ['@fishmouse', 'hilarious', 'linked', 'clip', 'lj', 'time', 'ago', 'went', 'back', 'dead', 'link']
# filtered_tokens ['@diannepulham', 'oooooooo', 'with?', '(im', 'neither', 'thats', 'need', 'study', ')']
# filtered_tokens ['tweeted', 'nearly', 'day', 'posted', 'website', 'tonight,', 'hopefully', 'goes', 'well', 'night', 'time!']
# filtered_tokens ['@bostongarden', 'miss', 'bentley']
# filtered_tokens ['seriously', 'needs', 'finish', 'job', 'applications']
# filtered_tokens ['son', 'vincas', 'sick,', 'stay', 'home', 'three', 'tense', 'days', 'work,', 'back', 'holiday', 'kids']
# filtered_tokens ['whinging.', 'client&amp;boss', 'understand', 'english', 'well.', 'rewrote', 'text', 'unreadable.', 'written', 'v.', 'good', 'writer&amp;reviewed', 'correctly.']
# filtered_tokens ['@huntermoore', 'want', 'ever', 'punch', 'me.']
# filtered_tokens ['sooo', 'sick', 'snow', 'ughh']
# filtered_tokens ['@its_nemesis', '-------']
# filtered_tokens ['@lovemeagan', 'work', 'fan', 'upset']
# filtered_tokens ['would', 'like', 'apologize', 'repeated', 'video', 'games', 'live', 'related', 'tweets.', 'going', 'stern', 'discussion', 'koodo', 'soon.', 'stern.']
# filtered_tokens ['@zaydia', 'cant', 'figure', 'get', '/', 'back', '/', 'pay', 'hotel', 'etc']
# filtered_tokens ['fml:', 'much', 'seniority,', 'bc', 'technological', 'ineptness,', '&quot;register&quot;', 'classes']
# filtered_tokens ['feels', 'like', 'slept', 'day', 'away.', 'looking', 'forward', 'bouts', 'gallbladder.', 'least', 'pills', 'pain.']
# filtered_tokens ['@thastevieg', 'really', 'want', 'old', 'bass', 'back']
# filtered_tokens ['mad', 'tired', 'today...', 'callin', 'early', 'tonight', 'nighty', 'night', 'twittas']
# filtered_tokens ['@levenrambin:', 'take', 'easy,', 'good', 'you.']
# filtered_tokens ["i'm", 'afraid', 'bad', 'code.']
# filtered_tokens ['think', "i'm", 'going', 'bed.', 'goodniight.', 'hate']
# filtered_tokens ['@riancurtis', "i'm", 'here,', 'friend,', 'love', 'you.']
# filtered_tokens ['@kariajay', 'time', 'notice', 'gone...just', 'needed', 'db2', 'it??']
# filtered_tokens ['@aaronrva', 'bathroom', 'pee!']
# filtered_tokens ['@ashleyskyy', 'wanted', 'margarita', 'too!']
# filtered_tokens ['@kourtneykardash', 'yup', 'night', 'workouts', 'r', 'worst', 'unfortunetly', 'work', 'schedule', 'allows', 'go', 'night', 'tough!']
# filtered_tokens ['called', 'hillsong', '-', 'said', 'tell', 'waiting', 'list', '-', 'know', 'looking', 'good']
# filtered_tokens ['0g', 'milky', 'bar', 'left,', 'around', '200ml', 'coke']
# filtered_tokens ['@jokerrrr', 'stillllll', 'arrived']
# filtered_tokens ['mraow,', 'feel', 'like', 'dancing,', 'first', 'art', 'school', 'wants', 'rape', 'more.']
# filtered_tokens ['@karenucol', 'ah!', 'bet', "i've", 'like', 'craving', 'play', 'softball', 'basketball', '!!!', 'noo', 'time']
# filtered_tokens ['terrified', 'accidentally', 'deleted', 'reference', 'management', 'assignment', 'hopes', 'doesnt', 'get', 'trouble', 'gets', 'back']
# filtered_tokens ['amazon', 's3', 'plugin', 'worked', 'website', '.', 'need', 'php', '5', '.', 'hosting', 'provider', 'php', '4.4', '.', 'sad.']
# filtered_tokens ['argh!', 'suuuper', 'sleepy', 'hour', 'ago,', "i'm", 'wide', 'awake.', 'hope', 'stay', 'night.', ':-/']
# filtered_tokens ['@austinhill', 'wish', 'was!', 'sold', 'time', 'let', 'know,', 'would', 'love', 'hear', 'to!']
# filtered_tokens ['watched', 'tropic', 'thunder.', 'dreading', 'tomorrow']
# filtered_tokens ['@qweendassah', "no...he's", 'still', "miss'n..."]
# filtered_tokens ['chiefdelphi']
# filtered_tokens ['http://twitpic.com/2y2wr', '-', 'according', 'bro,', 'new', 'puppy', 'poo', 'fight', 'covered', 'poop', '(picture', 'stolen', 'him)']
# filtered_tokens ['playing', 'game', 'home!', 'new', 'boss', 'call', 'yet...']
# filtered_tokens ['su', 'yin', 'huen', 'tweeted', 'feel', 'unbearable', 'guilt.', 'made', 'staff', 'cry', 'http://tinyurl.com/cw2l9t']
# filtered_tokens ['poor', 'joshy', 'sick???', 'damn', 'tejanos!']
# filtered_tokens ['thoughts', 'sandra', "cantu's", 'family', 'difficult', 'sad', 'time']
# filtered_tokens ['@franzglaus', 'know,', 'wanted', 'let', 'everybody', 'know', 'happening']
# filtered_tokens ['michigan', 'who?', 'know', 'them.', '*sigh*', 'shameful!']
# filtered_tokens ['fill', 'two', 'hours']
# filtered_tokens ['@alicayaba', 'cuuute!', 'hey,', 'miss', 'na!', 'seeing', 'girls', 'everyday']
# filtered_tokens ['@jonathanrknight', 'oh!', 'mention', 'it?', '&quot;gooooood', 'moooorniiiiiiing&quot;', 'germany!', 'im', 'back', 'cage....or', 'better...my', 'office']
# filtered_tokens ['throat', 'closing', 'string', 'cheese.', 'good', 'idea']
# filtered_tokens ['aww,', 'sandra', 'cantu', 'found', 'dead', 'suitcase', 'missing', 'children', 'stories', 'never', 'seem', 'go', 'good.', 'poor', 'family.']
# filtered_tokens ['wishing', 'home', 'underneath', 'covers']
# filtered_tokens ['walking', 'home', 'school', 'drains', 'energy']
# filtered_tokens ['@ridley1013', 'agree.', 'shapeshifting', 'copout.', 'excited', "angela's", 'ep,', 'thought', 'week.', 'noah', 'awesome', 'tho!']
# filtered_tokens ['@savethestrib', 'dang!', 'would', 'done', 'knew', 'earlier.', 'outings', 'planned?']
# filtered_tokens ['wish', 'better', 'writing.', 'taking', 'long', 'write', 'paper.']
# filtered_tokens ['..and', 'course...', 'access', 'halo', '3', 'mythic', 'map', 'pack', 're-download..', 'bad', 'news..', 'legendary', 'map', 'pack...', 'ugh..', '600ms...']
# filtered_tokens ['@vene2ia', '...not', 'yet', 'unfortunately,', 'another', 'weeks', "i've", 'told', 'you?', "i've", 'little', 'bit', 'busy', 'latest', 'project.']
# filtered_tokens ['@thecoolestout', 'ha', "sun's", 'already', 'gone']
# filtered_tokens ['day', '2.', 'lot', 'harder', 'day', '1.', "let's", 'see', 'day', '3', 'goes', 'tomorrow.']
# filtered_tokens ['man', 'crush', 'jake', 'peavy', 'let', '#gayforpeavy']
# filtered_tokens ['@trishzw', 'megafast', 'trip,', 'time', 'day', 'tom/weds?', 'or,', 'going', 'tonight?', 'want', 'see', 'bad.', 'tried', 'warn', 'you,', 'tech', 'fail']
# filtered_tokens ['michigan', 'state', 'make', 'sad']
# filtered_tokens ['omg.', 'mouth', 'much', 'pain', 'wanna', 'sleep', 'untill', 'time', 'take', 'braces', 'off.']
# filtered_tokens ['getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biofuel', 'proposal:', 'getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biof..', 'http://tinyurl.com/ceprvs']
# filtered_tokens ['@mizzchievouz', 'hey', 'girl.', 'site', 'back.', 'girlyvue', 'back', 'even', 'videos.']
# filtered_tokens ['@a5hleyf', "i'm", 'spending', 'time', 'grandma', 'early', 'tomorrow', "can't", 'leave', 'skittles', 'herself.']
# filtered_tokens ['got', 'home', 'watching', 'michigan', 'state', 'get', 'tromped!']
# filtered_tokens ['oh', 'jew-bus!', 'two', 'years', 'worth', "classes'", 'work', 'alot', 'organize', '&gt;_&lt;', "i'm", 'finishing', 'tonight,', 'possible...my', 'bones', 'ache']
# filtered_tokens ['@griffmiester', 'exchanging', 'me,', 'laptop', 'arrived']
# filtered_tokens ['@hyperbets', 'hope', 'last', 'long.', 'feel', 'miserable!']
# filtered_tokens ['@rcompo', 'rachel!', 'hang', 'outage', 'neccessary', '-', 'gonna', 'home', 'wekend', 'dumb', 'folk', 'make', 'work', 'im', 'free', 'f', 'sat', '4...']
# filtered_tokens ['@theleaguesf', 'fun', '&amp;', 'furious?', 'new', 'mantra', 'bay', '2', 'breakers?', 'getting', '2', 'rambunctious;the', 'city', 'overreacted', '&amp;', 'clamped']
# filtered_tokens ['@amber_benson', 'hubby', '(for', 'reason)', 'thinks', 'important', 'good', 'spot', 'red', 'carpet', 'trek', 'movie', 'premiere.', 'sod!']
# filtered_tokens ['swear', 'matter', 'long', "i've", 'getting', '5am,', 'never', 'gets', 'easier.', 'man', 'eyes', 'hurts', 'wah']
# filtered_tokens ['@jeffree_star', 'jeffree!', 'keep', 'hair', 'one', 'color?', 'permanent', 'dye', 'fades', 'within', 'week']
# filtered_tokens ['@otakusecret', 'reaction', 'whoa,', 'see', 'coming']
# filtered_tokens ['still', 'sick.', 'feeling', 'bit', 'better,', 'got', 'new', 'medicine....', 'hope', 'feel', 'good', 'night', 'sleep.', 'ohh,', 'suppose', 'snow!', 'wtf!']
# filtered_tokens ['@dangerm0use', 'think', 'maybe', 'get', 'couple', 'hours', 'sleep,', 'hon.', 'productive', 'right', 'ur', 'dog', 'tired?', 'worry']
# filtered_tokens ['@maddyva', 'thanks', 'lot.', 'learned', 'lot', 'new', 'words', 'find', 'looking', 'for.']
# filtered_tokens ['wish', 'xblm', 'downloads', 'gamertag', "'hitokyri'.", '5', 'gamertag', 'thing', 'nonsense...', "i'm", 'tired']
# filtered_tokens ['new', 'testament', 'test', '9:30']
# filtered_tokens ['@scoutbuck', 'tons', 'hay', 'troll?', 'ahhhh']
# filtered_tokens ['stupid', 'movies', 'watched...', 'mirrors', 'ugggggh...', 'stooopeeed!!!', 'rip', 'off!']
# filtered_tokens ['http://twitpic.com/2y2yi', '-', 'love', 'you,', 'buck.']
# filtered_tokens ['last', 'one!!!', 'still', 'done!!!']
# filtered_tokens ['homework....']
# filtered_tokens ['understand', 'things', 'get', 'taken', 'away.', 'enough', 'time', 'unfair.', 'want', 'back!!', 'like', 'baby']
# filtered_tokens ['scratch', 'that:', 'du', 'heif', '(two', 'half)', 'cookies.', 'tum', "can't", 'take', 'anymore', 'shoog.', 'poots']
# filtered_tokens ['@cococourtney', 'listening', 'sweets', 'first', 'time', 'forever!', 'miss', 'much', 'go', 'chi', 'town', 'visits', 'plz?']
# filtered_tokens ['geez', 'busy', 'afternoon.', 'meetings,', 'emails,', 'meetings', 'email', 'meetings.', '6pm', 'day', 'still', 'going!', 'ah', 'dark']
# filtered_tokens ['dang!!!', 'another', 'spring', 'break!!!', 'cool', 'that???', 'bad', 'work', 'week', 'oh', 'well,', 'money', 'phone.', 'ttyl', 'everbody!!!']
# filtered_tokens ['@sara_kate', 'im', 'afraid', '(', 'ur', 'reply', 'uni', 'ages', 'ago']
# filtered_tokens ['feeling']
# filtered_tokens ['@carvin1', 'lol', 'emotional', 'ass', 'men!!', 'omg', 'late', 'night', 'eating..', 'us', 'broke']
# filtered_tokens ['@nick_carter', 'aww', 'nick!!', 'like', 'hair', 'longer,', 'cut', 'off?', 'break.', 'my.', 'heart.']
# filtered_tokens ['wonder', 'jon', 'lost', 'net']
# filtered_tokens ['wow.', 'depressing', 'thing', 'world', 'losing', 'video', 'created', 'matter', 'seconds.', '#fml']
# filtered_tokens ['@nchokkan', 'https://www.mycomicshop.com/search?tid=395031', 'says', 'stock']
# filtered_tokens ['@poohpot', 'lmao', 'im', 'sorry', 'poohpot', 'ate', 'all!']
# filtered_tokens ['chance', 'softbelly', '(for', '@mtub)', 'loud?']
# filtered_tokens ['time', 'move', 'posterior', 'lose', 'fat.', 'articulation', 'creaking', 'running', 'i�m', 'drool', 'swimming']
# filtered_tokens ['listening', 'nathan', 'cry....']
# filtered_tokens ['today', 'sucked.', "i'm", 'gonna', 'die', 'without', 'chris', 'callum!', 'wahhh!']
# filtered_tokens ['stou', 'site', 'update,', 'info', '2/2552', 'exam,', 'open', 'course,', 'must', 'wait', 'mail', 'notices', 'doc.', 'um...']
# filtered_tokens ["@ohsbrat30...i'm", 'sorry.', "i'm", 'feeling', 'kinda', 'yucky', 'myself.', '5am', 'going', 'come', 'quick']
# filtered_tokens ['love', 'scrappy', 'missin', 'already']
# filtered_tokens ['wants', 'hear', '@seblefebvre', "'s", 'song', 'myspace', 'messing']
# filtered_tokens ['bad', 'news', 'dad', 'cancer', 'dying', 'good', 'news', 'new', 'business', 'started', 'life', 'coach', 'practising', 'holistic', 'weight', 'management']
# filtered_tokens ['@duchess_rebecca', 'man...', 'intervention', 'soo', 'sad']
# filtered_tokens ['help!', 'need', 'new', 'boyfriend...', "i'm", 'stuck', 'rut']
# filtered_tokens ['feel', 'like', 'complete', 'idiot.', "i'm", 'one', 'get', 'shit', 'works', 'help']
# filtered_tokens ['saw', 'ad', 'craigslist', 'casting', 'call', 'female', 'host', 'g4.', 'totally', 'psyched!', 'realized', 'hoax']
# filtered_tokens ['pepperoni', 'rolls', 'l.a.?:', 'called', "valentino's", '-', 'said', 'sausage', 'rolls', 'pepperoni', 'rolls', 'http://tinyurl.com/cec5ka']
# filtered_tokens ['@soillodge', 'yes,', 'be.', 'monday']
# filtered_tokens ['want', 'new', 'gg', 'episode', 'already']
# filtered_tokens ['miss', 'watching', "rocko's", 'modern', 'life.']
# filtered_tokens ['rip', 'sandra....its', 'sad', 'someone', 'something', 'like', 'that??']
# filtered_tokens ['keeping', 'fingers', 'crossed', 'buddy', 'feeling', 'well.']
# filtered_tokens ['wait', 'eat??', 'skinny', 'vegas!!', "i'm", 'hungry!']
# filtered_tokens ['@marge_inovera', 'tried', 'tweetdeck', 'hated', 'passion.', 'hated', 'me,', "i'm", 'sure...']
# filtered_tokens ['@benackerman', 'btw', 'iphone', 'acting', 'funny,', 'dying', 'quickly', 'freezing', 'bs.', "i'm", 'admitting', 'anything,', 'sayin']
# filtered_tokens ['sitting', 'wondering', '&quot;ed&quot;', 'still', 'strong', 'hold']
# filtered_tokens ['@bananaface', 'im', 'sorry', 'got', 'sick.', 'lol.', 'going', 'bed', 'too.', 'night!']
# filtered_tokens ['@carolrainbow', 'internet', 'home,', 'drive', 'ox', 'use', 'internet', 'builders!']
# filtered_tokens ['@steve_buscemi', 'weather', 'canada', 'freezing']
# filtered_tokens ['twiggassssssss', 'range', 'day', "i'm", 'back', 'hopefully', 'good.']
# filtered_tokens ['@danadearmond']
# filtered_tokens ['anyone', 'reads', 'pray', 'grandma.', 'pain']
# filtered_tokens ['#3', 'woke', 'accident', '-', "&quot;it's", 'pushing,', 'pushing!&quot;', 'crying', 'stop', 'wetting', 'pants.']
# filtered_tokens ['home', 'franklin', 'street,', 'almost', 'jumped', 'fire.', 'someone', 'kicked', 'could.', 'jenny', 'lost', 'shoe.']
# filtered_tokens ['@johnnybeane', 'hey!', 'changed', 'default.']
# filtered_tokens ['finally', 'gave', 'bored', 'enough', 'start', 'thing.', 'think', '140', 'going', 'problem', 'tho.', 'like', 'myspace', 'status.']
# filtered_tokens ['@ellievolia', 'oooonly', 'really', 'lucky,', 'eh?', 'awh', 'definitely', 'early', 'work.']
# filtered_tokens ['buttload', 'homework!']
# filtered_tokens ['needs', 'another', 'copy', 'visual', 'studio', '2008']
# filtered_tokens ['we,', 'school', 'world,', 'week.my', 'school', 'silly', 'anyway...', 'look', 'bright', 'side.', "i'm", 'off,', 'u']
# filtered_tokens ['omg', "i've", 'economics', 'test.', 'dont', 'know', 'things', 'know', 'omg', 'im', 'gonna', 'fail']
# filtered_tokens ['@robcthegeek', 'upon', 'time', 'hundred', 'islands', 'pride', 'philippine', 'tourism,', 'coral/clam/rare', 'fish', 'poaching', 'in.', 'kinda', 'sad']
# filtered_tokens ['@henkuyinepu', 'yeah,', 'apparently', 'really', 'bad', 'taste']
# filtered_tokens ['@hummiemd', 'know!', 'really', 'surprised', 'since', 'everyone', 'recommends', 'youtube.', 'call', 'tomorrow', 'figure', 'out.']
# filtered_tokens ['waiting', 'airport', 'ride', 'get', 'harassed', '2', 'men', 'trying', 'sell', 'ugly', 'hats..', 'me?!', 'want', 'sleep..']
# filtered_tokens ['left', 'ids', 'location', 'go', 'bars', 'fuckkkkkkkkkkkkk']
# filtered_tokens ['@celycarmo', "i'm", 'sorry', 'understand', 'last', 'comment']
# filtered_tokens ['@officialrandl', 'announcement?', 'stayed', 'late', 'last', 'night']
# filtered_tokens ['@kishorek', 'strange,', 'illegal', 'torrents', 'avlbl', 'everywhere,', 'legal', 'dvd', 'stock', 'now???']
# filtered_tokens ['enough', 'say', 'imiss', 'u']
# filtered_tokens ['trolley', 'packed', 'like', 'sardines!', 'padre', 'game', 'remove', 'car?!', 'good', 'call', 'mts']
# filtered_tokens ['@randomlynat', 'jeez,', 'trying', 'help', 'haha.']
# filtered_tokens ['@supamagg', 'happened', 'saturday', 'night.', 'along', 'glittery', 'green', 'lighter!']
# filtered_tokens ['trying', 'reduce', 'number', 'cigarettes', 'day!']
# filtered_tokens ['yea', 'quiet', 'around', 'cuz', 'everyone', 'work', 'im', 'bored', 'death', 'nobody', 'talk']
# filtered_tokens ['gotta', 'cooking', 'assignment', 'hard']
# filtered_tokens ['@treesahquiche', 'okay,', 'applepears,', "i've", 'talked', 'people', "they've", 'before.', 'one', 'ever', 'told', 'me,', 'never']
# filtered_tokens ['@jennifermf', 'know!', "i'm", 'night', 'owl', 'nature,', 'hahaha', 'time', 'zone', 'behind', 'you?', 'almost', '1']
# filtered_tokens ['@mamasvan', 'lol', '-', 'nope!', 'complete', '#camerafail']
# filtered_tokens ['@maxime68', '@megelder', 'but!', "i'm", 'useless', 'sleep', 'fair!', 'want', 'fun', 'well!!!']
# filtered_tokens ['pookie', 'uti.', 'nurse', 'gabbie', 'get', 'back', '100%!!!', 'sodas!!!!!!!!!!!!!!']
# filtered_tokens ['@jillianfish', 'tweet', 'something', 'damn', 'it!', 'hang', 'please?']
# filtered_tokens ['@anistorm']
# filtered_tokens ["i'm", 'behind', 'video', 'games,', 'everything', 'matter.', "i'm", "yesterday's", 'news']
# filtered_tokens ['@sleep_til_noon', 'did,', 'one', 'left', 'got', 'tempted', 'ate', 'soon', 'got', 'home', 'chocolate', 'velvet', '&amp;', 'ate', 'mocha']
# filtered_tokens ['stressing', 'blackberry', 'keeps', 'flashing', 'red', 'alert', 'status', 'reason!!', 'faking', 'hate', 'it!!!']
# filtered_tokens ['http://twitpic.com/2y34e', '-', 'wanna', 'wear', 'doc', 'martens', 'out!', 'worn', 'since', 'december.']
# filtered_tokens ['shoe', 'repair', 'shop', 'guy', 'could', 'find', 'shoes!', 'go', 'back', 'see', 'find', 'couple', 'days.']
# filtered_tokens ['@b_barnett', 'really', 'see', 'coming']
# filtered_tokens ['woke', 'vivid,', 'sketchy,', 'not-cool', 'dreams', 'life.', 'time', 'stare', 'wall', 'lights', 'on.']
# filtered_tokens ["it'll", 'take', '3', 'days', 'sister', 'get', 'passport']
# filtered_tokens ['@nicolerichie', 'oh', 'yes!!', 'miss']
# filtered_tokens ['uh', 'oh...', 'think', 'getting', 'sick']
# filtered_tokens ['good', 'god', 'ruined', 'belly', 'button!!!']
# filtered_tokens ['watching', 'framed', 'roger', 'rabbit.', 'makes', 'miss', 'toon', 'town.']
# filtered_tokens ['@akianz', 'renting..', 'cheap', 'renting,', 'awesome', 'house.', '3', 'buying', 'attempts', 'fall']
# filtered_tokens ['running', 'nose', '+', 'spinning', 'head', '=', 'good', 'combination', 'meeting!']
# filtered_tokens ['@eazydoesit87', 'negative..', 'lost', 'vote', 'confidence']
# filtered_tokens ['nasty', 'budget', 'due', 'iphone', 'sent', 'apple', 'today.']
# filtered_tokens ['@sofii_noel', 'that�s', 'bad']
# filtered_tokens ['dammit,', 'episode', '3', 'kings', 'play', 'reason', 'stopped', 'middle', 'anything']
# filtered_tokens ["i'm", 'upset', 'missed', 'chat', 'quiz', 'online', 'free', 'internet', 'ceased']
# filtered_tokens ["can't", 'believe', 'it!', "i'm", 'disbelief', 'way', 'really.', 'much', 'take', 'people', 'always', 'get', 'hurt', 'others!!']
# filtered_tokens ['car', 'show', 'season', 'started', 'without']
# filtered_tokens ['throat', 'raw.']
# filtered_tokens ['@kevchoice', 'get', 'it.', 'persons', 'mind', 'could', 'even', 'ish', 'like', 'this???', 'prayers', 'fam', 'real']
# filtered_tokens ['@frago', 'hate', 'you.', 'need', 'see', 'that.', 'need', 'call', 'therapist', 'now.']
# filtered_tokens ['twilight', 'come', 'yesterday', 'fingers', 'crossed', 'today']
# filtered_tokens ['@nilelegania', 'glad', 'able', 'help', 'feel', 'better.', 'hate', 'see', 'sick', 'love', 'you!']
# filtered_tokens ['tireddddddd.', 'want', 'sleep', 'assignment', 'finish', 'exam', 'tomorrow', 'study']
# filtered_tokens ['know,', 'thinking...', 'need', 'money']
# filtered_tokens ['omg..its', 'jst', 'teusday']
# filtered_tokens ['@ddlovato', '@david_henrie', 'ummmmm', 'cant', 'find', 'it.']
# filtered_tokens ['heard', 'found', 'sandra', 'cantu...', '8', 'yrs', 'old']
# filtered_tokens ['@corrosivecandy', 'ive', 'forgotten', 'snoo-snoo', 'wonder', 'snoo-snoo', 'ever', 'meet', 'again...']
# filtered_tokens ['@amanorris', 'wow', 'last', 'tweet', 'made', 'seem', 'like', 'giant', 'sexist...sorry']
# filtered_tokens ['bathtub', 'drain', 'fired:', 'haz', '1', 'job', '2', 'do,', '&amp;', 'iz', 'fail.', 'got', 'drano', 'ass,', '&amp;', 'iz', 'still', 'draining.', 'wanna', 'shower,', 'dangit!!']
# filtered_tokens ['stuck', 'home']
# filtered_tokens ['@nomadicmatt', 'mine', '1/10', 'get', 'up?']
# filtered_tokens ['duckling', 'famous', "children's", 'book', 'stolen', "boston's", 'public', 'garden', '-', 'boston', 'globe', 'http://tinyurl.com/dc2htx', 'via', '@sharethis', 'oh', 'no!!']
# filtered_tokens ['@appomattox_news', 'thank', 'you!', 'however,', 'hate', 'list', 'includes', '2', 'convicts.']
# filtered_tokens ['heading', 'altrincham,', 'again!', 'hours', 'install']
# filtered_tokens ['morning!!!', 'good', 'im', 'bloody', 'knackered!!!', 'work', 'today', 'helppp!!!!', 'xxx']
# filtered_tokens ['@jeffreecuntstar', 'garage.', 'park', 'driveway!']
# filtered_tokens ['@lauredhel', 'happened?']
# filtered_tokens ['&quot;on', 'popular', 'music&quot;', 't.w.adorno', 'probably', 'difficult', 'reading', 'ever', 'prescribed,', "i'm", 'actually', 'struggling', 'continue']
# filtered_tokens ['http://twitpic.com/2y36e', '-', 'cant', 'see', 'flowers', 'falling', 'dont', 'camera,', 'cellphone']
# filtered_tokens ["we've", 'good.', "i'm", 'liking', 'snow', 'right', 'now,', 'getting', 'used', 'nice', 'spring-like', 'weather.', 'you?']
# filtered_tokens ['@brian_armstrong', 'pity', 'youtube', 'currently', 'blocked', 'china.', "can't", 'see', 'vids.']
# filtered_tokens ['@margaretcho', 'happened', 'show', 'hightlight', 'life']
# filtered_tokens ['best', 'leather', 'sofa', 'world!', 'office', 'though', 'means', "i'm", 'still', 'working']
# filtered_tokens ['still', '3', 'days', 'internet', 'gets', 'uncapped']
# filtered_tokens ['get', 'better', 'days,', 'could', 'something', 'lodged', 'belly']
# filtered_tokens ['love', 'atekinzz', 'much.', '&amp;&amp;', 'soo', 'miss', 'her..']
# filtered_tokens ['wanna', 'sneak', 'zoo', 'play', 'kitties']
# filtered_tokens ['@lolitariot', 'oh', 'hope', 'getting', 'sick', 'too!']
# filtered_tokens ['@alejandralei', 'dont', 'think', 'cause', 'cousins', 'birthday', 'party']
# filtered_tokens ['sweet', 'little', 'man', 'fell', 'asleep', 'waiting', 'daddy', 'big', 'brother', 'get', 'home!', 'poor', 'baby,', 'missed', 'much', 'today!']
# filtered_tokens ['angel', 'going', 'miss', 'athlete', 'weekend']
# filtered_tokens ['trust', 'hard']
# filtered_tokens ['watched', 'considering', 'today.', 'yaknow.', 'shawnna', 'tomomorrow;i', 'need', 'bestfriend']
# filtered_tokens ['grr', 'want', 'keep', 'reading', 'wont', 'anything', 'left', 'read']
# filtered_tokens ['atekinzz,', 'world', 'you??']
# filtered_tokens ['@rumlover', 'no!', 'u', 'supposed', 'date']
# ...
# filtered_tokens ['@joannafbeckett,', 'think', "there's", 'one', 'close', 'by.', 'last', 'time', 'checked,', 'closest', 'one', '70', 'miles', 'away!']
# filtered_tokens ['aaaaand', 'back', 'literature', 'review', 'least', 'friendly', 'cup', 'coffee', 'keep', 'company.']
# filtered_tokens ['worried', 'get', '$900', 'even', 'though', 'paid', 'buttload', 'tax', 'last', 'year', '!']
# filtered_tokens ['okay,', 'so..', 'still', 'school!!!!']
# filtered_tokens ['phoneless', '...now', 'sleep']
# filtered_tokens ['reeked', 'alcohol', 'dentist', 'morning', '+', 'drunk', 'put', 'tshirt,', 'realised', 'huge', 'stain.', 'dentist', 'looked', 'disgusted']
# filtered_tokens ['really', 'cold']
# filtered_tokens ['cant', 'sleep', 'wants', 'dream!!']
# filtered_tokens ["can't", 'sleep', 'hate', 'nights', 'try', 'go', 'bed', 'early', 'stay', 'awake', 'hours.', 'poo!']
# filtered_tokens ['@rootbeersoup', 'yeah.', 'bad', 'people', 'like', 'certain', 'burrito-eating', 'man', 'exist.']
# filtered_tokens ['@cronotriggers', "that's", 'sad.']
# filtered_tokens ['found', 'mum', 'adopted', 'auntie', 'twitter..', 'check', 'mum', 'tessm64', 'awesome', 'auntie', 'tania38']
# filtered_tokens ['cannot', 'sleep....wide', 'awake!!...and', 'gotta', 'go', 'work', 'later', 'too.', 'boy,', 'going', 'crappy', 'day.']
# filtered_tokens ['struggling', 'eam', 'law']
# filtered_tokens ["can't", 'sleep', 'like', 'http://twitpic.com/2y3ty']
# filtered_tokens ['bouts', 'start', '24.', 'poor', 'linny', 'keep', 'eyes', 'open.', 'tired', 'work', 'tomorrow', 'morning.', 'night', '@ilovefatsusan.']
# filtered_tokens ['4', 'year', 'old', '(18', 'year', 'old)', 'driving', 'around', 'twist...i', 'want', 'like']
# filtered_tokens ['well,', 'sucked.']
# filtered_tokens ['place', '3', 'days...any', 'help', 'get', 'packing/painting/cleaning', 'much', 'appreciated.', 'oh.', 'rip', 'wall']
# filtered_tokens ['opening', 'partially', 'frozen', 'beer=', 'beer', 'toaster,', 'oven', 'counter.', 'kitchen', 'smells', 'like', 'run', 'speakeasy']
# filtered_tokens ['@stewiebrittany', 'dont', 'even', 'know', 'ride']
# filtered_tokens ['@monasmith', 'sadly,', 'yes.', 'think', 'need', 'counciling']
# filtered_tokens ['making', 'ready', "school...don't", 'feel', 'like', 'going,', 'two', 'tests']
# filtered_tokens ['smugness', 'gone.', 'train', 'also', 'failed', 'turn', "i'm", 'heading', 'victoria', 'followed', 'unpleasant', 'tube', 'ride', 'city.']
# filtered_tokens ['anybody', 'know', 'ipod', 'went?']
# filtered_tokens ['aww', 'earthquake', 'italy', 'made', 'sad', 'saw', 'pics', 'news,', 'terrible.']
# filtered_tokens ['@lilibat', 'never', 'able', 'afford', 'get', 'out.', "i'd", 'much', 'rather', 'go', 'extraction', 'continue', 'deal', 'now.']
# filtered_tokens ['pet', 'care', 'people', 'try', 'run', 'others', 'business?', 'send', 'suspicious', 'e-mails', 'fishing', 'info?']
# filtered_tokens ['@kameelahwrites', '&lt;33', "codez....they've", 'mia', 'tho']
# filtered_tokens ['@reannaremick', 'doesnt', 'work', 'cell', 'go', 'sleep!', '=p']
# filtered_tokens ['going', 'nice', 'tomorrow', 'rain', 'comes', 'back.', 'nice', 'weather', 'birthday']
# filtered_tokens ['@taliasunset', 'rock', 'band', 'hard..on', 'expert!!!']
# filtered_tokens ['@beachbassbone:', 'roomie', 'home', 'day.', 'scratch', 'door.', 'comforter', 'goto', 'large', 'laundromat', 'machines.']
# filtered_tokens ['one', 'hardest', 'thing', 'schedule,', 'one', 'chat', 'end', 'day', 'usually']
# filtered_tokens ['killed', 'character', 'one', 'favorite', 'shows', "i'm", 'upset']
# filtered_tokens ['jealous', 'friends', 'got', 'see', 'new', 'star', 'trek', 'film', 'austin', 'tonight.']
# filtered_tokens ['listening', 'q!', 'got', 'really', 'bad', 'headache', 'drivin', 'lesson', 'ten', 'mins....', 'lucky', 'wana', 'sleeep!']
# filtered_tokens ['@steve_buscemi', 'shut', 'you...i', 'hungry!', 'britain,', 'home', 'boring', 'suckassy', 'breakfast', 'world!', 'miss', 'dennys!!']
# filtered_tokens ['good', 'morning', 'everybody!', 'pkoi', 'fais', 'pas', 'beau', 'bon', 'coffee', 'time!']
# filtered_tokens ['work']
# filtered_tokens ['essay', 'time....']
# filtered_tokens ['@chauncey78', 'hey', 'u', 'talk', 'mom..', 'r', 'home', 'yet?', 'hope', 'r', 'ok..', 'wish', 'coming', 'home', '4', 'easter..']
# filtered_tokens ['@endearingevania', 'sure', 'wish', 'could', 'go', 'guys', 'tmrw.', 'per', 'usual,', 'school', 'interferes.']
# filtered_tokens ['@widyatarina', 'say', 'what???', 'kal', "penn's", 'leaving', 'house?!', 'noooooo!!!', 'awww...', 'totally', 'missed', 'tonight']
# filtered_tokens ['no!', 'lost', 'loyal']
# filtered_tokens ['played', 'another', 'hand', 'bad', 'lost', 'half', 'stack']
# filtered_tokens ['6.20pm', '-', 'early', 'days', 'looooooong', 'night', 'work']
# filtered_tokens ['@yaykimo', 'sad', 'last', 'season.', 'wanna', 'see', 'spencer', 'calls', 'lauren!']
# filtered_tokens ['im', 'done', 'editing', '&quot;the', 'phipstape&quot;.', 'back', '2', 'crack', 'brew', 'see', 'got.............', 'trees', 'though']
# filtered_tokens ['@rj', 'know', 'half', 'means']
# filtered_tokens ['homework', 'homework', 'homework']
# filtered_tokens ['worked', 'heart', 'today,', 'doubling', 'weight', 'station.', 'result:', 'stiff', 'pulled', 'muscles...', 'ouch!']
# filtered_tokens ['@melamachinko', 'feel', 'bad', 'unfollowing.']
# filtered_tokens ['so...', 'tired...', 'god', 'hate', 'new', 'job,', 'two', 'days']
# filtered_tokens ['sad', 'kutner', 'killed', 'fav', 'show', 'house!']
# filtered_tokens ['happy', 'coach', 'stringer', '(hof', 'c/o', '2009!)...now', 'finish', 'term', 'paper']
# filtered_tokens ['feel', 'like', 'shit.', 'way', 'want', 'spend', "birthday's", 'eve']
# filtered_tokens ['far', '311', 'sites', 'put', 'together,', 'checking', 'updates', 'made......']
# filtered_tokens ['lot', 'mind.', 'needs', 'make', 'moneys.', 'ideas.', 'nowhere', 'hiring!']
# filtered_tokens ['@emiliexclarkex', 'miss']
# filtered_tokens ['@stephenkruiser', "i'm", 'sorry', 'hear', 'dog']
# filtered_tokens ['much', 'internet.', 'plagues']
# filtered_tokens ['miss', 'ex', 'soo', 'much']
# filtered_tokens ['sodding', 'm25', 'http://twitpic.com/2y3y0']
# filtered_tokens ['oh', 'thought', 'pirate', 'bay', 'trial', 'verdict', 'today', ':-s', 'apparently', '10', 'days']
# filtered_tokens ['@featherinair', 'call', 'back.']
# filtered_tokens ['study', 'hall', 'now,', 'log', 'immediately.', 'http://plurk.com/p/mzxbg']
# filtered_tokens ['tired', 'im', 'crying', 'reason', 'all.', 'im', 'try', 'get', 'hour', 'half', 'tonight.', 'half', 'got', 'last', 'night.']
# filtered_tokens ['totally', 'like...', 'four', 'girl', 'options,', 'none', 'seem', 'viable']
# filtered_tokens ['far', '311', 'veiws', 'sites', 'put', 'together,', 'checking', 'updates', 'made......']
# filtered_tokens ['listening', "bjork's", 'full', 'love...', 'crying']
# filtered_tokens ['omg', 'hills!', 'love', 'money2,', 'aww', 'think', 'becky', 'buckwild', 'goes']
# filtered_tokens ['craving', 'tantan', 'nabe', 'http://plurk.com/p/mzxcs']
# filtered_tokens ["c'mon", 'sean', 'man']
# filtered_tokens ['watching', '&quot;a', 'league', 'own&quot;...makes', 'miss', 'mint', 'chocolate', 'ice', 'cream', 'cones', 'grand', 'fuck.']
# filtered_tokens ['lost', 'phone', 'where.maybe', 'grass,', 'long,', 'hope', 'rain']
# filtered_tokens ['@tomatosalsa', 'hope', 'referring', 'say', 'hello', 'new', 'stalker', 'lol']
# filtered_tokens ['@brettyboo', 'u', 'sleeping?!', 'ur', 'gonna', 'night', 'ur', 'bike', 'ride?']
# filtered_tokens ['@slessard', 'but,', 'but,', '.', '.', 'wanna', 'listen', 'masters', 'too!']
# filtered_tokens ['@sephystryx', "i've", 'looking', 'good', 'stuff', 'write,', 'also', 'loads', 'uni', 'work']
# filtered_tokens ['feel', 'unloved.', 'dropped', '2', 'tweeters']
# filtered_tokens ['london', 'day', 'thursday,', 'gonna', 'raining,', 'oh', 'fab', 'see', 'much', 'london', 'eye!', 'still', 'robbie', 'care', 'bless']
# filtered_tokens ['completely', 'wiped', 'reloaded', '8900....', 'lost', 'bbm', 'contacts', 'going', 'bed', 'sad.']
# filtered_tokens ['@mykele', 'sayyyy', 'whaaaa?', 'invited...']
# filtered_tokens ['sleep', 'bad', 'considering', 'workshop', 'starting', 'today.', 'beginnings', 'sore', 'throat', 'though']
# filtered_tokens ['@astewart87', 'oh', 'gosh', 'made', 'emotional', 'haha', 'idk', 'why!!!', 'dont', 'want', 'get', 'old']
# filtered_tokens ["we're", 'going', 'post', 'stories', 'manually', 'due', 'twitterfeed', 'problem.', "that's", "we've", 'quiet', 'lately', '....']
# filtered_tokens ['like', 'lukewarm', 'showers']
# filtered_tokens ['@linuxfoundation', '-', 'contact', 'need', '1099', 'freelance', 'work', 'linux.com', 'throughout', '2008?', 'never', 'got', 'one.']
# filtered_tokens ['@skylineking722', 'connor,', 'me,', 'febi', 'really', 'really', 'mad', 'me??']
# filtered_tokens ['need', 'help?!', 'want', 'buy', 'macbook', 'pro,', 'still', 'inlove', 'old', 'powerbook!']
# filtered_tokens ['@michaeltao', 'man', 'america', '..', 'borez', 'anyway', 'lol', 'realized', 'sent', 'msgs', 'here.', 'idea.', 'flash']
# filtered_tokens ['@hellivina', '@ihopness', "g'knight", 'lovely', 'ladies.', "i'm", 'sleepy']
# filtered_tokens ['anybody', 'know', 'get', 'electrolytes', 'back', 'order?', 'vitamin', 'work?', 'feel', 'sick.']
# filtered_tokens ['@sudam08', 'yes,', 'someone', 'reading', 'posts', 'properly']
# filtered_tokens ['almost', 'italian', 'homework!', 'weeeeee....', 'understood', 'doing.']
# filtered_tokens ['turned', 'lights', 'on?', 'time', 'get', 'ip']
# filtered_tokens ['@therealnph', 'twitter', 'hates', 'us', 'then.']
# filtered_tokens ['hate', 'fact', "i'm", 'genuinely', 'excited', 'last', 'tweet']
# filtered_tokens ['@celesteclara', "can't", 'sleep', 'either']
# filtered_tokens ['@theblondetheory', 'italy', 'earthquake,', 'sad', 'news', 'day.']
# filtered_tokens ['@champagnemanoir', 'rain', 'today', '.', 'garden', 'really', 'needs', 'quite', 'bad.']
# filtered_tokens ['yawn', 'yawn', 'yawn!!', '10', 'minutes', 'bed']
# filtered_tokens ['@majesticflame', 'ouch', '-', 'sounds', 'sucky']
# filtered_tokens ['@bengottlieb', 'great', 'idea', 'itunes', 'promo', 'codes', '-', 'work', 'uk', 'itunes', 'store', 'though']
# filtered_tokens ['@mattycus', '*cry*']
# filtered_tokens ['@rumlover', 'empty', 'rum', 'barrel', 'sad', 'rum', 'barrel.', '*shakes', 'head*', 'horror,', 'horror.']
# filtered_tokens ['sleepless', 'night']
# filtered_tokens ['@billybush', 'admitted', 'fake']
# filtered_tokens ['@batmannn', 'love', 'chutney......']
# filtered_tokens ['got', 'highly', 'bored', 'today', 'scanning', '24', 'pages', 'daddy.', 'it!']
# filtered_tokens ['@misterphipps', 'cooked', 'risotto', 'without', 'me!!???']
# filtered_tokens ['keeeerrrrriiiiii!!!!', 'really', 'nothing', 'better', 'post', 'thing', '224am.....wonderfullll.', 'says', 'alot.']
# filtered_tokens ['yay', 'baseball', 'season!', 'boo', 'yankees', 'losing', 'first', 'game']
# filtered_tokens ['lost', 'sucks', '...', 'work', 'today']
# filtered_tokens ['omg', 'exams', 'killed', 'could', 'know', 'difference', 'haif', 'circle', 'hemisphere', '&lt;/3', '&gt;']
# filtered_tokens ['bed...', 'suddenly', 'feel', 'wish', 'w/me...', 'goodnight', 'twitterfam']
# filtered_tokens ['@rachelcmrn', 'like', 'goodnights']
# filtered_tokens ['greaaat', 'lappy', 'turn', 'wtffffff']
# filtered_tokens ['@m4rkm', 'stuck', 'traffic', 'then?', 'journey', 'traffic', 'free', 'morning,', 'help.']
# filtered_tokens ['lookin', 'like', 'all-nighter.', 'hate']
# filtered_tokens ['@vernonhamilton', 'stranger']
# filtered_tokens ['debbugging', 'old', 'vb6', 'code,', 'day', 'could', 'started', 'better', '.', '.', '.']
# filtered_tokens ['@toddlington', 'quarter', 'percent', 'babe', 'darn']
# filtered_tokens ['coming', 'cold', 'bad', 'allergies.', 'either', 'way,', "i'm", 'miserable!']
# filtered_tokens ["can't", 'believe', 'cutner', 'dead', 'house!', 'sad', 'day.', 'santa', 'rosa,', 'ca', 'http://loopt.us/orpl3a']
# filtered_tokens ['damnit', 'really', 'digging', 'season', 'reaper', 'http://www.tv.com/story/13720.html?ref_story_id=13720&amp;ref_type=1101&amp;ref_name=story']
# filtered_tokens ['gah,', 'comcast', 'doubled', 'cable/internet', 'bill', 'w/out', 'telling', 'us,', 'quitting.', 'anyone', 'suggest', 'affordable', 'company', 'bay', 'area?']
# filtered_tokens ['another', 'early', 'morn', 'duchess,', 'although', 'managed', 'cross', 'legs', 'time']
# filtered_tokens ['@alexbigman', 'left', 'without', 'saying', 'hi!']
# filtered_tokens ['l', 'want,', "can't", 'sleep']
# filtered_tokens ['@tracydowds', 'xbox', 'shows', 'three', 'red', 'lights,', 'means', 'dead', 'needs', 'fixed', 'month', 'microsoft', 'hq.']
# filtered_tokens ['king', 'sized', 'bed', 'nice', 'sad', 'lonely', 'hubby,', 'puppy,', 'kitty', 'whole', 'conferenceing', 'thing.']
# filtered_tokens ['im', 'boredd.', 'gah', 'wish', 'could', 'sleep', 'get', 'ive', 'toooo', 'muchh', 'cooooffffeeeeeeeee', 'bahaha']
# filtered_tokens ['@whyinthehell', 'may', 'butt', 'again.', "i'm", 'done', 'nosey.', 'sorry', 'conversation', 'interesting!']
# filtered_tokens ['@smokey_robinson', 'fell', 'list...did', 'offend', 'you?']
# filtered_tokens ['18', 'weeks', 'till', 'sisters', 'home..', 'missed', 'call,', 'again!', 'worst', 'feeling', 'world.']
# filtered_tokens ['gonna', 'try', 'get', 'sleep', 'hotel', 'room']
# filtered_tokens ['@chimpytwit', 'brilliant', 'idea.', 'bring', 'much', 'think', 'spend', '&amp;', "i'll", 'swap', 'you.', 'bring', 'brolly']
# filtered_tokens ['@simonekali', 'get', 'autograph', 'shout', 'out!', 'record', 'though.', 'computer', 'dead', "can't", 'listen.']
# filtered_tokens ['rt', '@kimkardashian', 'khloe', 'got', 'fired', 'apprentice']
# filtered_tokens ['biology', 'class.', 'lip', 'hurts']
# filtered_tokens ['sorry', 'next', 'tweet...']
# filtered_tokens ['grr', 'go', 'school', 'today']
# filtered_tokens ['@jennlopez', 'get', 'hd', 'tivo', 'got', 'set', 'tonight', 'order', 'get', 'channels', '40', '-', '59.']
# filtered_tokens ['@mouthsex', 'asked', 'everyone', 'yesterday', 'single', 'tweet', 'back']
# filtered_tokens ['@adame', 'ruddy', 'money!!', 'like', 'it!!', 'still', 'waiting', 'here....', 'oh', 'surprise...', 'state', 'too??', 'hmmm.......', 'seriously!!']
# filtered_tokens ['@kal_penn', 'sad', 'kutner', 'favorite', 'new', 'team!!']
# filtered_tokens ['@marcusmims', 'wow', 'get', '&quot;hello&quot;', 'u', 'suck']
# filtered_tokens ['bedtime,', 'school', 'tomorrow,', 'still', 'books', 'broke', 'suckssss']
# filtered_tokens ['seating', 'helping', 'baby', 'papers...well', 'forcing', 'seat', 'im', 'sleepy']
# filtered_tokens ['synching', 'contacts', 'old', 'mobile', 'iphone.', 'import', 'work', 'well']
# filtered_tokens ["can't", 'concentrate']
# filtered_tokens ["i've", 'spent', '1', 'hour', 'enter', 'bureaucratic', 'nonsense', 'march.', 'waste', 'time']
# filtered_tokens ['nw', 'confused', 'ever!']
# filtered_tokens ['feeling', 'well', 'again.', 'stupid', 'migraine', 'making', 'tummy', 'upset.', 'whole', 'body', 'aches,', 'shoot', 'now.']
# filtered_tokens ['reading', 'buyology', 'bedtime...', 'great', 'premise', 'turning', '&quot;ok&quot;', 'book', '-', 'lots', 'info', 'already', 'knew']
# filtered_tokens ['home!', 'really', 'wana', 'sleep,', 'due', 'wasting', 'free', 'line', 'town', 'assignment', 'finish']
# filtered_tokens ['@hellobebe', 'also', 'send', 'updates', 'plurk', 'upload', 'photos', 'twitter!', 'didnt', 'see', 'updates', 'plurk?', 'zero?']
# filtered_tokens ['omg...', '&quot;the', 'reader&quot;', 'making']
# filtered_tokens ['@cloudpimps', "d'oh!", 'least', 'getting', 'decent', 'exchange', 'rate', 'moment,', 'sterling', 'still', 'getting', 'flogged']
# filtered_tokens ['tried', 'download', 'tweetdeck', 'wont', 'download']
# filtered_tokens ["there's", 'inch', 'snow', 'ground', '(and', 'counting).', "i'm", 'worried', 'poor', 'flowers']
# filtered_tokens ['@dweeman', 'happy', 'camper?']
# filtered_tokens ['@dkoenigs', 'thanks', 'man.', "i'm", 'grateful.', 'feel', 'unworthy', 'attention,', 'though,', "i'm", 'myself...']
# filtered_tokens ['@t_wolfe', 'miss', 'u', 'too.', "i'm", 'totally', 'comin', 'back', 'tho!', 'lastnight', 'sooooooo', 'much', 'fun!']
# filtered_tokens ['@sniffinglue', 'ohhh.', 'love', 'it.', 'ps', "i'm", 'sad', 'get', 'hang']
# filtered_tokens ['somehow', 'still', 'end', 'place']
# filtered_tokens ['@kisluvkis', 'oh', 'sad,', 'poor', 'boy.']

# %% [markdown]
# The removal of stopwords has reduced the texts. However after analysing the filtered words, it is seen that symbols are still considered, tokens. As such, the **removal of symbols** would be added to stop_words. Due to the tokenization making ending words with symbols (eg: "goodbye!") a single token, the removal will only be on tokens with no characters (eg: "!")

# %%
stop_words = set(stopwords.words("english"))
symbols = set(string.punctuation)

# Checking removal works on a test text
test_tweet2 = ["modified test that StopwOrd removal works. It will remove @testtry"]

def filter_text2(tweets):
    for tweet in tweets:
        tokens = tweet.lower().split()
        
        filtered_tokens = [token for token in tokens if not (
            # Removing each token if part of symbols
            all(char in symbols for char in token)
            # Removing each token if part of stop_words
            or token in stop_words
        )]
        
        print("filtered_tokens", filtered_tokens)
        
filter_text2(test_tweet2)
# Out:
# filtered_tokens ['modified', 'test', 'stopword', 'removal', 'works.', 'remove', '@testtry']

# %%
# After improvement of stopwords
tweets = tweets_df["tweet"].tolist()
filter_text2(tweets)
# Out:
# filtered_tokens ['@switchfoot', 'http://twitpic.com/2y1zl', 'awww,', "that's", 'bummer.', 'shoulda', 'got', 'david', 'carr', 'third', 'day', 'it.', ';d']
# filtered_tokens ['upset', "can't", 'update', 'facebook', 'texting', 'it...', 'might', 'cry', 'result', 'school', 'today', 'also.', 'blah!']
# filtered_tokens ['@kenichan', 'dived', 'many', 'times', 'ball.', 'managed', 'save', '50%', 'rest', 'go', 'bounds']
# filtered_tokens ['whole', 'body', 'feels', 'itchy', 'like', 'fire']
# filtered_tokens ['@nationwideclass', 'no,', 'behaving', 'all.', "i'm", 'mad.', 'here?', "can't", 'see', 'there.']
# filtered_tokens ['@kwesidei', 'whole', 'crew']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['@loltrish', 'hey', 'long', 'time', 'see!', 'yes..', 'rains', 'bit', ',only', 'bit', 'lol', "i'm", 'fine', 'thanks', "how's"]
# filtered_tokens ['@tatiana_k', 'nope']
# filtered_tokens ['@twittera', 'que', 'muera']
# filtered_tokens ['spring', 'break', 'plain', 'city...', 'snowing']
# filtered_tokens ['re-pierced', 'ears']
# filtered_tokens ['@caregiving', 'bear', 'watch', 'it.', 'thought', 'ua', 'loss', 'embarrassing']
# filtered_tokens ['@octolinz16', 'counts,', 'idk', 'either.', 'never', 'talk', 'anymore']
# filtered_tokens ['@smarrison', "would've", 'first,', 'gun.', 'really', 'though,', 'zac', "snyder's", 'doucheclown.']
# filtered_tokens ['@iamjazzyfizzle', 'wish', 'got', 'watch', 'you!!', 'miss', '@iamlilnicki', 'premiere?!']
# filtered_tokens ["hollis'", 'death', 'scene', 'hurt', 'severely', 'watch', 'film', 'wry', 'directors', 'cut', 'now?']
# filtered_tokens ['file', 'taxes']
# filtered_tokens ['@lettya', 'ahh', 'ive', 'always', 'wanted', 'see', 'rent', 'love', 'soundtrack!!']
# filtered_tokens ['@fakerpattypattz', 'oh', 'dear.', 'drinking', 'forgotten', 'table', 'drinks?']
# filtered_tokens ['@alydesigns', 'day', 'get', 'much', 'done']
# filtered_tokens ['one', 'friend', 'called', 'me,', 'asked', 'meet', 'mid', 'valley', 'today...but', "i've", 'time', '*sigh*']
# filtered_tokens ['@angry_barista', 'baked', 'cake', 'ated']
# filtered_tokens ['week', 'going', 'hoped']
# filtered_tokens ['blagh', 'class', '8', 'tomorrow']
# filtered_tokens ['hate', 'call', 'wake', 'people']
# filtered_tokens ['going', 'cry', 'sleep', 'watching', 'marley', 'me.']
# filtered_tokens ['im', 'sad', 'miss.lilly']
# filtered_tokens ['ooooh....', 'lol', 'leslie....', 'ok', 'leslie', 'get', 'mad']
# filtered_tokens ['meh...', 'almost', 'lover', 'exception...', 'track', 'gets', 'depressed', 'every', 'time.']
# filtered_tokens ['some1', 'hacked', 'account', 'aim', 'make', 'new', 'one']
# filtered_tokens ['@alielayus', 'want', 'go', 'promote', 'gear', 'groove', 'unfornately', 'ride', 'may', 'b', 'going', 'one', 'anaheim', 'may', 'though']
# filtered_tokens ['thought', 'sleeping', 'option', 'tomorrow', 'realizing', 'not.', 'evaluations', 'morning', 'work', 'afternoon!']
# filtered_tokens ['@julieebaby', 'awe', 'love', 'too!!!!', '1', 'miss']
# filtered_tokens ['@humpninja', 'cry', 'asian', 'eyes', 'sleep', 'night']
# filtered_tokens ['ok', "i'm", 'sick', 'spent', 'hour', 'sitting', 'shower', 'cause', 'sick', 'stand', 'held', 'back', 'puke', 'like', 'champ.', 'bed']
# filtered_tokens ['@cocomix04', 'ill', 'tell', 'ya', 'story', 'later', 'good', 'day', 'ill', 'workin', 'like', 'three', 'hours...']
# filtered_tokens ['@missxu', 'sorry!', 'bed', 'time', 'came', '(gmt+1)', 'http://is.gd/fnge']
# filtered_tokens ['@fleurylis', 'either.', 'depressing.', 'think', 'even', 'want', 'know', 'kids', 'suitcases.']
# filtered_tokens ['bed.', 'class', '8-12.', 'work', '12-3.', 'gym', '3-5', '6.', 'class', '6-10.', 'another', 'day', "that's", 'gonna', 'fly', 'by.', 'miss', 'girlfriend']
# filtered_tokens ['really', 'feel', 'like', 'getting', 'today...', 'got', 'study', 'tomorrows', 'practical', 'exam...']
# filtered_tokens ["he's", 'reason', 'teardrops', 'guitar', 'one', 'enough', 'break', 'heart']
# filtered_tokens ['sad,', 'sad,', 'sad.', 'know', 'hate', 'feeling', 'wanna', 'sleep', 'still', "can't!"]
# filtered_tokens ['@jonathanrknight', 'awww', 'soo', 'wish', 'see', 'finally', 'comfortable!', 'im', 'sad', 'missed']
# filtered_tokens ['falling', 'asleep.', 'heard', 'tracy', "girl's", 'body', 'found.', 'sad', 'heart', 'breaks', 'family.']
# filtered_tokens ['@viennah', 'yay!', "i'm", 'happy', 'job!', 'also', 'means', 'less', 'time', 'you...']
# filtered_tokens ['checked', 'user', 'timeline', 'blackberry,', 'looks', 'like', 'twanking', 'still', 'happening', 'ppl', 'still', 'probs', 'w/', 'bgs', 'uids?']
# filtered_tokens ['oh', 'man...was', 'ironing', "@jeancjumbe's", 'fave', 'top', 'wear', 'meeting.', 'burnt']
# filtered_tokens ['strangely', 'sad', 'lilo', 'samro', 'breaking', 'up.']
# filtered_tokens ['@tea', 'oh!', "i'm", 'sorry', 'think', 'retweeting.']
# filtered_tokens ['broadband', 'plan', "'a", 'massive', 'broken', "promise'", 'http://tinyurl.com/dcuc33', 'via', 'www.diigo.com/~tautao', 'still', 'waiting', 'broadband']
# filtered_tokens ['@localtweeps', 'wow,', 'tons', 'replies', 'you,', 'may', 'unfollow', 'see', "friends'", 'tweets,', 'scrolling', 'feed', 'lot.']
# filtered_tokens ['duck', 'chicken', 'taking', 'wayyy', 'long', 'hatch']
# filtered_tokens ['put', 'vacation', 'photos', 'online', 'yrs', 'ago.', 'pc', 'crashed,', 'forget', 'name', 'site.']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['@andywana', 'sure', 'are,', 'pos!', 'much', 'want', 'to,', 'dont', 'think', 'trade', 'away', 'company', 'assets', 'sorry', 'andy!']
# filtered_tokens ['@oanhlove', 'hate', 'happens...']
# filtered_tokens ['sad', 'feeling', 'dallas', 'going', 'show', 'gotta', 'say', 'though,', 'think', 'shows', 'would', 'use', 'music', 'game.', 'mmm']
# filtered_tokens ['ugh....92', 'degrees', 'tomorrow']
# filtered_tokens ['u', 'move', 'to?', 'thought', 'u', 'already', 'sd.', 'hmmm.', 'random', 'u', 'found', 'me.', 'glad', 'hear', 'yer', 'well.']
# filtered_tokens ['@batmanyng', 'miss', 'ps3,', 'commission', 'wutcha', 'playing?', 'copped', "'blood", "sand'?"]
# filtered_tokens ['leaving', 'parking', 'lot', 'work!']
# filtered_tokens ['life', 'cool.', 'me.']
# filtered_tokens ['sadly', 'though,', "i've", 'never', 'gotten', 'experience', 'post', 'coitus', 'cigarette', 'before,', 'never', 'will.']
# filtered_tokens ['nice', 'day.', 'bad', 'rain', 'comes', 'tomorrow', '5am']
# filtered_tokens ['@starrbby', 'bad', 'around', 'lost', 'job', "can't", 'even', 'pay', 'phone', 'bill', 'lmao', 'aw', 'shucks']
# filtered_tokens ['damm', 'back', 'school', 'tomorrow']
# filtered_tokens ['mo', 'jobs,', 'money.', 'hell', 'min', 'wage', '4', "f'n", 'clams', 'hour?']
# filtered_tokens ['@katortiz', 'forever...', 'see', 'soon!']
# filtered_tokens ['@lt_algonquin', 'agreed,', 'saw', 'failwhale', 'allllll', 'day', 'today.']
# filtered_tokens ['@jdarter', 'oh!', 'haha...', 'dude', 'dont', 'really', 'look', 'em', 'unless', 'someone', 'says', 'hey', 'added', 'you.', 'sorry', "i'm", 'terrible', 'that.', 'need', 'pop', 'up!']
# filtered_tokens ['@ninjen', "i'm", 'sure', 'right...', 'need', 'start', 'working', 'nikster...', 'jared', 'least!']
# filtered_tokens ['really', 'hate', 'people', 'diss', 'bands!', 'trace', 'clearly', 'ugly!']
# filtered_tokens ['gym', 'attire', 'today', 'was:', 'puma', 'singlet,', 'adidas', 'shorts.......and', 'black', 'business', 'socks', 'leather', 'shoes', 'lucky', 'run', 'cute', 'girls.']
# filtered_tokens ['show', 'location?!', 'http://twitpic.com/2y2es']
# filtered_tokens ['picnic', 'phone', 'smells', 'like', 'citrus.']
# filtered_tokens ['@ashleyac', 'donkey', 'sensitive', 'comments.', 'nevertheless,', "he'd", '(and', "me'd)", 'glad', 'see', 'mug', 'asap.', 'charger', 'still', 'awol.']
# filtered_tokens ['new', 'csi', 'tonight.', 'fml']
# filtered_tokens ['think', 'arms', 'sore', 'tennis']
# filtered_tokens ['wonders', 'someone', 'u', 'like', 'much', 'make', 'unhappy', 'split', 'seccond', 'depressed']
# filtered_tokens ['sleep', 'soon...', 'hate', 'saying', 'bye', 'see', 'tomorrow', 'night.']
# filtered_tokens ['@statravelau', 'got', 'ur', 'newsletter,', 'fares', 'really', 'unbelievable,', 'shame', 'already', 'booked', 'paid', 'mine']
# filtered_tokens ["missin'", 'boo']
# filtered_tokens ['@markhardy1974', '#itm']
# filtered_tokens ['damn...', 'chalk!', 'chalkboard', 'useless']
# filtered_tokens ['blast', 'getty', 'villa,', 'hates', 'sore', 'throat', 'day.', 'getting', 'worse']
# filtered_tokens ['@msdrama', 'hey', 'missed', 'ya', 'meeting', 'sup', 'mama']
# filtered_tokens ['tummy', 'hurts.', 'wonder', 'hypnosis', 'anything', 'it?', 'so,', 'working,', 'get', 'it,', 'stop', 'smoking!!!']
# filtered_tokens ['always', 'fat', 'ones?!']
# filtered_tokens ['@januarycrimson', 'sorry,', 'babe!!', 'fam', 'annoys', 'too.', 'thankfully,', "they're", 'asleep', 'right', 'now.', 'muahaha.', '*evil', 'laugh*']
# filtered_tokens ['@hollywoodheat', 'paid', 'attention', 'covered', 'photoshop', 'webpage', 'design', 'class', 'undergrad']
# filtered_tokens ['wednesday', 'b-day!', 'know', '2', 'do!!']
# filtered_tokens ['poor', 'cameron', '(the', 'hills)']
# filtered_tokens ['pray', 'please,', 'ex', 'threatening', 'start', 'sh**', 'my/our', 'babies', '1st', 'birthday', 'party.', 'jerk.', 'still', 'headache']
# filtered_tokens ['@makeherfamous', 'hmm', 'u', 'really', 'enjoy', 'problems', 'constants', 'u', 'think', 'things', 'find', 'someone', 'ulike']
# filtered_tokens ['strider', 'sick', 'little', 'puppy', 'http://apps.facebook.com/dogbook/profile/view/5248435']
# filtered_tokens ['rylee,grace...wana', 'go', "steve's", 'party', 'not??', 'sadly', 'since', 'easter', 'wnt', 'b', 'able', '2', 'much', 'ohh', 'well.....']
# filtered_tokens ['hey,', 'actually', 'one', 'bracket', 'pools!', 'bad', 'one', 'money']
# filtered_tokens ['@stark', 'follow', 'me,', 'either', 'work', 'you!']
# filtered_tokens ['bad', 'nite', 'favorite', 'teams:', 'astros', 'spartans', 'lose.', 'nite', 't.w.', 'good.']
# filtered_tokens ['body', 'missing', 'northern', 'calif.', 'girl', 'found:', 'police', 'found', 'remains', 'missing', 'northern', 'california', 'girl', 'http://tr.im/imji']
# filtered_tokens ['@mangaaa', 'hope', 'increase', 'capacity', 'fast,', 'yesterday', 'pain.', 'got', 'fail', 'whale', '+15', 'times', '2', 'hours....']
# filtered_tokens ['behind', 'classes', 'work']
# filtered_tokens ['watching', '&quot;house&quot;']
# filtered_tokens ['@kpreyes', 'remember', 'bum', 'leg?', 'strikes', 'back', 'time', 'serious']
# filtered_tokens ['@paradisej', 'cool,', 'will.', 'kinds', 'complaints', 'laptop', 'online', 'overheating,', 'recalls']
# filtered_tokens ['emily', 'glad', 'mommy', 'done', 'training', 'new', 'job.', 'misses', 'her.', 'http://apps.facebook.com/dogbook/profile/view/6176014']
# filtered_tokens ['would', 'rather', 'first', 'party', 'send', 'bad', 'messages', '3rd', 'party', 'send', 'mixed', 'ones', 'sophmore', 'year', 'again?']
# filtered_tokens ['@henkuyinepu', 'overrated']
# filtered_tokens ['@marykatherine_q', 'know!', 'heard', 'afternoon', 'wondered', 'thing.', 'moscow', 'behind', 'times']
# filtered_tokens ['laying', 'bed', 'voice..']
# filtered_tokens ["i'm", 'sooo', 'sad!!!', 'killed', 'kutner', 'house', 'whyyyyyyyy']
# filtered_tokens ['@jacobsummers', 'sorry', 'tell', 'mea', 'culpa', 'really', 'sorry.']
# filtered_tokens ['@alliana07', 'make', 'sense', 'me,', 'suicide', 'thing.', 'refuse', 'believe', 'actually', 'happened.']
# filtered_tokens ['@salancaster', 'hope', 'ok.']
# filtered_tokens ['@mercedesashley', 'damn!', 'grind', 'inspirational', 'saddening', 'time.', 'want', 'stop', 'cuz', 'like', 'u', 'do!', 'much', 'love']
# filtered_tokens ['@hibanick', 'yeah', 'aw', 'know', 'wudnt', 'stand', 'chance']
# filtered_tokens ['ugh.', 'cant', 'sleep.', '1:30am.']
# filtered_tokens ['hanging', 'crooners.', 'wanna', 'sing.', "can't.", 'sucks.']
# filtered_tokens ['@erre_sc', 'aaw', 'miss', 'ya', 'too..', 'im', 'leaving', 'bh', 'tomorrow', '&quot;morning&quot;', 'think..', 'aww', 'wanna', 'go', 'beach', 'w', 'u', 'girls!!']
# filtered_tokens ['pissed', "there's", "asba's", 'radio', 'station.']
# filtered_tokens ['wednesday', 'b-day', 'n', 'know', '2', 'do!']
# filtered_tokens ['know', 'life', 'flipped', 'upside', 'thought', 'head', 'ramen', 'sounds', 'good.']
# filtered_tokens ['pain.', 'back', 'sides', 'hurt.', 'mention', 'crying', 'made', 'fail.']
# filtered_tokens ['late', 'night', 'snack,', 'glass', 'oj', 'b/c', "i'm", '&quot;down', 'sickness&quot;,', 'back', 'sleep...ugh', 'hate', 'getting', 'sick...']
# filtered_tokens ['@allyheman', 'but..', 'but..', 'but..', "i'm", 'big', 'fan', 'camilla', 'belle']
# filtered_tokens ['@grum', 'wah', "can't", 'see', 'clip,', 'must', 'el-stupido', 'work', 'filters.', "can't", 'wait', "'till", 'get', "'puter.", 'something', 'else', '2', 'blame', 'ex', '4.', 'broke', 'mine']
# filtered_tokens ['week', 'seems', 'get', 'longer', 'longer', 'terms', 'much', 'need', 'do..', 'much', "i'm", 'actually', 'going', 'get', 'done']
# filtered_tokens ["i'm", 'cold']
# filtered_tokens ['@thecoolestout', 'ehhh', "don't.", "weather's", 'gonna', 'take', 'turn', 'ugly', 'tomorrow']
# filtered_tokens ['@chelserlynn', 'haha', 'cooooold', 'd!', 'still', 'go', 'show.', 'incredible', 'stuff']
# filtered_tokens ['hoping', 'tummy', 'rumbles', 'go', 'away', 'soon']
# filtered_tokens ['@knights_', 'no,', 'notice.', 'told', "i'd", 'working', 'tomorrow,', 'called', 'agency', 'follow', 'said', 'over.']
# filtered_tokens ['almost', 'bedtime']
# filtered_tokens ["i'm", 'missing', 'babe..', 'long', 'alive', "i'm", 'happy..', 'yawwwnn..', "i'm", 'tired', 'love', 'imma', 'try', 'sleep', 'hopefully', 'headstart']
# filtered_tokens ['agh...snow!!!']
# filtered_tokens ['miss', 'kenny', 'powers']
# filtered_tokens ['@bridgetsbeaches', 'thank', 'letting', 'people', 'know,', "i'm", 'sad', 'direct', 'message', 'got', 'actually', 'bridget']
# filtered_tokens ['...and,', 'india', 'missed', '100th', 'test', 'victory', 'n', '10th', 'consecutive', 'win', 'without', 'loss.']
# filtered_tokens ['@jonathanrknight', 'guess', "that's", 'then.']
# filtered_tokens ['sadly', 'going', 'bed.']
# filtered_tokens ['@ozesteph1992', 'shame', 'hear', 'stephan']
# filtered_tokens ['@mrsaintnick', 'hey!', "i'm", 'leavin', 'morning...']
# filtered_tokens ['intending', 'finish', 'editing', '536-page', 'novel', 'manuscript', 'tonight,', 'probably', 'happen.', '12', 'pages', 'left']
# filtered_tokens ['laid', 'around', 'much', 'today...', 'head', 'hurts']
# filtered_tokens ['@twista202', 'still', 'read', '9th&amp;10th', 'princess', 'diaries', 'saving', 'francesca', 'made', 'cry', 'end.', 'hmm', 'easy', 'books.']
# filtered_tokens ['nokia', '1110', 'died..']
# filtered_tokens ['mom', 'might', 'breast', 'cancer', 'find', 'anything', 'for.', 'like', 'week', "i'm", 'worried!']
# filtered_tokens ['going', 'sleep.', 'hoping', 'tomorrow', 'better', 'day.']
# filtered_tokens ['@rumblepurr', 'lol..', 'wish', 'understood', 'daylight', 'savings', 'ended', 'though', 'breakfast', 'hour', 'later', 'keep', 'waking', 'kids']
# filtered_tokens ['@onemoreproject', 'lame']
# filtered_tokens ['understand...', 'really']
# filtered_tokens ['heroes', 'season...']
# filtered_tokens ['living', 'downtown', 'sure', 'much', 'fun.']
# filtered_tokens ['@jonathanchard', 'calorie', 'wise', 'wish', 'junk', 'food', 'calorie', 'free!', 'ate', 'thing', 'sour', 'skittles', 'big', 'ass', 'cherry', 'coke!']
# filtered_tokens ['man', 'work', 'hard']
# filtered_tokens ['getting', 'sick', 'time', 'hot', 'tea,', 'studying,', 'sleeeep']
# filtered_tokens ['getting', 'eyebrows', 'waxed.', 'pain']
# filtered_tokens ['phantasy', 'star', 'yesterday', 'going', 'work...']
# filtered_tokens ['oh', 'got', 'macheist', '3.0', 'apps', 'sweet.', 'get', 'espresso', 'serial', 'though', 'although', 'said', 'sent', 'oh', 'well']
# filtered_tokens ['picked', 'mich', 'st', 'win', 'get', 'go.', 'feeling', 'pretty', 'good', 'pick', 'way', 'until......tonight.', "a's", 'lost']
# filtered_tokens ['alone', 'downstairs...working']
# filtered_tokens ['feel', 'bad']
# filtered_tokens ['@ryanseacrest', 'me,', 'hates', 'anoop.', 'mean', 'seriously,', 'kinda', 'mean', 'him.']
# filtered_tokens ['@pinkserendipity', 'yes', 'sprint', '4g', 'baltimore', 'chicago', 'far']
# filtered_tokens ["i'm", 'stuck', 'awake', 'middle', 'night', 'second', 'day', 'row.', 'felt', 'terrible', 'yesterday.']
# filtered_tokens ['thanks', 'bursting', 'bubble']
# filtered_tokens ['going', 'school', 'soon...', "can't", 'find', 'anything', 'wear!!', 'gosh', 'hard']
# filtered_tokens ['@marieclr', 'serious', 'lol']
# filtered_tokens ['@naughtyhaughty', 'page', 'sooooo', 'long!!!', 'got', 'deleted', 'sad', 'day', 'history']
# filtered_tokens ['crazy', 'wind', 'today', 'birding', 'http://ff.im/1xtti']
# filtered_tokens ['currently', 'work..']
# filtered_tokens ['grrr..', 'ipods', 'acting', 'weird', 'too!', 'jai', 'ho', 'thinking', 'playing', 'full', 'songs..', 'ughh.']
# filtered_tokens ['@penndbad', 'send', 'dvd', 'cos', 'missed', 'heaps', 'happy', 'that!']
# filtered_tokens ['see', 'big', 'deal', 'website']
# filtered_tokens ['@machineplay', "i'm", 'sorry', 'go', 'this.', 'again.', '#therapyfail']
# filtered_tokens ['@colindemar', 'far', 'way', 'rail.', 'tips?']
# filtered_tokens ["i'm", 'still', 'swear.', 'keep', 'losing.', 'gaining.', 'losing.', 'gaining.', 'tweeps?', 'heart', 'wrenching.']
# filtered_tokens ['today', 'realized', 'good', 'hiding', 'things,', 'even', "can't", 'find']
# filtered_tokens ['staying', 'friends', 'house...house', 'sitting,', 'neighbors', 'loud-having', 'party']
# filtered_tokens ['@dannyvegasbaby', 'danny', 'im', 'upset', 'wasnt', 'watch', 'live', 'chat', 'car.', '3', 'hours', 'trip', 'im', 'soooo', 'upset!!']
# filtered_tokens ['check', 'mug', 'http://www.erika-obscura.blogspot.com']
# filtered_tokens ['borders', 'closed', '10']
# filtered_tokens ['downloading', "nin's", 'new', 'album', '&quot;the', 'slip&quot;', 'hell', 'come', 'out?', "i'm", 'behind', 'times', 'days']
# filtered_tokens ['woke', 'already', 'written', 'e-mail...', "i've", 'go', 'early', 'university', 'today', 'teach', '8:30', 'am!']
# filtered_tokens ['watching', 'hill', '.and', 'making', 'sad']
# filtered_tokens ['many', 'channels....', 'yet', 'boring...', 'lazy', 'day', 'may', 'find', 'hobby']
# filtered_tokens ['@supersport', 'miss', 'buddy', 'ill', 'ny', '25th']
# filtered_tokens ['@robluketic', 'love', 'french.', 'tell', 'people', 'south', "i'm", 'qtr.', 'french', 'snarl', 'me.', 'french', 'beautiful', 'people']
# filtered_tokens ['opps..', 'said..', 'still', 'got', 'one', 'day', 'remain', 'problem', 'come']
# filtered_tokens ['activated', 'selfcontrol', 'block', 'early,', 'meaning', "can't", 'check', 'new', 'qc.', 'regularizing', 'internal', 'clock', 'might', 'difficult.', '#fb']
# filtered_tokens ['@hillydop', 'oh']
# filtered_tokens ['spencer', 'good', 'guy.']
# filtered_tokens ['@goodlaura', 'reese', 'dying', '#ttsc?', 'season', 'finale', 'next', 'week.', '#24', 'boring,', 'madame', 'president', 'crazy', 'woman.']
# filtered_tokens ['@jonathanrknight', 'hate', 'limited', 'letters,too.hope', 'guys', 'fine?i', 'pray', 'dog,she�s', 'well']
# filtered_tokens ['get', 'shit', 'done', 'today', "i'm", 'screwed']
# filtered_tokens ['wanttss', 'go']
# filtered_tokens ['going', 'sleep', 'tonite.']
# filtered_tokens ['worried', 'tired', 'post', 'tonight']
# filtered_tokens ['get', 'shit', 'done', 'today', "i'm", 'screwed']
# filtered_tokens ['job', 'interview', 'cardiff', 'today,', 'wish', 'luck!', 'got', '3', 'hours', 'sleep']
# filtered_tokens ['@stustone', 'show', 'whack.', 'way', 'worse', 'whack,', 'wiggety-whack.']
# filtered_tokens ['@djalizay', 'really', 'think', 'people', 'choose', 'way.', 'think', 'chose', 'accept', "family's", 'help', 'might', 'dead']
# filtered_tokens ['@eloquentembrace', 'going', 'kill', 'me,', "i've", 'seen', 'ds9.', "i've", 'waiting', 'till', 'one', 'solid', 'week', 'sitting.']
# filtered_tokens ['@cheechbud', 'think', 'ur', 'right!!', 'hahaha!!', '4.5', 'hrs', 'now!!']
# filtered_tokens ['hate', 'see', 'spartans', 'sad']
# filtered_tokens ['mind', 'body', 'severely', 'protesting', '&quot;getting', 'up&quot;', 'thing.', 'nightmares', 'boot']
# filtered_tokens ['@mysteezradio', "i'm", "goin'", 'follow', 'u,', 'since', 'u', 'lol', 'go', 'angels!']
# filtered_tokens ['@mandayyy']
# filtered_tokens ['@twista202', 'think', 'want', 'read', 'books', 'library']
# filtered_tokens ['nap', 'interrupted', 'many', 'times', 'today', 'going', 'japanese', "'rents", 'again...']
# filtered_tokens ['kind', 'longs', 'bus', 'shows', 'end', 'ghost', 'world', 'right', 'now.', 'ugh.']
# filtered_tokens ['@gurumn', 'canada', 'canada', 'weird.', "we're", 'supposed', 'get', 'snow', 'wednesday.', 'ugh.']
# filtered_tokens ['awwh', 'babs...', 'look', 'sad', 'underneith', 'shop', 'entrance', "&quot;yesterday's", 'musik&quot;', 'o-:', 'like', 'look', 'new', 'transformer', 'movie']
# filtered_tokens ['sad', "'feet'", 'macbook', 'fell']
# filtered_tokens ["i'm", 'gonna', 'get', 'late', 'tomorrow', '132am', 'here.', 'gonna', 'get', 'tipsy', 'lonesome.', "that's...that's", 'sad']
# filtered_tokens ["i'm", 'sweating', 'forthcoming', 'trip', 'e3.', "can't", 'find', 'someone', 'crash', "i'm", 'there,', 'may', 'screwed.']
# filtered_tokens ['gotten', 'somebody', 'read', 'tweets,', 'cant', 'get', 'make', 'account.']
# filtered_tokens ['@infinitydefines', 'omgawd', 'couldnt', 'handle', 'cat', 'heat', 'time', 'd:', 'd:']
# filtered_tokens ['@donniewahlberg', 'hope', 'make', 'auburn', 'show.', 'looking', 'good']
# filtered_tokens ['@david_henrie', '*thats', 'people', 'mag', 'haha', 'couldnt', 'fit', 'in..', 'dont', 'think', 'pictures', 'ever', 'made', 'magazine', 'tho!', 'haha']
# filtered_tokens ['@breadandbadger', 'congrats!!', 'totally', 'forgot', 'submit', 'photos']
# filtered_tokens ['@paulaabdul', 'awww,', 'good', 'luck', 'paula!!', 'please', 'work', 'hard', 'hope', 'fun', 'new', 'album', 'gonna', 'amazing!', 'xxx']
# filtered_tokens ['@imaginarypeach', 'leaving', '-gets', 'sad-']
# filtered_tokens ['miss', 'twitter.', 'phone', 'broke,', "i'm", 'using', 'stupid', 'nokia', 'phone.', 'ughhh,', 'miss', 'advance', 'phone.']
# filtered_tokens ['shooting', 'outside', 'house', ':o', 'kidding!', 'scared']
# filtered_tokens ['tuesday�ll', 'start', 'reflection', '�n', 'lecture', 'stress', 'reducing', 'techniques.', 'sure', 'might', 'become', 'useful', 'us', 'accompaniers']
# filtered_tokens ['tragedy', 'disaster', 'news', 'week']
# filtered_tokens ['yes', 'yes', 'still', 'trying', 'find', 'picture', 'upload', 'correclty..']
# filtered_tokens ['oh', 'red', 'sox', 'game', 'rained', 'out?', 'looking', 'forward', 'opening', 'day']
# filtered_tokens ['still', "can't", 'find', 'keys.']
# filtered_tokens ['@charlietm', 'know', 'right.', 'dunno', 'going', 'twitter.']
# filtered_tokens ['might', 'getting', 'sore', 'throat']
# filtered_tokens ['@labelsnotlove', 'home', 'town.', 'mammy', 'called', 'depressd.', 'pls', 'explain', 'parent', 'let', '8yr', 'old', 'child', 'walk', 'alone?', 'hello?', '2009!']
# filtered_tokens ['@ircmaxell', 'think', 'need', 'find', 'better', 'anti-depressants.', 'think', 'paxil/wellbutrin', 'combo', 'losing', 'efficacy.']
# filtered_tokens ['@myconnecticut', 'restaurant', 'called', 'woodntap', 'competitive', 'eating', 'tourney', 'round', 'tourney', 'time.', 'place', '2nd']
# filtered_tokens ['bathroom...', 'wake', 'lakin.']
# filtered_tokens ['@caitlinoconnor', 'want', 'tacos', 'margarhitas', 'telll', 'gay', 'say', 'hello&lt;3']
# filtered_tokens ['im', 'lonely', 'keep', 'company!', '22', 'female,', 'california']
# filtered_tokens ['bad', 'day', 'betfair', 'office']
# filtered_tokens ['miss', 'him.', "can't", 'wait', 'celebrate', 'tar', 'heel', 'win', 'weekend', 'though!!']
# filtered_tokens ["i'm", 'really', 'cold.', 'want', 'go', 'sleep', 'yet', "there's", 'nothing']
# filtered_tokens ['@kristencampisi', '4', 'u?', 'officially', '4', 'go', 'round!']
# filtered_tokens ['monkeys???', 'found', 'twin', 'wont', 'even', 'write', 'back.', "i'm", 'heartbroken']
# filtered_tokens ['@miss_om', 'aww', 'know', 'felt', 'like', 'yesterday', 'work']
# filtered_tokens ['@sarahreedsc', 'treaty', 'defined']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['@jpfurry', 'poor', 'john', 'happens', 'play', 'fruit', 'microwave!', 'seriously', 'though', 'seen', 'doctor??', 'xxx']
# filtered_tokens ['missing', 'bff', 'watching', 'home', 'away', 'reminds', '&lt;3', 'it.', 'shout', 'u', 'courts']
# filtered_tokens ['@mandayyy']
# filtered_tokens ['new', 'video', 'card', 'doa.']
# filtered_tokens ['feeling', 'lost,', 'naked', 'confused', '(jk,', 'sort', 'of).....no', 'iphone', 'me.']
# filtered_tokens ['damn', 'late', 'filling', 'appraisal', 'form,', 'people', 'almost', 'sent', 'occupied', 'work']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['think', 'much', 'past.', 'cant', 'change', 'it.', 'deserved', 'much', 'wat', 'got.', '..but', 'still', 'thinking', 'gah']
# filtered_tokens ['lost', 'ring.', 'no-where', 'seen']
# filtered_tokens ['@burgaw', 'ooooooh!', '*sealclap*', 'see,', 'download', 'shitloads', 'zip', 'folders', '4chan.', 'internet', 'moneys.', 'fuck', 'yeah', 'alicia', '&amp;', 'mikey.']
# filtered_tokens ['still', 'nursing', 'nile', 'glad', 'feeling', 'better.', 'hate', 'baby', 'sick']
# filtered_tokens ['fucked', 'go', 'back', 'ic']
# filtered_tokens ['@brandizzzle08', 'yoyoyo.', 'internet', 'rude', 'tonight.', 'reconnected', "i'm", 'go', 'bed.']
# filtered_tokens ['@jemcam', 'well', 'uni', 'stuff', 'netball', 'netbal', "i've", 'done', 'uni', 'stuff']
# filtered_tokens ['@kissability', 'poor']
# filtered_tokens ['help', 'forget', '8th', 'april', '&amp;', '13th', 'july!']
# filtered_tokens ['dierks', 'bentley', "comin'", 'columbus,', 'oh!!', 'wanna', 'go', 'bad']
# filtered_tokens ['take', 'sidekick', 'back.']
# filtered_tokens ['@chriscantore', 'congrats!', "i'm", 'totally', 'jealous!', 'wish', 'xm', 'working']
# filtered_tokens ['gr8t', 'face', 'itchy']
# filtered_tokens ['poor', 'socks', 'luvvvvv', 'golden', 'retriever!!', 'want', 'one', 'sighhhh']
# filtered_tokens ['saw', 'found', 'tracy', 'girl', 'piece', 'luggage...', 'fucking', 'terrible']
# filtered_tokens ['aaaaand', 'nausea', 'back.']
# filtered_tokens ['@donniewahlberg', 'ooh', 'i�m', 'excited', 'even', 'going', '2', 'long', 'love', 'youtube!']
# filtered_tokens ['spent', '1', 'hour', 'reach', 'axis', 'bank', 'find', 'today', 'holiday', 'mahavir', 'jayanti', 'contd..']
# filtered_tokens ['@mathewsmichael', 'agree...', 'jobros', 'dont', 'update', 'theres', 'often']
# filtered_tokens ['@fishmouse', 'hilarious', 'linked', 'clip', 'lj', 'time', 'ago', 'went', 'back', 'dead', 'link']
# filtered_tokens ['@diannepulham', 'oooooooo', 'with?', '(im', 'neither', 'thats', 'need', 'study']
# filtered_tokens ['tweeted', 'nearly', 'day', 'posted', 'website', 'tonight,', 'hopefully', 'goes', 'well', 'night', 'time!']
# filtered_tokens ['@bostongarden', 'miss', 'bentley']
# filtered_tokens ['seriously', 'needs', 'finish', 'job', 'applications']
# filtered_tokens ['son', 'vincas', 'sick,', 'stay', 'home', 'three', 'tense', 'days', 'work,', 'back', 'holiday', 'kids']
# filtered_tokens ['whinging.', 'client&amp;boss', 'understand', 'english', 'well.', 'rewrote', 'text', 'unreadable.', 'written', 'v.', 'good', 'writer&amp;reviewed', 'correctly.']
# filtered_tokens ['@huntermoore', 'want', 'ever', 'punch', 'me.']
# filtered_tokens ['sooo', 'sick', 'snow', 'ughh']
# filtered_tokens ['@its_nemesis']
# filtered_tokens ['@lovemeagan', 'work', 'fan', 'upset']
# filtered_tokens ['would', 'like', 'apologize', 'repeated', 'video', 'games', 'live', 'related', 'tweets.', 'going', 'stern', 'discussion', 'koodo', 'soon.', 'stern.']
# filtered_tokens ['@zaydia', 'cant', 'figure', 'get', 'back', 'pay', 'hotel', 'etc']
# filtered_tokens ['fml:', 'much', 'seniority,', 'bc', 'technological', 'ineptness,', '&quot;register&quot;', 'classes']
# filtered_tokens ['feels', 'like', 'slept', 'day', 'away.', 'looking', 'forward', 'bouts', 'gallbladder.', 'least', 'pills', 'pain.']
# filtered_tokens ['@thastevieg', 'really', 'want', 'old', 'bass', 'back']
# filtered_tokens ['mad', 'tired', 'today...', 'callin', 'early', 'tonight', 'nighty', 'night', 'twittas']
# filtered_tokens ['@levenrambin:', 'take', 'easy,', 'good', 'you.']
# filtered_tokens ["i'm", 'afraid', 'bad', 'code.']
# filtered_tokens ['think', "i'm", 'going', 'bed.', 'goodniight.', 'hate']
# filtered_tokens ['@riancurtis', "i'm", 'here,', 'friend,', 'love', 'you.']
# filtered_tokens ['@kariajay', 'time', 'notice', 'gone...just', 'needed', 'db2', 'it??']
# filtered_tokens ['@aaronrva', 'bathroom', 'pee!']
# filtered_tokens ['@ashleyskyy', 'wanted', 'margarita', 'too!']
# filtered_tokens ['@kourtneykardash', 'yup', 'night', 'workouts', 'r', 'worst', 'unfortunetly', 'work', 'schedule', 'allows', 'go', 'night', 'tough!']
# filtered_tokens ['called', 'hillsong', 'said', 'tell', 'waiting', 'list', 'know', 'looking', 'good']
# filtered_tokens ['0g', 'milky', 'bar', 'left,', 'around', '200ml', 'coke']
# filtered_tokens ['@jokerrrr', 'stillllll', 'arrived']
# filtered_tokens ['mraow,', 'feel', 'like', 'dancing,', 'first', 'art', 'school', 'wants', 'rape', 'more.']
# filtered_tokens ['@karenucol', 'ah!', 'bet', "i've", 'like', 'craving', 'play', 'softball', 'basketball', 'noo', 'time']
# filtered_tokens ['terrified', 'accidentally', 'deleted', 'reference', 'management', 'assignment', 'hopes', 'doesnt', 'get', 'trouble', 'gets', 'back']
# filtered_tokens ['amazon', 's3', 'plugin', 'worked', 'website', 'need', 'php', '5', 'hosting', 'provider', 'php', '4.4', 'sad.']
# filtered_tokens ['argh!', 'suuuper', 'sleepy', 'hour', 'ago,', "i'm", 'wide', 'awake.', 'hope', 'stay', 'night.']
# filtered_tokens ['@austinhill', 'wish', 'was!', 'sold', 'time', 'let', 'know,', 'would', 'love', 'hear', 'to!']
# filtered_tokens ['watched', 'tropic', 'thunder.', 'dreading', 'tomorrow']
# filtered_tokens ['@qweendassah', "no...he's", 'still', "miss'n..."]
# filtered_tokens ['chiefdelphi']
# filtered_tokens ['http://twitpic.com/2y2wr', 'according', 'bro,', 'new', 'puppy', 'poo', 'fight', 'covered', 'poop', '(picture', 'stolen', 'him)']
# filtered_tokens ['playing', 'game', 'home!', 'new', 'boss', 'call', 'yet...']
# filtered_tokens ['su', 'yin', 'huen', 'tweeted', 'feel', 'unbearable', 'guilt.', 'made', 'staff', 'cry', 'http://tinyurl.com/cw2l9t']
# filtered_tokens ['poor', 'joshy', 'sick???', 'damn', 'tejanos!']
# filtered_tokens ['thoughts', 'sandra', "cantu's", 'family', 'difficult', 'sad', 'time']
# filtered_tokens ['@franzglaus', 'know,', 'wanted', 'let', 'everybody', 'know', 'happening']
# filtered_tokens ['michigan', 'who?', 'know', 'them.', '*sigh*', 'shameful!']
# filtered_tokens ['fill', 'two', 'hours']
# filtered_tokens ['@alicayaba', 'cuuute!', 'hey,', 'miss', 'na!', 'seeing', 'girls', 'everyday']
# filtered_tokens ['@jonathanrknight', 'oh!', 'mention', 'it?', '&quot;gooooood', 'moooorniiiiiiing&quot;', 'germany!', 'im', 'back', 'cage....or', 'better...my', 'office']
# filtered_tokens ['throat', 'closing', 'string', 'cheese.', 'good', 'idea']
# filtered_tokens ['aww,', 'sandra', 'cantu', 'found', 'dead', 'suitcase', 'missing', 'children', 'stories', 'never', 'seem', 'go', 'good.', 'poor', 'family.']
# filtered_tokens ['wishing', 'home', 'underneath', 'covers']
# filtered_tokens ['walking', 'home', 'school', 'drains', 'energy']
# filtered_tokens ['@ridley1013', 'agree.', 'shapeshifting', 'copout.', 'excited', "angela's", 'ep,', 'thought', 'week.', 'noah', 'awesome', 'tho!']
# filtered_tokens ['@savethestrib', 'dang!', 'would', 'done', 'knew', 'earlier.', 'outings', 'planned?']
# filtered_tokens ['wish', 'better', 'writing.', 'taking', 'long', 'write', 'paper.']
# filtered_tokens ['..and', 'course...', 'access', 'halo', '3', 'mythic', 'map', 'pack', 're-download..', 'bad', 'news..', 'legendary', 'map', 'pack...', 'ugh..', '600ms...']
# filtered_tokens ['@vene2ia', '...not', 'yet', 'unfortunately,', 'another', 'weeks', "i've", 'told', 'you?', "i've", 'little', 'bit', 'busy', 'latest', 'project.']
# filtered_tokens ['@thecoolestout', 'ha', "sun's", 'already', 'gone']
# filtered_tokens ['day', '2.', 'lot', 'harder', 'day', '1.', "let's", 'see', 'day', '3', 'goes', 'tomorrow.']
# filtered_tokens ['man', 'crush', 'jake', 'peavy', 'let', '#gayforpeavy']
# filtered_tokens ['@trishzw', 'megafast', 'trip,', 'time', 'day', 'tom/weds?', 'or,', 'going', 'tonight?', 'want', 'see', 'bad.', 'tried', 'warn', 'you,', 'tech', 'fail']
# filtered_tokens ['michigan', 'state', 'make', 'sad']
# filtered_tokens ['omg.', 'mouth', 'much', 'pain', 'wanna', 'sleep', 'untill', 'time', 'take', 'braces', 'off.']
# filtered_tokens ['getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biofuel', 'proposal:', 'getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biof..', 'http://tinyurl.com/ceprvs']
# filtered_tokens ['@mizzchievouz', 'hey', 'girl.', 'site', 'back.', 'girlyvue', 'back', 'even', 'videos.']
# filtered_tokens ['@a5hleyf', "i'm", 'spending', 'time', 'grandma', 'early', 'tomorrow', "can't", 'leave', 'skittles', 'herself.']
# filtered_tokens ['got', 'home', 'watching', 'michigan', 'state', 'get', 'tromped!']
# filtered_tokens ['oh', 'jew-bus!', 'two', 'years', 'worth', "classes'", 'work', 'alot', 'organize', '&gt;_&lt;', "i'm", 'finishing', 'tonight,', 'possible...my', 'bones', 'ache']
# filtered_tokens ['@griffmiester', 'exchanging', 'me,', 'laptop', 'arrived']
# filtered_tokens ['@hyperbets', 'hope', 'last', 'long.', 'feel', 'miserable!']
# filtered_tokens ['@rcompo', 'rachel!', 'hang', 'outage', 'neccessary', 'gonna', 'home', 'wekend', 'dumb', 'folk', 'make', 'work', 'im', 'free', 'f', 'sat', '4...']
# filtered_tokens ['@theleaguesf', 'fun', '&amp;', 'furious?', 'new', 'mantra', 'bay', '2', 'breakers?', 'getting', '2', 'rambunctious;the', 'city', 'overreacted', '&amp;', 'clamped']
# filtered_tokens ['@amber_benson', 'hubby', '(for', 'reason)', 'thinks', 'important', 'good', 'spot', 'red', 'carpet', 'trek', 'movie', 'premiere.', 'sod!']
# filtered_tokens ['swear', 'matter', 'long', "i've", 'getting', '5am,', 'never', 'gets', 'easier.', 'man', 'eyes', 'hurts', 'wah']
# filtered_tokens ['@jeffree_star', 'jeffree!', 'keep', 'hair', 'one', 'color?', 'permanent', 'dye', 'fades', 'within', 'week']
# filtered_tokens ['@otakusecret', 'reaction', 'whoa,', 'see', 'coming']
# filtered_tokens ['still', 'sick.', 'feeling', 'bit', 'better,', 'got', 'new', 'medicine....', 'hope', 'feel', 'good', 'night', 'sleep.', 'ohh,', 'suppose', 'snow!', 'wtf!']
# filtered_tokens ['@dangerm0use', 'think', 'maybe', 'get', 'couple', 'hours', 'sleep,', 'hon.', 'productive', 'right', 'ur', 'dog', 'tired?', 'worry']
# filtered_tokens ['@maddyva', 'thanks', 'lot.', 'learned', 'lot', 'new', 'words', 'find', 'looking', 'for.']
# filtered_tokens ['wish', 'xblm', 'downloads', 'gamertag', "'hitokyri'.", '5', 'gamertag', 'thing', 'nonsense...', "i'm", 'tired']
# filtered_tokens ['new', 'testament', 'test', '9:30']
# filtered_tokens ['@scoutbuck', 'tons', 'hay', 'troll?', 'ahhhh']
# filtered_tokens ['stupid', 'movies', 'watched...', 'mirrors', 'ugggggh...', 'stooopeeed!!!', 'rip', 'off!']
# filtered_tokens ['http://twitpic.com/2y2yi', 'love', 'you,', 'buck.']
# filtered_tokens ['last', 'one!!!', 'still', 'done!!!']
# filtered_tokens ['homework....']
# filtered_tokens ['understand', 'things', 'get', 'taken', 'away.', 'enough', 'time', 'unfair.', 'want', 'back!!', 'like', 'baby']
# filtered_tokens ['scratch', 'that:', 'du', 'heif', '(two', 'half)', 'cookies.', 'tum', "can't", 'take', 'anymore', 'shoog.', 'poots']
# filtered_tokens ['@cococourtney', 'listening', 'sweets', 'first', 'time', 'forever!', 'miss', 'much', 'go', 'chi', 'town', 'visits', 'plz?']
# filtered_tokens ['geez', 'busy', 'afternoon.', 'meetings,', 'emails,', 'meetings', 'email', 'meetings.', '6pm', 'day', 'still', 'going!', 'ah', 'dark']
# filtered_tokens ['dang!!!', 'another', 'spring', 'break!!!', 'cool', 'that???', 'bad', 'work', 'week', 'oh', 'well,', 'money', 'phone.', 'ttyl', 'everbody!!!']
# filtered_tokens ['@sara_kate', 'im', 'afraid', 'ur', 'reply', 'uni', 'ages', 'ago']
# filtered_tokens ['feeling']
# filtered_tokens ['@carvin1', 'lol', 'emotional', 'ass', 'men!!', 'omg', 'late', 'night', 'eating..', 'us', 'broke']
# filtered_tokens ['@nick_carter', 'aww', 'nick!!', 'like', 'hair', 'longer,', 'cut', 'off?', 'break.', 'my.', 'heart.']
# filtered_tokens ['wonder', 'jon', 'lost', 'net']
# filtered_tokens ['wow.', 'depressing', 'thing', 'world', 'losing', 'video', 'created', 'matter', 'seconds.', '#fml']
# filtered_tokens ['@nchokkan', 'https://www.mycomicshop.com/search?tid=395031', 'says', 'stock']
# filtered_tokens ['@poohpot', 'lmao', 'im', 'sorry', 'poohpot', 'ate', 'all!']
# filtered_tokens ['chance', 'softbelly', '(for', '@mtub)', 'loud?']
# filtered_tokens ['time', 'move', 'posterior', 'lose', 'fat.', 'articulation', 'creaking', 'running', 'i�m', 'drool', 'swimming']
# filtered_tokens ['listening', 'nathan', 'cry....']
# filtered_tokens ['today', 'sucked.', "i'm", 'gonna', 'die', 'without', 'chris', 'callum!', 'wahhh!']
# filtered_tokens ['stou', 'site', 'update,', 'info', '2/2552', 'exam,', 'open', 'course,', 'must', 'wait', 'mail', 'notices', 'doc.', 'um...']
# filtered_tokens ["@ohsbrat30...i'm", 'sorry.', "i'm", 'feeling', 'kinda', 'yucky', 'myself.', '5am', 'going', 'come', 'quick']
# filtered_tokens ['love', 'scrappy', 'missin', 'already']
# filtered_tokens ['wants', 'hear', '@seblefebvre', "'s", 'song', 'myspace', 'messing']
# filtered_tokens ['bad', 'news', 'dad', 'cancer', 'dying', 'good', 'news', 'new', 'business', 'started', 'life', 'coach', 'practising', 'holistic', 'weight', 'management']
# filtered_tokens ['@duchess_rebecca', 'man...', 'intervention', 'soo', 'sad']
# filtered_tokens ['help!', 'need', 'new', 'boyfriend...', "i'm", 'stuck', 'rut']
# filtered_tokens ['feel', 'like', 'complete', 'idiot.', "i'm", 'one', 'get', 'shit', 'works', 'help']
# filtered_tokens ['saw', 'ad', 'craigslist', 'casting', 'call', 'female', 'host', 'g4.', 'totally', 'psyched!', 'realized', 'hoax']
# filtered_tokens ['pepperoni', 'rolls', 'l.a.?:', 'called', "valentino's", 'said', 'sausage', 'rolls', 'pepperoni', 'rolls', 'http://tinyurl.com/cec5ka']
# filtered_tokens ['@soillodge', 'yes,', 'be.', 'monday']
# filtered_tokens ['want', 'new', 'gg', 'episode', 'already']
# filtered_tokens ['miss', 'watching', "rocko's", 'modern', 'life.']
# filtered_tokens ['rip', 'sandra....its', 'sad', 'someone', 'something', 'like', 'that??']
# filtered_tokens ['keeping', 'fingers', 'crossed', 'buddy', 'feeling', 'well.']
# filtered_tokens ['wait', 'eat??', 'skinny', 'vegas!!', "i'm", 'hungry!']
# filtered_tokens ['@marge_inovera', 'tried', 'tweetdeck', 'hated', 'passion.', 'hated', 'me,', "i'm", 'sure...']
# filtered_tokens ['@benackerman', 'btw', 'iphone', 'acting', 'funny,', 'dying', 'quickly', 'freezing', 'bs.', "i'm", 'admitting', 'anything,', 'sayin']
# filtered_tokens ['sitting', 'wondering', '&quot;ed&quot;', 'still', 'strong', 'hold']
# filtered_tokens ['@bananaface', 'im', 'sorry', 'got', 'sick.', 'lol.', 'going', 'bed', 'too.', 'night!']
# filtered_tokens ['@carolrainbow', 'internet', 'home,', 'drive', 'ox', 'use', 'internet', 'builders!']
# filtered_tokens ['@steve_buscemi', 'weather', 'canada', 'freezing']
# filtered_tokens ['twiggassssssss', 'range', 'day', "i'm", 'back', 'hopefully', 'good.']
# filtered_tokens ['@danadearmond']
# filtered_tokens ['anyone', 'reads', 'pray', 'grandma.', 'pain']
# filtered_tokens ['#3', 'woke', 'accident', "&quot;it's", 'pushing,', 'pushing!&quot;', 'crying', 'stop', 'wetting', 'pants.']
# filtered_tokens ['home', 'franklin', 'street,', 'almost', 'jumped', 'fire.', 'someone', 'kicked', 'could.', 'jenny', 'lost', 'shoe.']
# filtered_tokens ['@johnnybeane', 'hey!', 'changed', 'default.']
# filtered_tokens ['finally', 'gave', 'bored', 'enough', 'start', 'thing.', 'think', '140', 'going', 'problem', 'tho.', 'like', 'myspace', 'status.']
# filtered_tokens ['@ellievolia', 'oooonly', 'really', 'lucky,', 'eh?', 'awh', 'definitely', 'early', 'work.']
# filtered_tokens ['buttload', 'homework!']
# filtered_tokens ['needs', 'another', 'copy', 'visual', 'studio', '2008']
# filtered_tokens ['we,', 'school', 'world,', 'week.my', 'school', 'silly', 'anyway...', 'look', 'bright', 'side.', "i'm", 'off,', 'u']
# filtered_tokens ['omg', "i've", 'economics', 'test.', 'dont', 'know', 'things', 'know', 'omg', 'im', 'gonna', 'fail']
# filtered_tokens ['@robcthegeek', 'upon', 'time', 'hundred', 'islands', 'pride', 'philippine', 'tourism,', 'coral/clam/rare', 'fish', 'poaching', 'in.', 'kinda', 'sad']
# filtered_tokens ['@henkuyinepu', 'yeah,', 'apparently', 'really', 'bad', 'taste']
# filtered_tokens ['@hummiemd', 'know!', 'really', 'surprised', 'since', 'everyone', 'recommends', 'youtube.', 'call', 'tomorrow', 'figure', 'out.']
# filtered_tokens ['waiting', 'airport', 'ride', 'get', 'harassed', '2', 'men', 'trying', 'sell', 'ugly', 'hats..', 'me?!', 'want', 'sleep..']
# filtered_tokens ['left', 'ids', 'location', 'go', 'bars', 'fuckkkkkkkkkkkkk']
# filtered_tokens ['@celycarmo', "i'm", 'sorry', 'understand', 'last', 'comment']
# filtered_tokens ['@officialrandl', 'announcement?', 'stayed', 'late', 'last', 'night']
# filtered_tokens ['@kishorek', 'strange,', 'illegal', 'torrents', 'avlbl', 'everywhere,', 'legal', 'dvd', 'stock', 'now???']
# filtered_tokens ['enough', 'say', 'imiss', 'u']
# filtered_tokens ['trolley', 'packed', 'like', 'sardines!', 'padre', 'game', 'remove', 'car?!', 'good', 'call', 'mts']
# filtered_tokens ['@randomlynat', 'jeez,', 'trying', 'help', 'haha.']
# filtered_tokens ['@supamagg', 'happened', 'saturday', 'night.', 'along', 'glittery', 'green', 'lighter!']
# filtered_tokens ['trying', 'reduce', 'number', 'cigarettes', 'day!']
# filtered_tokens ['yea', 'quiet', 'around', 'cuz', 'everyone', 'work', 'im', 'bored', 'death', 'nobody', 'talk']
# filtered_tokens ['gotta', 'cooking', 'assignment', 'hard']
# filtered_tokens ['@treesahquiche', 'okay,', 'applepears,', "i've", 'talked', 'people', "they've", 'before.', 'one', 'ever', 'told', 'me,', 'never']
# filtered_tokens ['@jennifermf', 'know!', "i'm", 'night', 'owl', 'nature,', 'hahaha', 'time', 'zone', 'behind', 'you?', 'almost', '1']
# filtered_tokens ['@mamasvan', 'lol', 'nope!', 'complete', '#camerafail']
# filtered_tokens ['@maxime68', '@megelder', 'but!', "i'm", 'useless', 'sleep', 'fair!', 'want', 'fun', 'well!!!']
# filtered_tokens ['pookie', 'uti.', 'nurse', 'gabbie', 'get', 'back', '100%!!!', 'sodas!!!!!!!!!!!!!!']
# filtered_tokens ['@jillianfish', 'tweet', 'something', 'damn', 'it!', 'hang', 'please?']
# filtered_tokens ['@anistorm']
# filtered_tokens ["i'm", 'behind', 'video', 'games,', 'everything', 'matter.', "i'm", "yesterday's", 'news']
# filtered_tokens ['@sleep_til_noon', 'did,', 'one', 'left', 'got', 'tempted', 'ate', 'soon', 'got', 'home', 'chocolate', 'velvet', '&amp;', 'ate', 'mocha']
# filtered_tokens ['stressing', 'blackberry', 'keeps', 'flashing', 'red', 'alert', 'status', 'reason!!', 'faking', 'hate', 'it!!!']
# filtered_tokens ['http://twitpic.com/2y34e', 'wanna', 'wear', 'doc', 'martens', 'out!', 'worn', 'since', 'december.']
# filtered_tokens ['shoe', 'repair', 'shop', 'guy', 'could', 'find', 'shoes!', 'go', 'back', 'see', 'find', 'couple', 'days.']
# filtered_tokens ['@b_barnett', 'really', 'see', 'coming']
# filtered_tokens ['woke', 'vivid,', 'sketchy,', 'not-cool', 'dreams', 'life.', 'time', 'stare', 'wall', 'lights', 'on.']
# filtered_tokens ["it'll", 'take', '3', 'days', 'sister', 'get', 'passport']
# filtered_tokens ['@nicolerichie', 'oh', 'yes!!', 'miss']
# filtered_tokens ['uh', 'oh...', 'think', 'getting', 'sick']
# filtered_tokens ['good', 'god', 'ruined', 'belly', 'button!!!']
# filtered_tokens ['watching', 'framed', 'roger', 'rabbit.', 'makes', 'miss', 'toon', 'town.']
# filtered_tokens ['@akianz', 'renting..', 'cheap', 'renting,', 'awesome', 'house.', '3', 'buying', 'attempts', 'fall']
# filtered_tokens ['running', 'nose', 'spinning', 'head', 'good', 'combination', 'meeting!']
# filtered_tokens ['@eazydoesit87', 'negative..', 'lost', 'vote', 'confidence']
# filtered_tokens ['nasty', 'budget', 'due', 'iphone', 'sent', 'apple', 'today.']
# filtered_tokens ['@sofii_noel', 'that�s', 'bad']
# filtered_tokens ['dammit,', 'episode', '3', 'kings', 'play', 'reason', 'stopped', 'middle', 'anything']
# filtered_tokens ["i'm", 'upset', 'missed', 'chat', 'quiz', 'online', 'free', 'internet', 'ceased']
# filtered_tokens ["can't", 'believe', 'it!', "i'm", 'disbelief', 'way', 'really.', 'much', 'take', 'people', 'always', 'get', 'hurt', 'others!!']
# filtered_tokens ['car', 'show', 'season', 'started', 'without']
# filtered_tokens ['throat', 'raw.']
# filtered_tokens ['@kevchoice', 'get', 'it.', 'persons', 'mind', 'could', 'even', 'ish', 'like', 'this???', 'prayers', 'fam', 'real']
# filtered_tokens ['@frago', 'hate', 'you.', 'need', 'see', 'that.', 'need', 'call', 'therapist', 'now.']
# filtered_tokens ['twilight', 'come', 'yesterday', 'fingers', 'crossed', 'today']
# filtered_tokens ['@nilelegania', 'glad', 'able', 'help', 'feel', 'better.', 'hate', 'see', 'sick', 'love', 'you!']
# filtered_tokens ['tireddddddd.', 'want', 'sleep', 'assignment', 'finish', 'exam', 'tomorrow', 'study']
# filtered_tokens ['know,', 'thinking...', 'need', 'money']
# filtered_tokens ['omg..its', 'jst', 'teusday']
# filtered_tokens ['@ddlovato', '@david_henrie', 'ummmmm', 'cant', 'find', 'it.']
# filtered_tokens ['heard', 'found', 'sandra', 'cantu...', '8', 'yrs', 'old']
# filtered_tokens ['@corrosivecandy', 'ive', 'forgotten', 'snoo-snoo', 'wonder', 'snoo-snoo', 'ever', 'meet', 'again...']
# filtered_tokens ['@amanorris', 'wow', 'last', 'tweet', 'made', 'seem', 'like', 'giant', 'sexist...sorry']
# filtered_tokens ['bathtub', 'drain', 'fired:', 'haz', '1', 'job', '2', 'do,', '&amp;', 'iz', 'fail.', 'got', 'drano', 'ass,', '&amp;', 'iz', 'still', 'draining.', 'wanna', 'shower,', 'dangit!!']
# filtered_tokens ['stuck', 'home']
# filtered_tokens ['@nomadicmatt', 'mine', '1/10', 'get', 'up?']
# filtered_tokens ['duckling', 'famous', "children's", 'book', 'stolen', "boston's", 'public', 'garden', 'boston', 'globe', 'http://tinyurl.com/dc2htx', 'via', '@sharethis', 'oh', 'no!!']
# filtered_tokens ['@appomattox_news', 'thank', 'you!', 'however,', 'hate', 'list', 'includes', '2', 'convicts.']
# filtered_tokens ['heading', 'altrincham,', 'again!', 'hours', 'install']
# filtered_tokens ['morning!!!', 'good', 'im', 'bloody', 'knackered!!!', 'work', 'today', 'helppp!!!!', 'xxx']
# filtered_tokens ['@jeffreecuntstar', 'garage.', 'park', 'driveway!']
# filtered_tokens ['@lauredhel', 'happened?']
# filtered_tokens ['&quot;on', 'popular', 'music&quot;', 't.w.adorno', 'probably', 'difficult', 'reading', 'ever', 'prescribed,', "i'm", 'actually', 'struggling', 'continue']
# filtered_tokens ['http://twitpic.com/2y36e', 'cant', 'see', 'flowers', 'falling', 'dont', 'camera,', 'cellphone']
# filtered_tokens ["we've", 'good.', "i'm", 'liking', 'snow', 'right', 'now,', 'getting', 'used', 'nice', 'spring-like', 'weather.', 'you?']
# filtered_tokens ['@brian_armstrong', 'pity', 'youtube', 'currently', 'blocked', 'china.', "can't", 'see', 'vids.']
# filtered_tokens ['@margaretcho', 'happened', 'show', 'hightlight', 'life']
# filtered_tokens ['best', 'leather', 'sofa', 'world!', 'office', 'though', 'means', "i'm", 'still', 'working']
# filtered_tokens ['still', '3', 'days', 'internet', 'gets', 'uncapped']
# filtered_tokens ['get', 'better', 'days,', 'could', 'something', 'lodged', 'belly']
# filtered_tokens ['love', 'atekinzz', 'much.', '&amp;&amp;', 'soo', 'miss', 'her..']
# filtered_tokens ['wanna', 'sneak', 'zoo', 'play', 'kitties']
# filtered_tokens ['@lolitariot', 'oh', 'hope', 'getting', 'sick', 'too!']
# filtered_tokens ['@alejandralei', 'dont', 'think', 'cause', 'cousins', 'birthday', 'party']
# filtered_tokens ['sweet', 'little', 'man', 'fell', 'asleep', 'waiting', 'daddy', 'big', 'brother', 'get', 'home!', 'poor', 'baby,', 'missed', 'much', 'today!']
# filtered_tokens ['angel', 'going', 'miss', 'athlete', 'weekend']
# filtered_tokens ['trust', 'hard']
# filtered_tokens ['watched', 'considering', 'today.', 'yaknow.', 'shawnna', 'tomomorrow;i', 'need', 'bestfriend']
# filtered_tokens ['grr', 'want', 'keep', 'reading', 'wont', 'anything', 'left', 'read']
# filtered_tokens ['atekinzz,', 'world', 'you??']
# filtered_tokens ['@rumlover', 'no!', 'u', 'supposed', 'date']
# filtered_tokens ['pears', '&amp;', 'brie,', 'bottle', 'cabernet,', '&quot;win', 'date', 'tad', 'hamilton&quot;...', 'oh', 'gawwd', 'life', 'flashed', 'forward', "i'm", '40', '75', 'cats']
# filtered_tokens ['crap.', 'need', 'dresses', 'too.']
# ...
# filtered_tokens ['stucked', 'paris', "can't", 'even', 'travel', 'france', '(for', 'work)']
# filtered_tokens ['@joannafbeckett,', 'think', "there's", 'one', 'close', 'by.', 'last', 'time', 'checked,', 'closest', 'one', '70', 'miles', 'away!']
# filtered_tokens ['aaaaand', 'back', 'literature', 'review', 'least', 'friendly', 'cup', 'coffee', 'keep', 'company.']
# filtered_tokens ['worried', 'get', '$900', 'even', 'though', 'paid', 'buttload', 'tax', 'last', 'year']
# filtered_tokens ['okay,', 'so..', 'still', 'school!!!!']
# filtered_tokens ['phoneless', '...now', 'sleep']
# filtered_tokens ['reeked', 'alcohol', 'dentist', 'morning', 'drunk', 'put', 'tshirt,', 'realised', 'huge', 'stain.', 'dentist', 'looked', 'disgusted']
# filtered_tokens ['really', 'cold']
# filtered_tokens ['cant', 'sleep', 'wants', 'dream!!']
# filtered_tokens ["can't", 'sleep', 'hate', 'nights', 'try', 'go', 'bed', 'early', 'stay', 'awake', 'hours.', 'poo!']
# filtered_tokens ['@rootbeersoup', 'yeah.', 'bad', 'people', 'like', 'certain', 'burrito-eating', 'man', 'exist.']
# filtered_tokens ['@cronotriggers', "that's", 'sad.']
# filtered_tokens ['found', 'mum', 'adopted', 'auntie', 'twitter..', 'check', 'mum', 'tessm64', 'awesome', 'auntie', 'tania38']
# filtered_tokens ['cannot', 'sleep....wide', 'awake!!...and', 'gotta', 'go', 'work', 'later', 'too.', 'boy,', 'going', 'crappy', 'day.']
# filtered_tokens ['struggling', 'eam', 'law']
# filtered_tokens ["can't", 'sleep', 'like', 'http://twitpic.com/2y3ty']
# filtered_tokens ['bouts', 'start', '24.', 'poor', 'linny', 'keep', 'eyes', 'open.', 'tired', 'work', 'tomorrow', 'morning.', 'night', '@ilovefatsusan.']
# filtered_tokens ['4', 'year', 'old', '(18', 'year', 'old)', 'driving', 'around', 'twist...i', 'want', 'like']
# filtered_tokens ['well,', 'sucked.']
# filtered_tokens ['place', '3', 'days...any', 'help', 'get', 'packing/painting/cleaning', 'much', 'appreciated.', 'oh.', 'rip', 'wall']
# filtered_tokens ['opening', 'partially', 'frozen', 'beer=', 'beer', 'toaster,', 'oven', 'counter.', 'kitchen', 'smells', 'like', 'run', 'speakeasy']
# filtered_tokens ['@stewiebrittany', 'dont', 'even', 'know', 'ride']
# filtered_tokens ['@monasmith', 'sadly,', 'yes.', 'think', 'need', 'counciling']
# filtered_tokens ['making', 'ready', "school...don't", 'feel', 'like', 'going,', 'two', 'tests']
# filtered_tokens ['smugness', 'gone.', 'train', 'also', 'failed', 'turn', "i'm", 'heading', 'victoria', 'followed', 'unpleasant', 'tube', 'ride', 'city.']
# filtered_tokens ['anybody', 'know', 'ipod', 'went?']
# filtered_tokens ['aww', 'earthquake', 'italy', 'made', 'sad', 'saw', 'pics', 'news,', 'terrible.']
# filtered_tokens ['@lilibat', 'never', 'able', 'afford', 'get', 'out.', "i'd", 'much', 'rather', 'go', 'extraction', 'continue', 'deal', 'now.']
# filtered_tokens ['pet', 'care', 'people', 'try', 'run', 'others', 'business?', 'send', 'suspicious', 'e-mails', 'fishing', 'info?']
# filtered_tokens ['@kameelahwrites', '&lt;33', "codez....they've", 'mia', 'tho']
# filtered_tokens ['@reannaremick', 'doesnt', 'work', 'cell', 'go', 'sleep!', '=p']
# filtered_tokens ['going', 'nice', 'tomorrow', 'rain', 'comes', 'back.', 'nice', 'weather', 'birthday']
# filtered_tokens ['@taliasunset', 'rock', 'band', 'hard..on', 'expert!!!']
# filtered_tokens ['@beachbassbone:', 'roomie', 'home', 'day.', 'scratch', 'door.', 'comforter', 'goto', 'large', 'laundromat', 'machines.']
# filtered_tokens ['one', 'hardest', 'thing', 'schedule,', 'one', 'chat', 'end', 'day', 'usually']
# filtered_tokens ['killed', 'character', 'one', 'favorite', 'shows', "i'm", 'upset']
# filtered_tokens ['jealous', 'friends', 'got', 'see', 'new', 'star', 'trek', 'film', 'austin', 'tonight.']
# filtered_tokens ['listening', 'q!', 'got', 'really', 'bad', 'headache', 'drivin', 'lesson', 'ten', 'mins....', 'lucky', 'wana', 'sleeep!']
# filtered_tokens ['@steve_buscemi', 'shut', 'you...i', 'hungry!', 'britain,', 'home', 'boring', 'suckassy', 'breakfast', 'world!', 'miss', 'dennys!!']
# filtered_tokens ['good', 'morning', 'everybody!', 'pkoi', 'fais', 'pas', 'beau', 'bon', 'coffee', 'time!']
# filtered_tokens ['work']
# filtered_tokens ['essay', 'time....']
# filtered_tokens ['@chauncey78', 'hey', 'u', 'talk', 'mom..', 'r', 'home', 'yet?', 'hope', 'r', 'ok..', 'wish', 'coming', 'home', '4', 'easter..']
# filtered_tokens ['@endearingevania', 'sure', 'wish', 'could', 'go', 'guys', 'tmrw.', 'per', 'usual,', 'school', 'interferes.']
# filtered_tokens ['@widyatarina', 'say', 'what???', 'kal', "penn's", 'leaving', 'house?!', 'noooooo!!!', 'awww...', 'totally', 'missed', 'tonight']
# filtered_tokens ['no!', 'lost', 'loyal']
# filtered_tokens ['played', 'another', 'hand', 'bad', 'lost', 'half', 'stack']
# filtered_tokens ['6.20pm', 'early', 'days', 'looooooong', 'night', 'work']
# filtered_tokens ['@yaykimo', 'sad', 'last', 'season.', 'wanna', 'see', 'spencer', 'calls', 'lauren!']
# filtered_tokens ['im', 'done', 'editing', '&quot;the', 'phipstape&quot;.', 'back', '2', 'crack', 'brew', 'see', 'got.............', 'trees', 'though']
# filtered_tokens ['@rj', 'know', 'half', 'means']
# filtered_tokens ['homework', 'homework', 'homework']
# filtered_tokens ['worked', 'heart', 'today,', 'doubling', 'weight', 'station.', 'result:', 'stiff', 'pulled', 'muscles...', 'ouch!']
# filtered_tokens ['@melamachinko', 'feel', 'bad', 'unfollowing.']
# filtered_tokens ['so...', 'tired...', 'god', 'hate', 'new', 'job,', 'two', 'days']
# filtered_tokens ['sad', 'kutner', 'killed', 'fav', 'show', 'house!']
# filtered_tokens ['happy', 'coach', 'stringer', '(hof', 'c/o', '2009!)...now', 'finish', 'term', 'paper']
# filtered_tokens ['feel', 'like', 'shit.', 'way', 'want', 'spend', "birthday's", 'eve']
# filtered_tokens ['far', '311', 'sites', 'put', 'together,', 'checking', 'updates', 'made......']
# filtered_tokens ['lot', 'mind.', 'needs', 'make', 'moneys.', 'ideas.', 'nowhere', 'hiring!']
# filtered_tokens ['@emiliexclarkex', 'miss']
# filtered_tokens ['@stephenkruiser', "i'm", 'sorry', 'hear', 'dog']
# filtered_tokens ['much', 'internet.', 'plagues']
# filtered_tokens ['miss', 'ex', 'soo', 'much']
# filtered_tokens ['sodding', 'm25', 'http://twitpic.com/2y3y0']
# filtered_tokens ['oh', 'thought', 'pirate', 'bay', 'trial', 'verdict', 'today', ':-s', 'apparently', '10', 'days']
# filtered_tokens ['@featherinair', 'call', 'back.']
# filtered_tokens ['study', 'hall', 'now,', 'log', 'immediately.', 'http://plurk.com/p/mzxbg']
# filtered_tokens ['tired', 'im', 'crying', 'reason', 'all.', 'im', 'try', 'get', 'hour', 'half', 'tonight.', 'half', 'got', 'last', 'night.']
# filtered_tokens ['totally', 'like...', 'four', 'girl', 'options,', 'none', 'seem', 'viable']
# filtered_tokens ['far', '311', 'veiws', 'sites', 'put', 'together,', 'checking', 'updates', 'made......']
# filtered_tokens ['listening', "bjork's", 'full', 'love...', 'crying']
# filtered_tokens ['omg', 'hills!', 'love', 'money2,', 'aww', 'think', 'becky', 'buckwild', 'goes']
# filtered_tokens ['craving', 'tantan', 'nabe', 'http://plurk.com/p/mzxcs']
# filtered_tokens ["c'mon", 'sean', 'man']
# filtered_tokens ['watching', '&quot;a', 'league', 'own&quot;...makes', 'miss', 'mint', 'chocolate', 'ice', 'cream', 'cones', 'grand', 'fuck.']
# filtered_tokens ['lost', 'phone', 'where.maybe', 'grass,', 'long,', 'hope', 'rain']
# filtered_tokens ['@tomatosalsa', 'hope', 'referring', 'say', 'hello', 'new', 'stalker', 'lol']
# filtered_tokens ['@brettyboo', 'u', 'sleeping?!', 'ur', 'gonna', 'night', 'ur', 'bike', 'ride?']
# filtered_tokens ['@slessard', 'but,', 'but,', 'wanna', 'listen', 'masters', 'too!']
# filtered_tokens ['@sephystryx', "i've", 'looking', 'good', 'stuff', 'write,', 'also', 'loads', 'uni', 'work']
# filtered_tokens ['feel', 'unloved.', 'dropped', '2', 'tweeters']
# filtered_tokens ['london', 'day', 'thursday,', 'gonna', 'raining,', 'oh', 'fab', 'see', 'much', 'london', 'eye!', 'still', 'robbie', 'care', 'bless']
# filtered_tokens ['completely', 'wiped', 'reloaded', '8900....', 'lost', 'bbm', 'contacts', 'going', 'bed', 'sad.']
# filtered_tokens ['@mykele', 'sayyyy', 'whaaaa?', 'invited...']
# filtered_tokens ['sleep', 'bad', 'considering', 'workshop', 'starting', 'today.', 'beginnings', 'sore', 'throat', 'though']
# filtered_tokens ['@astewart87', 'oh', 'gosh', 'made', 'emotional', 'haha', 'idk', 'why!!!', 'dont', 'want', 'get', 'old']
# filtered_tokens ["we're", 'going', 'post', 'stories', 'manually', 'due', 'twitterfeed', 'problem.', "that's", "we've", 'quiet', 'lately']
# filtered_tokens ['like', 'lukewarm', 'showers']
# filtered_tokens ['@linuxfoundation', 'contact', 'need', '1099', 'freelance', 'work', 'linux.com', 'throughout', '2008?', 'never', 'got', 'one.']
# filtered_tokens ['@skylineking722', 'connor,', 'me,', 'febi', 'really', 'really', 'mad', 'me??']
# filtered_tokens ['need', 'help?!', 'want', 'buy', 'macbook', 'pro,', 'still', 'inlove', 'old', 'powerbook!']
# filtered_tokens ['@michaeltao', 'man', 'america', 'borez', 'anyway', 'lol', 'realized', 'sent', 'msgs', 'here.', 'idea.', 'flash']
# filtered_tokens ['@hellivina', '@ihopness', "g'knight", 'lovely', 'ladies.', "i'm", 'sleepy']
# filtered_tokens ['anybody', 'know', 'get', 'electrolytes', 'back', 'order?', 'vitamin', 'work?', 'feel', 'sick.']
# filtered_tokens ['@sudam08', 'yes,', 'someone', 'reading', 'posts', 'properly']
# filtered_tokens ['almost', 'italian', 'homework!', 'weeeeee....', 'understood', 'doing.']
# filtered_tokens ['turned', 'lights', 'on?', 'time', 'get', 'ip']
# filtered_tokens ['@therealnph', 'twitter', 'hates', 'us', 'then.']
# filtered_tokens ['hate', 'fact', "i'm", 'genuinely', 'excited', 'last', 'tweet']
# filtered_tokens ['@celesteclara', "can't", 'sleep', 'either']
# filtered_tokens ['@theblondetheory', 'italy', 'earthquake,', 'sad', 'news', 'day.']
# filtered_tokens ['@champagnemanoir', 'rain', 'today', 'garden', 'really', 'needs', 'quite', 'bad.']
# filtered_tokens ['yawn', 'yawn', 'yawn!!', '10', 'minutes', 'bed']
# filtered_tokens ['@majesticflame', 'ouch', 'sounds', 'sucky']
# filtered_tokens ['@bengottlieb', 'great', 'idea', 'itunes', 'promo', 'codes', 'work', 'uk', 'itunes', 'store', 'though']
# filtered_tokens ['@mattycus', '*cry*']
# filtered_tokens ['@rumlover', 'empty', 'rum', 'barrel', 'sad', 'rum', 'barrel.', '*shakes', 'head*', 'horror,', 'horror.']
# filtered_tokens ['sleepless', 'night']
# filtered_tokens ['@billybush', 'admitted', 'fake']
# filtered_tokens ['@batmannn', 'love', 'chutney......']
# filtered_tokens ['got', 'highly', 'bored', 'today', 'scanning', '24', 'pages', 'daddy.', 'it!']
# filtered_tokens ['@misterphipps', 'cooked', 'risotto', 'without', 'me!!???']
# filtered_tokens ['keeeerrrrriiiiii!!!!', 'really', 'nothing', 'better', 'post', 'thing', '224am.....wonderfullll.', 'says', 'alot.']
# filtered_tokens ['yay', 'baseball', 'season!', 'boo', 'yankees', 'losing', 'first', 'game']
# filtered_tokens ['lost', 'sucks', 'work', 'today']
# filtered_tokens ['omg', 'exams', 'killed', 'could', 'know', 'difference', 'haif', 'circle', 'hemisphere', '&lt;/3', '&gt;']
# filtered_tokens ['bed...', 'suddenly', 'feel', 'wish', 'w/me...', 'goodnight', 'twitterfam']
# filtered_tokens ['@rachelcmrn', 'like', 'goodnights']
# filtered_tokens ['greaaat', 'lappy', 'turn', 'wtffffff']
# filtered_tokens ['@m4rkm', 'stuck', 'traffic', 'then?', 'journey', 'traffic', 'free', 'morning,', 'help.']
# filtered_tokens ['lookin', 'like', 'all-nighter.', 'hate']
# filtered_tokens ['@vernonhamilton', 'stranger']
# filtered_tokens ['debbugging', 'old', 'vb6', 'code,', 'day', 'could', 'started', 'better']
# filtered_tokens ['@toddlington', 'quarter', 'percent', 'babe', 'darn']
# filtered_tokens ['coming', 'cold', 'bad', 'allergies.', 'either', 'way,', "i'm", 'miserable!']
# filtered_tokens ["can't", 'believe', 'cutner', 'dead', 'house!', 'sad', 'day.', 'santa', 'rosa,', 'ca', 'http://loopt.us/orpl3a']
# filtered_tokens ['damnit', 'really', 'digging', 'season', 'reaper', 'http://www.tv.com/story/13720.html?ref_story_id=13720&amp;ref_type=1101&amp;ref_name=story']
# filtered_tokens ['gah,', 'comcast', 'doubled', 'cable/internet', 'bill', 'w/out', 'telling', 'us,', 'quitting.', 'anyone', 'suggest', 'affordable', 'company', 'bay', 'area?']
# filtered_tokens ['another', 'early', 'morn', 'duchess,', 'although', 'managed', 'cross', 'legs', 'time']
# filtered_tokens ['@alexbigman', 'left', 'without', 'saying', 'hi!']
# filtered_tokens ['l', 'want,', "can't", 'sleep']
# filtered_tokens ['@tracydowds', 'xbox', 'shows', 'three', 'red', 'lights,', 'means', 'dead', 'needs', 'fixed', 'month', 'microsoft', 'hq.']
# filtered_tokens ['king', 'sized', 'bed', 'nice', 'sad', 'lonely', 'hubby,', 'puppy,', 'kitty', 'whole', 'conferenceing', 'thing.']
# filtered_tokens ['im', 'boredd.', 'gah', 'wish', 'could', 'sleep', 'get', 'ive', 'toooo', 'muchh', 'cooooffffeeeeeeeee', 'bahaha']
# filtered_tokens ['@whyinthehell', 'may', 'butt', 'again.', "i'm", 'done', 'nosey.', 'sorry', 'conversation', 'interesting!']
# filtered_tokens ['@smokey_robinson', 'fell', 'list...did', 'offend', 'you?']
# filtered_tokens ['18', 'weeks', 'till', 'sisters', 'home..', 'missed', 'call,', 'again!', 'worst', 'feeling', 'world.']
# filtered_tokens ['gonna', 'try', 'get', 'sleep', 'hotel', 'room']
# filtered_tokens ['@chimpytwit', 'brilliant', 'idea.', 'bring', 'much', 'think', 'spend', '&amp;', "i'll", 'swap', 'you.', 'bring', 'brolly']
# filtered_tokens ['@simonekali', 'get', 'autograph', 'shout', 'out!', 'record', 'though.', 'computer', 'dead', "can't", 'listen.']
# filtered_tokens ['rt', '@kimkardashian', 'khloe', 'got', 'fired', 'apprentice']
# filtered_tokens ['biology', 'class.', 'lip', 'hurts']
# filtered_tokens ['sorry', 'next', 'tweet...']
# filtered_tokens ['grr', 'go', 'school', 'today']
# filtered_tokens ['@jennlopez', 'get', 'hd', 'tivo', 'got', 'set', 'tonight', 'order', 'get', 'channels', '40', '59.']
# filtered_tokens ['@mouthsex', 'asked', 'everyone', 'yesterday', 'single', 'tweet', 'back']
# filtered_tokens ['@adame', 'ruddy', 'money!!', 'like', 'it!!', 'still', 'waiting', 'here....', 'oh', 'surprise...', 'state', 'too??', 'hmmm.......', 'seriously!!']
# filtered_tokens ['@kal_penn', 'sad', 'kutner', 'favorite', 'new', 'team!!']
# filtered_tokens ['@marcusmims', 'wow', 'get', '&quot;hello&quot;', 'u', 'suck']
# filtered_tokens ['bedtime,', 'school', 'tomorrow,', 'still', 'books', 'broke', 'suckssss']
# filtered_tokens ['seating', 'helping', 'baby', 'papers...well', 'forcing', 'seat', 'im', 'sleepy']
# filtered_tokens ['synching', 'contacts', 'old', 'mobile', 'iphone.', 'import', 'work', 'well']
# filtered_tokens ["can't", 'concentrate']
# filtered_tokens ["i've", 'spent', '1', 'hour', 'enter', 'bureaucratic', 'nonsense', 'march.', 'waste', 'time']
# filtered_tokens ['nw', 'confused', 'ever!']
# filtered_tokens ['feeling', 'well', 'again.', 'stupid', 'migraine', 'making', 'tummy', 'upset.', 'whole', 'body', 'aches,', 'shoot', 'now.']
# filtered_tokens ['reading', 'buyology', 'bedtime...', 'great', 'premise', 'turning', '&quot;ok&quot;', 'book', 'lots', 'info', 'already', 'knew']
# filtered_tokens ['home!', 'really', 'wana', 'sleep,', 'due', 'wasting', 'free', 'line', 'town', 'assignment', 'finish']
# filtered_tokens ['@hellobebe', 'also', 'send', 'updates', 'plurk', 'upload', 'photos', 'twitter!', 'didnt', 'see', 'updates', 'plurk?', 'zero?']
# filtered_tokens ['omg...', '&quot;the', 'reader&quot;', 'making']
# filtered_tokens ['@cloudpimps', "d'oh!", 'least', 'getting', 'decent', 'exchange', 'rate', 'moment,', 'sterling', 'still', 'getting', 'flogged']
# filtered_tokens ['tried', 'download', 'tweetdeck', 'wont', 'download']
# filtered_tokens ["there's", 'inch', 'snow', 'ground', '(and', 'counting).', "i'm", 'worried', 'poor', 'flowers']
# filtered_tokens ['@dweeman', 'happy', 'camper?']
# filtered_tokens ['@dkoenigs', 'thanks', 'man.', "i'm", 'grateful.', 'feel', 'unworthy', 'attention,', 'though,', "i'm", 'myself...']
# filtered_tokens ['@t_wolfe', 'miss', 'u', 'too.', "i'm", 'totally', 'comin', 'back', 'tho!', 'lastnight', 'sooooooo', 'much', 'fun!']
# filtered_tokens ['@sniffinglue', 'ohhh.', 'love', 'it.', 'ps', "i'm", 'sad', 'get', 'hang']
# filtered_tokens ['somehow', 'still', 'end', 'place']
# filtered_tokens ['@kisluvkis', 'oh', 'sad,', 'poor', 'boy.']

# %% [markdown]
# - <b>Regular expressions (Regex)</b>: Regex are known to have highly optimised algorithms. By choosing the patterns that we want to recognise, it allows us to handle variations better. As such, we will use this to get rid of **links and tagging**.

# %%
stop_words = set(stopwords.words("english"))
symbols = set(string.punctuation)

# Checking removal works on a test text
test_tweet3 = ["modified test that stopword removal works. It will remove @testtry", 
               "http not removed but https://www.youtube.com/ and http://www.youtube.com/ removed"]

def filter_text3(tweets):
    for tweet in tweets:
        # Tokenizing URLs using regular expression
        tweet = re.sub(r"@\S+|(?:http|https)://\S+", "", tweet)
        tokens = tweet.lower().split()
        
        filtered_tokens = [token for token in tokens if not (
            # Removing each token if part of symbols
            all(char in symbols for char in token)
            # Removing each token if part of stop_words
            or token in stop_words
        )]
        
        print("filtered_tokens", filtered_tokens)
        
filter_text3(test_tweet3)
# Out:
# filtered_tokens ['modified', 'test', 'stopword', 'removal', 'works.', 'remove']
# filtered_tokens ['http', 'removed', 'removed']

# %%
# After improvement of stopwords
tweets = tweets_df["tweet"].tolist()
filter_text3(tweets)
# Out:
# filtered_tokens ['awww,', "that's", 'bummer.', 'shoulda', 'got', 'david', 'carr', 'third', 'day', 'it.', ';d']
# filtered_tokens ['upset', "can't", 'update', 'facebook', 'texting', 'it...', 'might', 'cry', 'result', 'school', 'today', 'also.', 'blah!']
# filtered_tokens ['dived', 'many', 'times', 'ball.', 'managed', 'save', '50%', 'rest', 'go', 'bounds']
# filtered_tokens ['whole', 'body', 'feels', 'itchy', 'like', 'fire']
# filtered_tokens ['no,', 'behaving', 'all.', "i'm", 'mad.', 'here?', "can't", 'see', 'there.']
# filtered_tokens ['whole', 'crew']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['hey', 'long', 'time', 'see!', 'yes..', 'rains', 'bit', ',only', 'bit', 'lol', "i'm", 'fine', 'thanks', "how's"]
# filtered_tokens ['nope']
# filtered_tokens ['que', 'muera']
# filtered_tokens ['spring', 'break', 'plain', 'city...', 'snowing']
# filtered_tokens ['re-pierced', 'ears']
# filtered_tokens ['bear', 'watch', 'it.', 'thought', 'ua', 'loss', 'embarrassing']
# filtered_tokens ['counts,', 'idk', 'either.', 'never', 'talk', 'anymore']
# filtered_tokens ["would've", 'first,', 'gun.', 'really', 'though,', 'zac', "snyder's", 'doucheclown.']
# filtered_tokens ['wish', 'got', 'watch', 'you!!', 'miss', 'premiere?!']
# filtered_tokens ["hollis'", 'death', 'scene', 'hurt', 'severely', 'watch', 'film', 'wry', 'directors', 'cut', 'now?']
# filtered_tokens ['file', 'taxes']
# filtered_tokens ['ahh', 'ive', 'always', 'wanted', 'see', 'rent', 'love', 'soundtrack!!']
# filtered_tokens ['oh', 'dear.', 'drinking', 'forgotten', 'table', 'drinks?']
# filtered_tokens ['day', 'get', 'much', 'done']
# filtered_tokens ['one', 'friend', 'called', 'me,', 'asked', 'meet', 'mid', 'valley', 'today...but', "i've", 'time', '*sigh*']
# filtered_tokens ['baked', 'cake', 'ated']
# filtered_tokens ['week', 'going', 'hoped']
# filtered_tokens ['blagh', 'class', '8', 'tomorrow']
# filtered_tokens ['hate', 'call', 'wake', 'people']
# filtered_tokens ['going', 'cry', 'sleep', 'watching', 'marley', 'me.']
# filtered_tokens ['im', 'sad', 'miss.lilly']
# filtered_tokens ['ooooh....', 'lol', 'leslie....', 'ok', 'leslie', 'get', 'mad']
# filtered_tokens ['meh...', 'almost', 'lover', 'exception...', 'track', 'gets', 'depressed', 'every', 'time.']
# filtered_tokens ['some1', 'hacked', 'account', 'aim', 'make', 'new', 'one']
# filtered_tokens ['want', 'go', 'promote', 'gear', 'groove', 'unfornately', 'ride', 'may', 'b', 'going', 'one', 'anaheim', 'may', 'though']
# filtered_tokens ['thought', 'sleeping', 'option', 'tomorrow', 'realizing', 'not.', 'evaluations', 'morning', 'work', 'afternoon!']
# filtered_tokens ['awe', 'love', 'too!!!!', '1', 'miss']
# filtered_tokens ['cry', 'asian', 'eyes', 'sleep', 'night']
# filtered_tokens ['ok', "i'm", 'sick', 'spent', 'hour', 'sitting', 'shower', 'cause', 'sick', 'stand', 'held', 'back', 'puke', 'like', 'champ.', 'bed']
# filtered_tokens ['ill', 'tell', 'ya', 'story', 'later', 'good', 'day', 'ill', 'workin', 'like', 'three', 'hours...']
# filtered_tokens ['sorry!', 'bed', 'time', 'came', '(gmt+1)']
# filtered_tokens ['either.', 'depressing.', 'think', 'even', 'want', 'know', 'kids', 'suitcases.']
# filtered_tokens ['bed.', 'class', '8-12.', 'work', '12-3.', 'gym', '3-5', '6.', 'class', '6-10.', 'another', 'day', "that's", 'gonna', 'fly', 'by.', 'miss', 'girlfriend']
# filtered_tokens ['really', 'feel', 'like', 'getting', 'today...', 'got', 'study', 'tomorrows', 'practical', 'exam...']
# filtered_tokens ["he's", 'reason', 'teardrops', 'guitar', 'one', 'enough', 'break', 'heart']
# filtered_tokens ['sad,', 'sad,', 'sad.', 'know', 'hate', 'feeling', 'wanna', 'sleep', 'still', "can't!"]
# filtered_tokens ['awww', 'soo', 'wish', 'see', 'finally', 'comfortable!', 'im', 'sad', 'missed']
# filtered_tokens ['falling', 'asleep.', 'heard', 'tracy', "girl's", 'body', 'found.', 'sad', 'heart', 'breaks', 'family.']
# filtered_tokens ['yay!', "i'm", 'happy', 'job!', 'also', 'means', 'less', 'time', 'you...']
# filtered_tokens ['checked', 'user', 'timeline', 'blackberry,', 'looks', 'like', 'twanking', 'still', 'happening', 'ppl', 'still', 'probs', 'w/', 'bgs', 'uids?']
# filtered_tokens ['oh', 'man...was', 'ironing', 'fave', 'top', 'wear', 'meeting.', 'burnt']
# filtered_tokens ['strangely', 'sad', 'lilo', 'samro', 'breaking', 'up.']
# filtered_tokens ['oh!', "i'm", 'sorry', 'think', 'retweeting.']
# filtered_tokens ['broadband', 'plan', "'a", 'massive', 'broken', "promise'", 'via', 'www.diigo.com/~tautao', 'still', 'waiting', 'broadband']
# filtered_tokens ['wow,', 'tons', 'replies', 'you,', 'may', 'unfollow', 'see', "friends'", 'tweets,', 'scrolling', 'feed', 'lot.']
# filtered_tokens ['duck', 'chicken', 'taking', 'wayyy', 'long', 'hatch']
# filtered_tokens ['put', 'vacation', 'photos', 'online', 'yrs', 'ago.', 'pc', 'crashed,', 'forget', 'name', 'site.']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['sure', 'are,', 'pos!', 'much', 'want', 'to,', 'dont', 'think', 'trade', 'away', 'company', 'assets', 'sorry', 'andy!']
# filtered_tokens ['hate', 'happens...']
# filtered_tokens ['sad', 'feeling', 'dallas', 'going', 'show', 'gotta', 'say', 'though,', 'think', 'shows', 'would', 'use', 'music', 'game.', 'mmm']
# filtered_tokens ['ugh....92', 'degrees', 'tomorrow']
# filtered_tokens ['u', 'move', 'to?', 'thought', 'u', 'already', 'sd.', 'hmmm.', 'random', 'u', 'found', 'me.', 'glad', 'hear', 'yer', 'well.']
# filtered_tokens ['miss', 'ps3,', 'commission', 'wutcha', 'playing?', 'copped', "'blood", "sand'?"]
# filtered_tokens ['leaving', 'parking', 'lot', 'work!']
# filtered_tokens ['life', 'cool.', 'me.']
# filtered_tokens ['sadly', 'though,', "i've", 'never', 'gotten', 'experience', 'post', 'coitus', 'cigarette', 'before,', 'never', 'will.']
# filtered_tokens ['nice', 'day.', 'bad', 'rain', 'comes', 'tomorrow', '5am']
# filtered_tokens ['bad', 'around', 'lost', 'job', "can't", 'even', 'pay', 'phone', 'bill', 'lmao', 'aw', 'shucks']
# filtered_tokens ['damm', 'back', 'school', 'tomorrow']
# filtered_tokens ['mo', 'jobs,', 'money.', 'hell', 'min', 'wage', '4', "f'n", 'clams', 'hour?']
# filtered_tokens ['forever...', 'see', 'soon!']
# filtered_tokens ['agreed,', 'saw', 'failwhale', 'allllll', 'day', 'today.']
# filtered_tokens ['oh!', 'haha...', 'dude', 'dont', 'really', 'look', 'em', 'unless', 'someone', 'says', 'hey', 'added', 'you.', 'sorry', "i'm", 'terrible', 'that.', 'need', 'pop', 'up!']
# filtered_tokens ["i'm", 'sure', 'right...', 'need', 'start', 'working', 'nikster...', 'jared', 'least!']
# filtered_tokens ['really', 'hate', 'people', 'diss', 'bands!', 'trace', 'clearly', 'ugly!']
# filtered_tokens ['gym', 'attire', 'today', 'was:', 'puma', 'singlet,', 'adidas', 'shorts.......and', 'black', 'business', 'socks', 'leather', 'shoes', 'lucky', 'run', 'cute', 'girls.']
# filtered_tokens ['show', 'location?!']
# filtered_tokens ['picnic', 'phone', 'smells', 'like', 'citrus.']
# filtered_tokens ['donkey', 'sensitive', 'comments.', 'nevertheless,', "he'd", '(and', "me'd)", 'glad', 'see', 'mug', 'asap.', 'charger', 'still', 'awol.']
# filtered_tokens ['new', 'csi', 'tonight.', 'fml']
# filtered_tokens ['think', 'arms', 'sore', 'tennis']
# filtered_tokens ['wonders', 'someone', 'u', 'like', 'much', 'make', 'unhappy', 'split', 'seccond', 'depressed']
# filtered_tokens ['sleep', 'soon...', 'hate', 'saying', 'bye', 'see', 'tomorrow', 'night.']
# filtered_tokens ['got', 'ur', 'newsletter,', 'fares', 'really', 'unbelievable,', 'shame', 'already', 'booked', 'paid', 'mine']
# filtered_tokens ["missin'", 'boo']
# filtered_tokens ['#itm']
# filtered_tokens ['damn...', 'chalk!', 'chalkboard', 'useless']
# filtered_tokens ['blast', 'getty', 'villa,', 'hates', 'sore', 'throat', 'day.', 'getting', 'worse']
# filtered_tokens ['hey', 'missed', 'ya', 'meeting', 'sup', 'mama']
# filtered_tokens ['tummy', 'hurts.', 'wonder', 'hypnosis', 'anything', 'it?', 'so,', 'working,', 'get', 'it,', 'stop', 'smoking!!!']
# filtered_tokens ['always', 'fat', 'ones?!']
# filtered_tokens ['sorry,', 'babe!!', 'fam', 'annoys', 'too.', 'thankfully,', "they're", 'asleep', 'right', 'now.', 'muahaha.', '*evil', 'laugh*']
# filtered_tokens ['paid', 'attention', 'covered', 'photoshop', 'webpage', 'design', 'class', 'undergrad']
# filtered_tokens ['wednesday', 'b-day!', 'know', '2', 'do!!']
# filtered_tokens ['poor', 'cameron', '(the', 'hills)']
# filtered_tokens ['pray', 'please,', 'ex', 'threatening', 'start', 'sh**', 'my/our', 'babies', '1st', 'birthday', 'party.', 'jerk.', 'still', 'headache']
# filtered_tokens ['hmm', 'u', 'really', 'enjoy', 'problems', 'constants', 'u', 'think', 'things', 'find', 'someone', 'ulike']
# filtered_tokens ['strider', 'sick', 'little', 'puppy']
# filtered_tokens ['rylee,grace...wana', 'go', "steve's", 'party', 'not??', 'sadly', 'since', 'easter', 'wnt', 'b', 'able', '2', 'much', 'ohh', 'well.....']
# filtered_tokens ['hey,', 'actually', 'one', 'bracket', 'pools!', 'bad', 'one', 'money']
# filtered_tokens ['follow', 'me,', 'either', 'work', 'you!']
# filtered_tokens ['bad', 'nite', 'favorite', 'teams:', 'astros', 'spartans', 'lose.', 'nite', 't.w.', 'good.']
# filtered_tokens ['body', 'missing', 'northern', 'calif.', 'girl', 'found:', 'police', 'found', 'remains', 'missing', 'northern', 'california', 'girl']
# filtered_tokens ['hope', 'increase', 'capacity', 'fast,', 'yesterday', 'pain.', 'got', 'fail', 'whale', '+15', 'times', '2', 'hours....']
# filtered_tokens ['behind', 'classes', 'work']
# filtered_tokens ['watching', '&quot;house&quot;']
# filtered_tokens ['remember', 'bum', 'leg?', 'strikes', 'back', 'time', 'serious']
# filtered_tokens ['cool,', 'will.', 'kinds', 'complaints', 'laptop', 'online', 'overheating,', 'recalls']
# filtered_tokens ['emily', 'glad', 'mommy', 'done', 'training', 'new', 'job.', 'misses', 'her.']
# filtered_tokens ['would', 'rather', 'first', 'party', 'send', 'bad', 'messages', '3rd', 'party', 'send', 'mixed', 'ones', 'sophmore', 'year', 'again?']
# filtered_tokens ['overrated']
# filtered_tokens ['know!', 'heard', 'afternoon', 'wondered', 'thing.', 'moscow', 'behind', 'times']
# filtered_tokens ['laying', 'bed', 'voice..']
# filtered_tokens ["i'm", 'sooo', 'sad!!!', 'killed', 'kutner', 'house', 'whyyyyyyyy']
# filtered_tokens ['sorry', 'tell', 'mea', 'culpa', 'really', 'sorry.']
# filtered_tokens ['make', 'sense', 'me,', 'suicide', 'thing.', 'refuse', 'believe', 'actually', 'happened.']
# filtered_tokens ['hope', 'ok.']
# filtered_tokens ['damn!', 'grind', 'inspirational', 'saddening', 'time.', 'want', 'stop', 'cuz', 'like', 'u', 'do!', 'much', 'love']
# filtered_tokens ['yeah', 'aw', 'know', 'wudnt', 'stand', 'chance']
# filtered_tokens ['ugh.', 'cant', 'sleep.', '1:30am.']
# filtered_tokens ['hanging', 'crooners.', 'wanna', 'sing.', "can't.", 'sucks.']
# filtered_tokens ['aaw', 'miss', 'ya', 'too..', 'im', 'leaving', 'bh', 'tomorrow', '&quot;morning&quot;', 'think..', 'aww', 'wanna', 'go', 'beach', 'w', 'u', 'girls!!']
# filtered_tokens ['pissed', "there's", "asba's", 'radio', 'station.']
# filtered_tokens ['wednesday', 'b-day', 'n', 'know', '2', 'do!']
# filtered_tokens ['know', 'life', 'flipped', 'upside', 'thought', 'head', 'ramen', 'sounds', 'good.']
# filtered_tokens ['pain.', 'back', 'sides', 'hurt.', 'mention', 'crying', 'made', 'fail.']
# filtered_tokens ['late', 'night', 'snack,', 'glass', 'oj', 'b/c', "i'm", '&quot;down', 'sickness&quot;,', 'back', 'sleep...ugh', 'hate', 'getting', 'sick...']
# filtered_tokens ['but..', 'but..', 'but..', "i'm", 'big', 'fan', 'camilla', 'belle']
# filtered_tokens ['wah', "can't", 'see', 'clip,', 'must', 'el-stupido', 'work', 'filters.', "can't", 'wait', "'till", 'get', "'puter.", 'something', 'else', '2', 'blame', 'ex', '4.', 'broke', 'mine']
# filtered_tokens ['week', 'seems', 'get', 'longer', 'longer', 'terms', 'much', 'need', 'do..', 'much', "i'm", 'actually', 'going', 'get', 'done']
# filtered_tokens ["i'm", 'cold']
# filtered_tokens ['ehhh', "don't.", "weather's", 'gonna', 'take', 'turn', 'ugly', 'tomorrow']
# filtered_tokens ['haha', 'cooooold', 'd!', 'still', 'go', 'show.', 'incredible', 'stuff']
# filtered_tokens ['hoping', 'tummy', 'rumbles', 'go', 'away', 'soon']
# filtered_tokens ['no,', 'notice.', 'told', "i'd", 'working', 'tomorrow,', 'called', 'agency', 'follow', 'said', 'over.']
# filtered_tokens ['almost', 'bedtime']
# filtered_tokens ["i'm", 'missing', 'babe..', 'long', 'alive', "i'm", 'happy..', 'yawwwnn..', "i'm", 'tired', 'love', 'imma', 'try', 'sleep', 'hopefully', 'headstart']
# filtered_tokens ['agh...snow!!!']
# filtered_tokens ['miss', 'kenny', 'powers']
# filtered_tokens ['thank', 'letting', 'people', 'know,', "i'm", 'sad', 'direct', 'message', 'got', 'actually', 'bridget']
# filtered_tokens ['...and,', 'india', 'missed', '100th', 'test', 'victory', 'n', '10th', 'consecutive', 'win', 'without', 'loss.']
# filtered_tokens ['guess', "that's", 'then.']
# filtered_tokens ['sadly', 'going', 'bed.']
# filtered_tokens ['shame', 'hear', 'stephan']
# filtered_tokens ['hey!', "i'm", 'leavin', 'morning...']
# filtered_tokens ['intending', 'finish', 'editing', '536-page', 'novel', 'manuscript', 'tonight,', 'probably', 'happen.', '12', 'pages', 'left']
# filtered_tokens ['laid', 'around', 'much', 'today...', 'head', 'hurts']
# filtered_tokens ['still', 'read', '9th&amp;10th', 'princess', 'diaries', 'saving', 'francesca', 'made', 'cry', 'end.', 'hmm', 'easy', 'books.']
# filtered_tokens ['nokia', '1110', 'died..']
# filtered_tokens ['mom', 'might', 'breast', 'cancer', 'find', 'anything', 'for.', 'like', 'week', "i'm", 'worried!']
# filtered_tokens ['going', 'sleep.', 'hoping', 'tomorrow', 'better', 'day.']
# filtered_tokens ['lol..', 'wish', 'understood', 'daylight', 'savings', 'ended', 'though', 'breakfast', 'hour', 'later', 'keep', 'waking', 'kids']
# filtered_tokens ['lame']
# filtered_tokens ['understand...', 'really']
# filtered_tokens ['heroes', 'season...']
# filtered_tokens ['living', 'downtown', 'sure', 'much', 'fun.']
# filtered_tokens ['calorie', 'wise', 'wish', 'junk', 'food', 'calorie', 'free!', 'ate', 'thing', 'sour', 'skittles', 'big', 'ass', 'cherry', 'coke!']
# filtered_tokens ['man', 'work', 'hard']
# filtered_tokens ['getting', 'sick', 'time', 'hot', 'tea,', 'studying,', 'sleeeep']
# filtered_tokens ['getting', 'eyebrows', 'waxed.', 'pain']
# filtered_tokens ['phantasy', 'star', 'yesterday', 'going', 'work...']
# filtered_tokens ['oh', 'got', 'macheist', '3.0', 'apps', 'sweet.', 'get', 'espresso', 'serial', 'though', 'although', 'said', 'sent', 'oh', 'well']
# filtered_tokens ['picked', 'mich', 'st', 'win', 'get', 'go.', 'feeling', 'pretty', 'good', 'pick', 'way', 'until......tonight.', "a's", 'lost']
# filtered_tokens ['alone', 'downstairs...working']
# filtered_tokens ['feel', 'bad']
# filtered_tokens ['me,', 'hates', 'anoop.', 'mean', 'seriously,', 'kinda', 'mean', 'him.']
# filtered_tokens ['yes', 'sprint', '4g', 'baltimore', 'chicago', 'far']
# filtered_tokens ["i'm", 'stuck', 'awake', 'middle', 'night', 'second', 'day', 'row.', 'felt', 'terrible', 'yesterday.']
# filtered_tokens ['thanks', 'bursting', 'bubble']
# filtered_tokens ['going', 'school', 'soon...', "can't", 'find', 'anything', 'wear!!', 'gosh', 'hard']
# filtered_tokens ['serious', 'lol']
# filtered_tokens ['page', 'sooooo', 'long!!!', 'got', 'deleted', 'sad', 'day', 'history']
# filtered_tokens ['crazy', 'wind', 'today', 'birding']
# filtered_tokens ['currently', 'work..']
# filtered_tokens ['grrr..', 'ipods', 'acting', 'weird', 'too!', 'jai', 'ho', 'thinking', 'playing', 'full', 'songs..', 'ughh.']
# filtered_tokens ['send', 'dvd', 'cos', 'missed', 'heaps', 'happy', 'that!']
# filtered_tokens ['see', 'big', 'deal', 'website']
# filtered_tokens ["i'm", 'sorry', 'go', 'this.', 'again.', '#therapyfail']
# filtered_tokens ['far', 'way', 'rail.', 'tips?']
# filtered_tokens ["i'm", 'still', 'swear.', 'keep', 'losing.', 'gaining.', 'losing.', 'gaining.', 'tweeps?', 'heart', 'wrenching.']
# filtered_tokens ['today', 'realized', 'good', 'hiding', 'things,', 'even', "can't", 'find']
# filtered_tokens ['staying', 'friends', 'house...house', 'sitting,', 'neighbors', 'loud-having', 'party']
# filtered_tokens ['danny', 'im', 'upset', 'wasnt', 'watch', 'live', 'chat', 'car.', '3', 'hours', 'trip', 'im', 'soooo', 'upset!!']
# filtered_tokens ['check', 'mug']
# filtered_tokens ['borders', 'closed', '10']
# filtered_tokens ['downloading', "nin's", 'new', 'album', '&quot;the', 'slip&quot;', 'hell', 'come', 'out?', "i'm", 'behind', 'times', 'days']
# filtered_tokens ['woke', 'already', 'written', 'e-mail...', "i've", 'go', 'early', 'university', 'today', 'teach', '8:30', 'am!']
# filtered_tokens ['watching', 'hill', '.and', 'making', 'sad']
# filtered_tokens ['many', 'channels....', 'yet', 'boring...', 'lazy', 'day', 'may', 'find', 'hobby']
# filtered_tokens ['miss', 'buddy', 'ill', 'ny', '25th']
# filtered_tokens ['love', 'french.', 'tell', 'people', 'south', "i'm", 'qtr.', 'french', 'snarl', 'me.', 'french', 'beautiful', 'people']
# filtered_tokens ['opps..', 'said..', 'still', 'got', 'one', 'day', 'remain', 'problem', 'come']
# filtered_tokens ['activated', 'selfcontrol', 'block', 'early,', 'meaning', "can't", 'check', 'new', 'qc.', 'regularizing', 'internal', 'clock', 'might', 'difficult.', '#fb']
# filtered_tokens ['oh']
# filtered_tokens ['spencer', 'good', 'guy.']
# filtered_tokens ['reese', 'dying', '#ttsc?', 'season', 'finale', 'next', 'week.', '#24', 'boring,', 'madame', 'president', 'crazy', 'woman.']
# filtered_tokens ['hate', 'limited', 'letters,too.hope', 'guys', 'fine?i', 'pray', 'dog,she�s', 'well']
# filtered_tokens ['get', 'shit', 'done', 'today', "i'm", 'screwed']
# filtered_tokens ['wanttss', 'go']
# filtered_tokens ['going', 'sleep', 'tonite.']
# filtered_tokens ['worried', 'tired', 'post', 'tonight']
# filtered_tokens ['get', 'shit', 'done', 'today', "i'm", 'screwed']
# filtered_tokens ['job', 'interview', 'cardiff', 'today,', 'wish', 'luck!', 'got', '3', 'hours', 'sleep']
# filtered_tokens ['show', 'whack.', 'way', 'worse', 'whack,', 'wiggety-whack.']
# filtered_tokens ['really', 'think', 'people', 'choose', 'way.', 'think', 'chose', 'accept', "family's", 'help', 'might', 'dead']
# filtered_tokens ['going', 'kill', 'me,', "i've", 'seen', 'ds9.', "i've", 'waiting', 'till', 'one', 'solid', 'week', 'sitting.']
# filtered_tokens ['think', 'ur', 'right!!', 'hahaha!!', '4.5', 'hrs', 'now!!']
# filtered_tokens ['hate', 'see', 'spartans', 'sad']
# filtered_tokens ['mind', 'body', 'severely', 'protesting', '&quot;getting', 'up&quot;', 'thing.', 'nightmares', 'boot']
# filtered_tokens ["i'm", "goin'", 'follow', 'u,', 'since', 'u', 'lol', 'go', 'angels!']
# filtered_tokens []
# filtered_tokens ['think', 'want', 'read', 'books', 'library']
# filtered_tokens ['nap', 'interrupted', 'many', 'times', 'today', 'going', 'japanese', "'rents", 'again...']
# filtered_tokens ['kind', 'longs', 'bus', 'shows', 'end', 'ghost', 'world', 'right', 'now.', 'ugh.']
# filtered_tokens ['canada', 'canada', 'weird.', "we're", 'supposed', 'get', 'snow', 'wednesday.', 'ugh.']
# filtered_tokens ['awwh', 'babs...', 'look', 'sad', 'underneith', 'shop', 'entrance', "&quot;yesterday's", 'musik&quot;', 'o-:', 'like', 'look', 'new', 'transformer', 'movie']
# filtered_tokens ['sad', "'feet'", 'macbook', 'fell']
# filtered_tokens ["i'm", 'gonna', 'get', 'late', 'tomorrow', '132am', 'here.', 'gonna', 'get', 'tipsy', 'lonesome.', "that's...that's", 'sad']
# filtered_tokens ["i'm", 'sweating', 'forthcoming', 'trip', 'e3.', "can't", 'find', 'someone', 'crash', "i'm", 'there,', 'may', 'screwed.']
# filtered_tokens ['gotten', 'somebody', 'read', 'tweets,', 'cant', 'get', 'make', 'account.']
# filtered_tokens ['omgawd', 'couldnt', 'handle', 'cat', 'heat', 'time', 'd:', 'd:']
# filtered_tokens ['hope', 'make', 'auburn', 'show.', 'looking', 'good']
# filtered_tokens ['*thats', 'people', 'mag', 'haha', 'couldnt', 'fit', 'in..', 'dont', 'think', 'pictures', 'ever', 'made', 'magazine', 'tho!', 'haha']
# filtered_tokens ['congrats!!', 'totally', 'forgot', 'submit', 'photos']
# filtered_tokens ['awww,', 'good', 'luck', 'paula!!', 'please', 'work', 'hard', 'hope', 'fun', 'new', 'album', 'gonna', 'amazing!', 'xxx']
# filtered_tokens ['leaving', '-gets', 'sad-']
# filtered_tokens ['miss', 'twitter.', 'phone', 'broke,', "i'm", 'using', 'stupid', 'nokia', 'phone.', 'ughhh,', 'miss', 'advance', 'phone.']
# filtered_tokens ['shooting', 'outside', 'house', ':o', 'kidding!', 'scared']
# filtered_tokens ['tuesday�ll', 'start', 'reflection', '�n', 'lecture', 'stress', 'reducing', 'techniques.', 'sure', 'might', 'become', 'useful', 'us', 'accompaniers']
# filtered_tokens ['tragedy', 'disaster', 'news', 'week']
# filtered_tokens ['yes', 'yes', 'still', 'trying', 'find', 'picture', 'upload', 'correclty..']
# filtered_tokens ['oh', 'red', 'sox', 'game', 'rained', 'out?', 'looking', 'forward', 'opening', 'day']
# filtered_tokens ['still', "can't", 'find', 'keys.']
# filtered_tokens ['know', 'right.', 'dunno', 'going', 'twitter.']
# filtered_tokens ['might', 'getting', 'sore', 'throat']
# filtered_tokens ['home', 'town.', 'mammy', 'called', 'depressd.', 'pls', 'explain', 'parent', 'let', '8yr', 'old', 'child', 'walk', 'alone?', 'hello?', '2009!']
# filtered_tokens ['think', 'need', 'find', 'better', 'anti-depressants.', 'think', 'paxil/wellbutrin', 'combo', 'losing', 'efficacy.']
# filtered_tokens ['restaurant', 'called', 'woodntap', 'competitive', 'eating', 'tourney', 'round', 'tourney', 'time.', 'place', '2nd']
# filtered_tokens ['bathroom...', 'wake', 'lakin.']
# filtered_tokens ['want', 'tacos', 'margarhitas', 'telll', 'gay', 'say', 'hello&lt;3']
# filtered_tokens ['im', 'lonely', 'keep', 'company!', '22', 'female,', 'california']
# filtered_tokens ['bad', 'day', 'betfair', 'office']
# filtered_tokens ['miss', 'him.', "can't", 'wait', 'celebrate', 'tar', 'heel', 'win', 'weekend', 'though!!']
# filtered_tokens ["i'm", 'really', 'cold.', 'want', 'go', 'sleep', 'yet', "there's", 'nothing']
# filtered_tokens ['4', 'u?', 'officially', '4', 'go', 'round!']
# filtered_tokens ['monkeys???', 'found', 'twin', 'wont', 'even', 'write', 'back.', "i'm", 'heartbroken']
# filtered_tokens ['aww', 'know', 'felt', 'like', 'yesterday', 'work']
# filtered_tokens ['treaty', 'defined']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['poor', 'john', 'happens', 'play', 'fruit', 'microwave!', 'seriously', 'though', 'seen', 'doctor??', 'xxx']
# filtered_tokens ['missing', 'bff', 'watching', 'home', 'away', 'reminds', '&lt;3', 'it.', 'shout', 'u', 'courts']
# filtered_tokens []
# filtered_tokens ['new', 'video', 'card', 'doa.']
# filtered_tokens ['feeling', 'lost,', 'naked', 'confused', '(jk,', 'sort', 'of).....no', 'iphone', 'me.']
# filtered_tokens ['damn', 'late', 'filling', 'appraisal', 'form,', 'people', 'almost', 'sent', 'occupied', 'work']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['think', 'much', 'past.', 'cant', 'change', 'it.', 'deserved', 'much', 'wat', 'got.', '..but', 'still', 'thinking', 'gah']
# filtered_tokens ['lost', 'ring.', 'no-where', 'seen']
# filtered_tokens ['ooooooh!', '*sealclap*', 'see,', 'download', 'shitloads', 'zip', 'folders', '4chan.', 'internet', 'moneys.', 'fuck', 'yeah', 'alicia', '&amp;', 'mikey.']
# filtered_tokens ['still', 'nursing', 'nile', 'glad', 'feeling', 'better.', 'hate', 'baby', 'sick']
# filtered_tokens ['fucked', 'go', 'back', 'ic']
# filtered_tokens ['yoyoyo.', 'internet', 'rude', 'tonight.', 'reconnected', "i'm", 'go', 'bed.']
# filtered_tokens ['well', 'uni', 'stuff', 'netball', 'netbal', "i've", 'done', 'uni', 'stuff']
# filtered_tokens ['poor']
# filtered_tokens ['help', 'forget', '8th', 'april', '&amp;', '13th', 'july!']
# filtered_tokens ['dierks', 'bentley', "comin'", 'columbus,', 'oh!!', 'wanna', 'go', 'bad']
# filtered_tokens ['take', 'sidekick', 'back.']
# filtered_tokens ['congrats!', "i'm", 'totally', 'jealous!', 'wish', 'xm', 'working']
# filtered_tokens ['gr8t', 'face', 'itchy']
# filtered_tokens ['poor', 'socks', 'luvvvvv', 'golden', 'retriever!!', 'want', 'one', 'sighhhh']
# filtered_tokens ['saw', 'found', 'tracy', 'girl', 'piece', 'luggage...', 'fucking', 'terrible']
# filtered_tokens ['aaaaand', 'nausea', 'back.']
# filtered_tokens ['ooh', 'i�m', 'excited', 'even', 'going', '2', 'long', 'love', 'youtube!']
# filtered_tokens ['spent', '1', 'hour', 'reach', 'axis', 'bank', 'find', 'today', 'holiday', 'mahavir', 'jayanti', 'contd..']
# filtered_tokens ['agree...', 'jobros', 'dont', 'update', 'theres', 'often']
# filtered_tokens ['hilarious', 'linked', 'clip', 'lj', 'time', 'ago', 'went', 'back', 'dead', 'link']
# filtered_tokens ['oooooooo', 'with?', '(im', 'neither', 'thats', 'need', 'study']
# filtered_tokens ['tweeted', 'nearly', 'day', 'posted', 'website', 'tonight,', 'hopefully', 'goes', 'well', 'night', 'time!']
# filtered_tokens ['miss', 'bentley']
# filtered_tokens ['seriously', 'needs', 'finish', 'job', 'applications']
# filtered_tokens ['son', 'vincas', 'sick,', 'stay', 'home', 'three', 'tense', 'days', 'work,', 'back', 'holiday', 'kids']
# filtered_tokens ['whinging.', 'client&amp;boss', 'understand', 'english', 'well.', 'rewrote', 'text', 'unreadable.', 'written', 'v.', 'good', 'writer&amp;reviewed', 'correctly.']
# filtered_tokens ['want', 'ever', 'punch', 'me.']
# filtered_tokens ['sooo', 'sick', 'snow', 'ughh']
# filtered_tokens []
# filtered_tokens ['work', 'fan', 'upset']
# filtered_tokens ['would', 'like', 'apologize', 'repeated', 'video', 'games', 'live', 'related', 'tweets.', 'going', 'stern', 'discussion', 'koodo', 'soon.', 'stern.']
# filtered_tokens ['cant', 'figure', 'get', 'back', 'pay', 'hotel', 'etc']
# filtered_tokens ['fml:', 'much', 'seniority,', 'bc', 'technological', 'ineptness,', '&quot;register&quot;', 'classes']
# filtered_tokens ['feels', 'like', 'slept', 'day', 'away.', 'looking', 'forward', 'bouts', 'gallbladder.', 'least', 'pills', 'pain.']
# filtered_tokens ['really', 'want', 'old', 'bass', 'back']
# filtered_tokens ['mad', 'tired', 'today...', 'callin', 'early', 'tonight', 'nighty', 'night', 'twittas']
# filtered_tokens ['take', 'easy,', 'good', 'you.']
# filtered_tokens ["i'm", 'afraid', 'bad', 'code.']
# filtered_tokens ['think', "i'm", 'going', 'bed.', 'goodniight.', 'hate']
# filtered_tokens ["i'm", 'here,', 'friend,', 'love', 'you.']
# filtered_tokens ['time', 'notice', 'gone...just', 'needed', 'db2', 'it??']
# filtered_tokens ['bathroom', 'pee!']
# filtered_tokens ['wanted', 'margarita', 'too!']
# filtered_tokens ['yup', 'night', 'workouts', 'r', 'worst', 'unfortunetly', 'work', 'schedule', 'allows', 'go', 'night', 'tough!']
# filtered_tokens ['called', 'hillsong', 'said', 'tell', 'waiting', 'list', 'know', 'looking', 'good']
# filtered_tokens ['0g', 'milky', 'bar', 'left,', 'around', '200ml', 'coke']
# filtered_tokens ['stillllll', 'arrived']
# filtered_tokens ['mraow,', 'feel', 'like', 'dancing,', 'first', 'art', 'school', 'wants', 'rape', 'more.']
# filtered_tokens ['ah!', 'bet', "i've", 'like', 'craving', 'play', 'softball', 'basketball', 'noo', 'time']
# filtered_tokens ['terrified', 'accidentally', 'deleted', 'reference', 'management', 'assignment', 'hopes', 'doesnt', 'get', 'trouble', 'gets', 'back']
# filtered_tokens ['amazon', 's3', 'plugin', 'worked', 'website', 'need', 'php', '5', 'hosting', 'provider', 'php', '4.4', 'sad.']
# filtered_tokens ['argh!', 'suuuper', 'sleepy', 'hour', 'ago,', "i'm", 'wide', 'awake.', 'hope', 'stay', 'night.']
# filtered_tokens ['wish', 'was!', 'sold', 'time', 'let', 'know,', 'would', 'love', 'hear', 'to!']
# filtered_tokens ['watched', 'tropic', 'thunder.', 'dreading', 'tomorrow']
# filtered_tokens ["no...he's", 'still', "miss'n..."]
# filtered_tokens ['chiefdelphi']
# filtered_tokens ['according', 'bro,', 'new', 'puppy', 'poo', 'fight', 'covered', 'poop', '(picture', 'stolen', 'him)']
# filtered_tokens ['playing', 'game', 'home!', 'new', 'boss', 'call', 'yet...']
# filtered_tokens ['su', 'yin', 'huen', 'tweeted', 'feel', 'unbearable', 'guilt.', 'made', 'staff', 'cry']
# filtered_tokens ['poor', 'joshy', 'sick???', 'damn', 'tejanos!']
# filtered_tokens ['thoughts', 'sandra', "cantu's", 'family', 'difficult', 'sad', 'time']
# filtered_tokens ['know,', 'wanted', 'let', 'everybody', 'know', 'happening']
# filtered_tokens ['michigan', 'who?', 'know', 'them.', '*sigh*', 'shameful!']
# filtered_tokens ['fill', 'two', 'hours']
# filtered_tokens ['cuuute!', 'hey,', 'miss', 'na!', 'seeing', 'girls', 'everyday']
# filtered_tokens ['oh!', 'mention', 'it?', '&quot;gooooood', 'moooorniiiiiiing&quot;', 'germany!', 'im', 'back', 'cage....or', 'better...my', 'office']
# filtered_tokens ['throat', 'closing', 'string', 'cheese.', 'good', 'idea']
# filtered_tokens ['aww,', 'sandra', 'cantu', 'found', 'dead', 'suitcase', 'missing', 'children', 'stories', 'never', 'seem', 'go', 'good.', 'poor', 'family.']
# filtered_tokens ['wishing', 'home', 'underneath', 'covers']
# filtered_tokens ['walking', 'home', 'school', 'drains', 'energy']
# filtered_tokens ['agree.', 'shapeshifting', 'copout.', 'excited', "angela's", 'ep,', 'thought', 'week.', 'noah', 'awesome', 'tho!']
# filtered_tokens ['dang!', 'would', 'done', 'knew', 'earlier.', 'outings', 'planned?']
# filtered_tokens ['wish', 'better', 'writing.', 'taking', 'long', 'write', 'paper.']
# filtered_tokens ['..and', 'course...', 'access', 'halo', '3', 'mythic', 'map', 'pack', 're-download..', 'bad', 'news..', 'legendary', 'map', 'pack...', 'ugh..', '600ms...']
# filtered_tokens ['...not', 'yet', 'unfortunately,', 'another', 'weeks', "i've", 'told', 'you?', "i've", 'little', 'bit', 'busy', 'latest', 'project.']
# filtered_tokens ['ha', "sun's", 'already', 'gone']
# filtered_tokens ['day', '2.', 'lot', 'harder', 'day', '1.', "let's", 'see', 'day', '3', 'goes', 'tomorrow.']
# filtered_tokens ['man', 'crush', 'jake', 'peavy', 'let', '#gayforpeavy']
# filtered_tokens ['megafast', 'trip,', 'time', 'day', 'tom/weds?', 'or,', 'going', 'tonight?', 'want', 'see', 'bad.', 'tried', 'warn', 'you,', 'tech', 'fail']
# filtered_tokens ['michigan', 'state', 'make', 'sad']
# filtered_tokens ['omg.', 'mouth', 'much', 'pain', 'wanna', 'sleep', 'untill', 'time', 'take', 'braces', 'off.']
# filtered_tokens ['getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biofuel', 'proposal:', 'getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biof..']
# filtered_tokens ['hey', 'girl.', 'site', 'back.', 'girlyvue', 'back', 'even', 'videos.']
# filtered_tokens ["i'm", 'spending', 'time', 'grandma', 'early', 'tomorrow', "can't", 'leave', 'skittles', 'herself.']
# filtered_tokens ['got', 'home', 'watching', 'michigan', 'state', 'get', 'tromped!']
# filtered_tokens ['oh', 'jew-bus!', 'two', 'years', 'worth', "classes'", 'work', 'alot', 'organize', '&gt;_&lt;', "i'm", 'finishing', 'tonight,', 'possible...my', 'bones', 'ache']
# filtered_tokens ['exchanging', 'me,', 'laptop', 'arrived']
# filtered_tokens ['hope', 'last', 'long.', 'feel', 'miserable!']
# filtered_tokens ['rachel!', 'hang', 'outage', 'neccessary', 'gonna', 'home', 'wekend', 'dumb', 'folk', 'make', 'work', 'im', 'free', 'f', 'sat', '4...']
# filtered_tokens ['fun', '&amp;', 'furious?', 'new', 'mantra', 'bay', '2', 'breakers?', 'getting', '2', 'rambunctious;the', 'city', 'overreacted', '&amp;', 'clamped']
# filtered_tokens ['hubby', '(for', 'reason)', 'thinks', 'important', 'good', 'spot', 'red', 'carpet', 'trek', 'movie', 'premiere.', 'sod!']
# filtered_tokens ['swear', 'matter', 'long', "i've", 'getting', '5am,', 'never', 'gets', 'easier.', 'man', 'eyes', 'hurts', 'wah']
# filtered_tokens ['jeffree!', 'keep', 'hair', 'one', 'color?', 'permanent', 'dye', 'fades', 'within', 'week']
# filtered_tokens ['reaction', 'whoa,', 'see', 'coming']
# filtered_tokens ['still', 'sick.', 'feeling', 'bit', 'better,', 'got', 'new', 'medicine....', 'hope', 'feel', 'good', 'night', 'sleep.', 'ohh,', 'suppose', 'snow!', 'wtf!']
# filtered_tokens ['think', 'maybe', 'get', 'couple', 'hours', 'sleep,', 'hon.', 'productive', 'right', 'ur', 'dog', 'tired?', 'worry']
# filtered_tokens ['thanks', 'lot.', 'learned', 'lot', 'new', 'words', 'find', 'looking', 'for.']
# filtered_tokens ['wish', 'xblm', 'downloads', 'gamertag', "'hitokyri'.", '5', 'gamertag', 'thing', 'nonsense...', "i'm", 'tired']
# filtered_tokens ['new', 'testament', 'test', '9:30']
# filtered_tokens ['tons', 'hay', 'troll?', 'ahhhh']
# filtered_tokens ['stupid', 'movies', 'watched...', 'mirrors', 'ugggggh...', 'stooopeeed!!!', 'rip', 'off!']
# filtered_tokens ['love', 'you,', 'buck.']
# filtered_tokens ['last', 'one!!!', 'still', 'done!!!']
# filtered_tokens ['homework....']
# filtered_tokens ['understand', 'things', 'get', 'taken', 'away.', 'enough', 'time', 'unfair.', 'want', 'back!!', 'like', 'baby']
# filtered_tokens ['scratch', 'that:', 'du', 'heif', '(two', 'half)', 'cookies.', 'tum', "can't", 'take', 'anymore', 'shoog.', 'poots']
# filtered_tokens ['listening', 'sweets', 'first', 'time', 'forever!', 'miss', 'much', 'go', 'chi', 'town', 'visits', 'plz?']
# filtered_tokens ['geez', 'busy', 'afternoon.', 'meetings,', 'emails,', 'meetings', 'email', 'meetings.', '6pm', 'day', 'still', 'going!', 'ah', 'dark']
# filtered_tokens ['dang!!!', 'another', 'spring', 'break!!!', 'cool', 'that???', 'bad', 'work', 'week', 'oh', 'well,', 'money', 'phone.', 'ttyl', 'everbody!!!']
# filtered_tokens ['im', 'afraid', 'ur', 'reply', 'uni', 'ages', 'ago']
# filtered_tokens ['feeling']
# filtered_tokens ['lol', 'emotional', 'ass', 'men!!', 'omg', 'late', 'night', 'eating..', 'us', 'broke']
# filtered_tokens ['aww', 'nick!!', 'like', 'hair', 'longer,', 'cut', 'off?', 'break.', 'my.', 'heart.']
# filtered_tokens ['wonder', 'jon', 'lost', 'net']
# filtered_tokens ['wow.', 'depressing', 'thing', 'world', 'losing', 'video', 'created', 'matter', 'seconds.', '#fml']
# filtered_tokens ['says', 'stock']
# filtered_tokens ['lmao', 'im', 'sorry', 'poohpot', 'ate', 'all!']
# filtered_tokens ['chance', 'softbelly', '(for', 'loud?']
# filtered_tokens ['time', 'move', 'posterior', 'lose', 'fat.', 'articulation', 'creaking', 'running', 'i�m', 'drool', 'swimming']
# filtered_tokens ['listening', 'nathan', 'cry....']
# filtered_tokens ['today', 'sucked.', "i'm", 'gonna', 'die', 'without', 'chris', 'callum!', 'wahhh!']
# filtered_tokens ['stou', 'site', 'update,', 'info', '2/2552', 'exam,', 'open', 'course,', 'must', 'wait', 'mail', 'notices', 'doc.', 'um...']
# filtered_tokens ['sorry.', "i'm", 'feeling', 'kinda', 'yucky', 'myself.', '5am', 'going', 'come', 'quick']
# filtered_tokens ['love', 'scrappy', 'missin', 'already']
# filtered_tokens ['wants', 'hear', "'s", 'song', 'myspace', 'messing']
# filtered_tokens ['bad', 'news', 'dad', 'cancer', 'dying', 'good', 'news', 'new', 'business', 'started', 'life', 'coach', 'practising', 'holistic', 'weight', 'management']
# filtered_tokens ['man...', 'intervention', 'soo', 'sad']
# filtered_tokens ['help!', 'need', 'new', 'boyfriend...', "i'm", 'stuck', 'rut']
# filtered_tokens ['feel', 'like', 'complete', 'idiot.', "i'm", 'one', 'get', 'shit', 'works', 'help']
# filtered_tokens ['saw', 'ad', 'craigslist', 'casting', 'call', 'female', 'host', 'g4.', 'totally', 'psyched!', 'realized', 'hoax']
# filtered_tokens ['pepperoni', 'rolls', 'l.a.?:', 'called', "valentino's", 'said', 'sausage', 'rolls', 'pepperoni', 'rolls']
# filtered_tokens ['yes,', 'be.', 'monday']
# filtered_tokens ['want', 'new', 'gg', 'episode', 'already']
# filtered_tokens ['miss', 'watching', "rocko's", 'modern', 'life.']
# filtered_tokens ['rip', 'sandra....its', 'sad', 'someone', 'something', 'like', 'that??']
# filtered_tokens ['keeping', 'fingers', 'crossed', 'buddy', 'feeling', 'well.']
# filtered_tokens ['wait', 'eat??', 'skinny', 'vegas!!', "i'm", 'hungry!']
# filtered_tokens ['tried', 'tweetdeck', 'hated', 'passion.', 'hated', 'me,', "i'm", 'sure...']
# filtered_tokens ['btw', 'iphone', 'acting', 'funny,', 'dying', 'quickly', 'freezing', 'bs.', "i'm", 'admitting', 'anything,', 'sayin']
# filtered_tokens ['sitting', 'wondering', '&quot;ed&quot;', 'still', 'strong', 'hold']
# filtered_tokens ['im', 'sorry', 'got', 'sick.', 'lol.', 'going', 'bed', 'too.', 'night!']
# filtered_tokens ['internet', 'home,', 'drive', 'ox', 'use', 'internet', 'builders!']
# filtered_tokens ['weather', 'canada', 'freezing']
# filtered_tokens ['twiggassssssss', 'range', 'day', "i'm", 'back', 'hopefully', 'good.']
# filtered_tokens []
# filtered_tokens ['anyone', 'reads', 'pray', 'grandma.', 'pain']
# filtered_tokens ['#3', 'woke', 'accident', "&quot;it's", 'pushing,', 'pushing!&quot;', 'crying', 'stop', 'wetting', 'pants.']
# filtered_tokens ['home', 'franklin', 'street,', 'almost', 'jumped', 'fire.', 'someone', 'kicked', 'could.', 'jenny', 'lost', 'shoe.']
# filtered_tokens ['hey!', 'changed', 'default.']
# filtered_tokens ['finally', 'gave', 'bored', 'enough', 'start', 'thing.', 'think', '140', 'going', 'problem', 'tho.', 'like', 'myspace', 'status.']
# filtered_tokens ['oooonly', 'really', 'lucky,', 'eh?', 'awh', 'definitely', 'early', 'work.']
# filtered_tokens ['buttload', 'homework!']
# filtered_tokens ['needs', 'another', 'copy', 'visual', 'studio', '2008']
# filtered_tokens ['we,', 'school', 'world,', 'week.my', 'school', 'silly', 'anyway...', 'look', 'bright', 'side.', "i'm", 'off,', 'u']
# filtered_tokens ['omg', "i've", 'economics', 'test.', 'dont', 'know', 'things', 'know', 'omg', 'im', 'gonna', 'fail']
# filtered_tokens ['upon', 'time', 'hundred', 'islands', 'pride', 'philippine', 'tourism,', 'coral/clam/rare', 'fish', 'poaching', 'in.', 'kinda', 'sad']
# filtered_tokens ['yeah,', 'apparently', 'really', 'bad', 'taste']
# filtered_tokens ['know!', 'really', 'surprised', 'since', 'everyone', 'recommends', 'youtube.', 'call', 'tomorrow', 'figure', 'out.']
# filtered_tokens ['waiting', 'airport', 'ride', 'get', 'harassed', '2', 'men', 'trying', 'sell', 'ugly', 'hats..', 'me?!', 'want', 'sleep..']
# filtered_tokens ['left', 'ids', 'location', 'go', 'bars', 'fuckkkkkkkkkkkkk']
# filtered_tokens ["i'm", 'sorry', 'understand', 'last', 'comment']
# filtered_tokens ['announcement?', 'stayed', 'late', 'last', 'night']
# filtered_tokens ['strange,', 'illegal', 'torrents', 'avlbl', 'everywhere,', 'legal', 'dvd', 'stock', 'now???']
# filtered_tokens ['enough', 'say', 'imiss', 'u']
# filtered_tokens ['trolley', 'packed', 'like', 'sardines!', 'padre', 'game', 'remove', 'car?!', 'good', 'call', 'mts']
# filtered_tokens ['jeez,', 'trying', 'help', 'haha.']
# filtered_tokens ['happened', 'saturday', 'night.', 'along', 'glittery', 'green', 'lighter!']
# filtered_tokens ['trying', 'reduce', 'number', 'cigarettes', 'day!']
# filtered_tokens ['yea', 'quiet', 'around', 'cuz', 'everyone', 'work', 'im', 'bored', 'death', 'nobody', 'talk']
# filtered_tokens ['gotta', 'cooking', 'assignment', 'hard']
# filtered_tokens ['okay,', 'applepears,', "i've", 'talked', 'people', "they've", 'before.', 'one', 'ever', 'told', 'me,', 'never']
# filtered_tokens ['know!', "i'm", 'night', 'owl', 'nature,', 'hahaha', 'time', 'zone', 'behind', 'you?', 'almost', '1']
# filtered_tokens ['lol', 'nope!', 'complete', '#camerafail']
# filtered_tokens ['but!', "i'm", 'useless', 'sleep', 'fair!', 'want', 'fun', 'well!!!']
# filtered_tokens ['pookie', 'uti.', 'nurse', 'gabbie', 'get', 'back', '100%!!!', 'sodas!!!!!!!!!!!!!!']
# filtered_tokens ['tweet', 'something', 'damn', 'it!', 'hang', 'please?']
# filtered_tokens []
# filtered_tokens ["i'm", 'behind', 'video', 'games,', 'everything', 'matter.', "i'm", "yesterday's", 'news']
# filtered_tokens ['did,', 'one', 'left', 'got', 'tempted', 'ate', 'soon', 'got', 'home', 'chocolate', 'velvet', '&amp;', 'ate', 'mocha']
# filtered_tokens ['stressing', 'blackberry', 'keeps', 'flashing', 'red', 'alert', 'status', 'reason!!', 'faking', 'hate', 'it!!!']
# filtered_tokens ['wanna', 'wear', 'doc', 'martens', 'out!', 'worn', 'since', 'december.']
# filtered_tokens ['shoe', 'repair', 'shop', 'guy', 'could', 'find', 'shoes!', 'go', 'back', 'see', 'find', 'couple', 'days.']
# filtered_tokens ['really', 'see', 'coming']
# filtered_tokens ['woke', 'vivid,', 'sketchy,', 'not-cool', 'dreams', 'life.', 'time', 'stare', 'wall', 'lights', 'on.']
# filtered_tokens ["it'll", 'take', '3', 'days', 'sister', 'get', 'passport']
# filtered_tokens ['oh', 'yes!!', 'miss']
# filtered_tokens ['uh', 'oh...', 'think', 'getting', 'sick']
# filtered_tokens ['good', 'god', 'ruined', 'belly', 'button!!!']
# filtered_tokens ['watching', 'framed', 'roger', 'rabbit.', 'makes', 'miss', 'toon', 'town.']
# filtered_tokens ['renting..', 'cheap', 'renting,', 'awesome', 'house.', '3', 'buying', 'attempts', 'fall']
# filtered_tokens ['running', 'nose', 'spinning', 'head', 'good', 'combination', 'meeting!']
# filtered_tokens ['negative..', 'lost', 'vote', 'confidence']
# filtered_tokens ['nasty', 'budget', 'due', 'iphone', 'sent', 'apple', 'today.']
# filtered_tokens ['that�s', 'bad']
# filtered_tokens ['dammit,', 'episode', '3', 'kings', 'play', 'reason', 'stopped', 'middle', 'anything']
# filtered_tokens ["i'm", 'upset', 'missed', 'chat', 'quiz', 'online', 'free', 'internet', 'ceased']
# filtered_tokens ["can't", 'believe', 'it!', "i'm", 'disbelief', 'way', 'really.', 'much', 'take', 'people', 'always', 'get', 'hurt', 'others!!']
# filtered_tokens ['car', 'show', 'season', 'started', 'without']
# filtered_tokens ['throat', 'raw.']
# filtered_tokens ['get', 'it.', 'persons', 'mind', 'could', 'even', 'ish', 'like', 'this???', 'prayers', 'fam', 'real']
# filtered_tokens ['hate', 'you.', 'need', 'see', 'that.', 'need', 'call', 'therapist', 'now.']
# filtered_tokens ['twilight', 'come', 'yesterday', 'fingers', 'crossed', 'today']
# filtered_tokens ['glad', 'able', 'help', 'feel', 'better.', 'hate', 'see', 'sick', 'love', 'you!']
# filtered_tokens ['tireddddddd.', 'want', 'sleep', 'assignment', 'finish', 'exam', 'tomorrow', 'study']
# filtered_tokens ['know,', 'thinking...', 'need', 'money']
# filtered_tokens ['omg..its', 'jst', 'teusday']
# filtered_tokens ['ummmmm', 'cant', 'find', 'it.']
# filtered_tokens ['heard', 'found', 'sandra', 'cantu...', '8', 'yrs', 'old']
# filtered_tokens ['ive', 'forgotten', 'snoo-snoo', 'wonder', 'snoo-snoo', 'ever', 'meet', 'again...']
# filtered_tokens ['wow', 'last', 'tweet', 'made', 'seem', 'like', 'giant', 'sexist...sorry']
# filtered_tokens ['bathtub', 'drain', 'fired:', 'haz', '1', 'job', '2', 'do,', '&amp;', 'iz', 'fail.', 'got', 'drano', 'ass,', '&amp;', 'iz', 'still', 'draining.', 'wanna', 'shower,', 'dangit!!']
# filtered_tokens ['stuck', 'home']
# filtered_tokens ['mine', '1/10', 'get', 'up?']
# filtered_tokens ['duckling', 'famous', "children's", 'book', 'stolen', "boston's", 'public', 'garden', 'boston', 'globe', 'via', 'oh', 'no!!']
# filtered_tokens ['thank', 'you!', 'however,', 'hate', 'list', 'includes', '2', 'convicts.']
# filtered_tokens ['heading', 'altrincham,', 'again!', 'hours', 'install']
# filtered_tokens ['morning!!!', 'good', 'im', 'bloody', 'knackered!!!', 'work', 'today', 'helppp!!!!', 'xxx']
# filtered_tokens ['garage.', 'park', 'driveway!']
# filtered_tokens ['happened?']
# filtered_tokens ['&quot;on', 'popular', 'music&quot;', 't.w.adorno', 'probably', 'difficult', 'reading', 'ever', 'prescribed,', "i'm", 'actually', 'struggling', 'continue']
# filtered_tokens ['cant', 'see', 'flowers', 'falling', 'dont', 'camera,', 'cellphone']
# filtered_tokens ["we've", 'good.', "i'm", 'liking', 'snow', 'right', 'now,', 'getting', 'used', 'nice', 'spring-like', 'weather.', 'you?']
# filtered_tokens ['pity', 'youtube', 'currently', 'blocked', 'china.', "can't", 'see', 'vids.']
# filtered_tokens ['happened', 'show', 'hightlight', 'life']
# filtered_tokens ['best', 'leather', 'sofa', 'world!', 'office', 'though', 'means', "i'm", 'still', 'working']
# filtered_tokens ['still', '3', 'days', 'internet', 'gets', 'uncapped']
# filtered_tokens ['get', 'better', 'days,', 'could', 'something', 'lodged', 'belly']
# filtered_tokens ['love', 'atekinzz', 'much.', '&amp;&amp;', 'soo', 'miss', 'her..']
# filtered_tokens ['wanna', 'sneak', 'zoo', 'play', 'kitties']
# filtered_tokens ['oh', 'hope', 'getting', 'sick', 'too!']
# filtered_tokens ['dont', 'think', 'cause', 'cousins', 'birthday', 'party']
# filtered_tokens ['sweet', 'little', 'man', 'fell', 'asleep', 'waiting', 'daddy', 'big', 'brother', 'get', 'home!', 'poor', 'baby,', 'missed', 'much', 'today!']
# filtered_tokens ['angel', 'going', 'miss', 'athlete', 'weekend']
# filtered_tokens ['trust', 'hard']
# filtered_tokens ['watched', 'considering', 'today.', 'yaknow.', 'shawnna', 'tomomorrow;i', 'need', 'bestfriend']
# filtered_tokens ['grr', 'want', 'keep', 'reading', 'wont', 'anything', 'left', 'read']
# filtered_tokens ['atekinzz,', 'world', 'you??']
# filtered_tokens ['no!', 'u', 'supposed', 'date']
# filtered_tokens ['pears', '&amp;', 'brie,', 'bottle', 'cabernet,', '&quot;win', 'date', 'tad', 'hamilton&quot;...', 'oh', 'gawwd', 'life', 'flashed', 'forward', "i'm", '40', '75', 'cats']
# filtered_tokens ['crap.', 'need', 'dresses', 'too.']
# filtered_tokens ['yeah!', 'know!', 'horrible!!!!', 'ugh.', 'saddening.']
# filtered_tokens ['geez', 'ur', 'fun']
# filtered_tokens ['wanna', 'punk', 'rock', 'band']
# filtered_tokens ["that's", 'lot', 'angst', 'tuesday', 'afternoon']
# filtered_tokens ["i'm", 'glad', 'britney', 'crazy', 'anymore!', 'one', 'hell', 'show!', "i'm", 'sad', 'over.', 'next', 'up...ap', 'cook', 'county!']
# filtered_tokens ['huuuge', 'headache!', 'omg', 'feel', 'like', 'crap!']
# filtered_tokens ['sorry']
# filtered_tokens ['sorry...i', 'rooting', 'too...']
# filtered_tokens ['man,', 'took', 'forever.']
# filtered_tokens ['see.']
# filtered_tokens ['listing', 'items', 'ebay', 'sell!', 'takes', 'forever..meanwhile', 'coleman', 'watching', 'hills', 'season', 'premier', 'without', 'me..']
# filtered_tokens ['got', 'presentation', 'done,', '23', 'slides', 'done...', "i'm", 'crying', 'week', 'hardest', 'weeks.']
# filtered_tokens ['lost', '$160']
# filtered_tokens ['like', 'previously', 'skins', 'thing', 'starts', 'season', 'two.', 'like', 'went', 'straight', 'intro', 'like']
# filtered_tokens ['...i', 'wish', "there...i'm", 'pretty', 'good', 'scaring', 'shit', 'people']
# filtered_tokens ['going', 'sound', 'vain...', 'running', 'fav', 'lip', 'gloss']
# filtered_tokens ['never', 'click', 'link', 'screams,', "&quot;i'm", 'spider,', "i'm", 'spider&quot;.', 'known', 'better.', 'yucky']
# filtered_tokens ['time', 'work', 'get', 'sick?']
# filtered_tokens ['imac', 'came', '$320', 'indonesia', 'states.']
# filtered_tokens ['dammit...', 'need', 'stop', 'buying', 'furniture']
# filtered_tokens ['half', 'asleep', 'turned', 'laptop']
# filtered_tokens ['death', 'peaceful,', 'life', 'however,', 'bites']
# filtered_tokens ['think', 'lost', 'net', 'sure', 'hope']
# filtered_tokens ['test', 'footage', 'girlfriend', '(in', 'hd)', 'dark', 'one', 'underxposed']
# filtered_tokens ['tough', 'game', 'watch', 'tonight', 'state', 'finally', 'going', 'bed', 'also', 'staying', 'watch', 'season', 'premiere', 'hills!']
# filtered_tokens ['seems', 'jruby', 'support', 'hpricot', 'two', 'versions', 'behind']
# filtered_tokens ['unlike', 'sister...i', 'still', 'one']
# filtered_tokens ['fraking', 'app', 'store', 'pissing']
# filtered_tokens ['logging', 'out.', 'need', 'study....']
# filtered_tokens ['anyone', 'else', 'problems', 'accessing', 'ttb???', 'cant', 'get', 'on!!!']
# filtered_tokens ['strongly', 'dislike', 'people', 'make', 'stupid', 'comments', 'dont', 'know', 'whole', 'story']
# filtered_tokens ["i'm", 'sorry', 'emma,', 'swarley', 'goldfish?', "i'm", 'sad', 'u.']
# filtered_tokens ['tweets', 'already', 'gone,', 'missed', 'guys', 'tonight.']
# filtered_tokens ["can't", 'sleep', 'again.', 'face', 'kinda', 'swollen.', 'let', 'allergic', 'thing', 'get', 'thursday.', 'school', 'tomorrow?', 'doubtful.']
# filtered_tokens ["izzy's", 'cat', 'tree,', "she'll", 'stare', 'down,', 'floor,', 'chases', 'runs.']
# filtered_tokens ['officially', 'banning', 'godaddy.com', 'comp.', 'head', 'hurts', 'small', 'print', 'wasted', '$10', "could've", 'happily', 'gone', 'boba']
# filtered_tokens ['pretty', 'much', 'scary']
# filtered_tokens ['mines', 'too...', "i'm", 'finding', 'well', 'hard', 'get', 'fit...']
# filtered_tokens ['good', 'morning!', 'ready', '2', 'go,', 'want', '2', 'go', 'back', '2', 'bed']
# filtered_tokens ['hates', 'waiting', 'mails']
# filtered_tokens ['wheat', 'bread', 'dollar', 'store', 'toast', 'nicely', 'going', 'taxes', 'calling', 'early', 'night']
# filtered_tokens ['kutner?', 'mean', 'knew', 'something', 'going', 'happen', 'someone', 'sad.', '&lt;3', 'house', 'well', 'done,', "i'm", 'still', 'sad']
# filtered_tokens ['aw', 'ok', 'goonite....']
# filtered_tokens ['ill', 'cant', 'go', 'cinema!!']
# filtered_tokens ['fell', 'asleep', 'really', 'mean', '*christina*']
# ...
# filtered_tokens ['massage', 'great.', 'spilled', 'coke', 'desk', 'lame.', 'watching', 'simpsons', "i've", 'finished', 'hills', 'dvds.']
# filtered_tokens ['wait', 'fanclub', 'chat..', 'even', 'tough', 'favorite']
# filtered_tokens ['mild', 'left', 'inner', 'ear', 'infection..', 'got', 'irritating', '&quot;blocked&quot;', 'feeling', 'since', 'sunday..']
# filtered_tokens ['hey', 'there!', 'nope.', 'cuteness', 'away', 'awhile']
# filtered_tokens ['tuesday']
# filtered_tokens ['haha', 'even', 'yo.', 'know', 'twitter', 'haha']
# filtered_tokens ['someones', 'alarm', 'clock', 'phone', 'woke', '3am...still', 'got', 'headache', 'yesterday', 'night']
# filtered_tokens ['awww', 'poor', 'puppy', 'ok?']
# filtered_tokens ['might', 'break', 'eat', 'buffalo', 'wings', 'tomorrow']
# filtered_tokens ['sittin', 'w/kayla,', 'really', 'really', 'reallly', 'dis-like', 'brother.', 'know', 'stop.', "i'm", 'waiting', 'day', 'one']
# filtered_tokens ['fed', 'bokkie', 'many', 'birthday', 'treats-sicko']
# filtered_tokens ["'s", 'kinda', 'bummed.', 'agency', 'told', "'look'", 'going', 'for.', 'ladies,', 'please', 'help', 'create', "'look'"]
# filtered_tokens ['work', 'laptop', 'officially', 'dead', 'happy', 'all..']
# filtered_tokens ['goodness,', 'freezing']
# filtered_tokens ['put', 'him!!!!!', 'listen', 'mom']
# filtered_tokens ['stucked', 'paris', "can't", 'even', 'travel', 'france', '(for', 'work)']
# filtered_tokens ['think', "there's", 'one', 'close', 'by.', 'last', 'time', 'checked,', 'closest', 'one', '70', 'miles', 'away!']
# filtered_tokens ['aaaaand', 'back', 'literature', 'review', 'least', 'friendly', 'cup', 'coffee', 'keep', 'company.']
# filtered_tokens ['worried', 'get', '$900', 'even', 'though', 'paid', 'buttload', 'tax', 'last', 'year']
# filtered_tokens ['okay,', 'so..', 'still', 'school!!!!']
# filtered_tokens ['phoneless', '...now', 'sleep']
# filtered_tokens ['reeked', 'alcohol', 'dentist', 'morning', 'drunk', 'put', 'tshirt,', 'realised', 'huge', 'stain.', 'dentist', 'looked', 'disgusted']
# filtered_tokens ['really', 'cold']
# filtered_tokens ['cant', 'sleep', 'wants', 'dream!!']
# filtered_tokens ["can't", 'sleep', 'hate', 'nights', 'try', 'go', 'bed', 'early', 'stay', 'awake', 'hours.', 'poo!']
# filtered_tokens ['yeah.', 'bad', 'people', 'like', 'certain', 'burrito-eating', 'man', 'exist.']
# filtered_tokens ["that's", 'sad.']
# filtered_tokens ['found', 'mum', 'adopted', 'auntie', 'twitter..', 'check', 'mum', 'tessm64', 'awesome', 'auntie', 'tania38']
# filtered_tokens ['cannot', 'sleep....wide', 'awake!!...and', 'gotta', 'go', 'work', 'later', 'too.', 'boy,', 'going', 'crappy', 'day.']
# filtered_tokens ['struggling', 'eam', 'law']
# filtered_tokens ["can't", 'sleep', 'like']
# filtered_tokens ['bouts', 'start', '24.', 'poor', 'linny', 'keep', 'eyes', 'open.', 'tired', 'work', 'tomorrow', 'morning.', 'night']
# filtered_tokens ['4', 'year', 'old', '(18', 'year', 'old)', 'driving', 'around', 'twist...i', 'want', 'like']
# filtered_tokens ['well,', 'sucked.']
# filtered_tokens ['place', '3', 'days...any', 'help', 'get', 'packing/painting/cleaning', 'much', 'appreciated.', 'oh.', 'rip', 'wall']
# filtered_tokens ['opening', 'partially', 'frozen', 'beer=', 'beer', 'toaster,', 'oven', 'counter.', 'kitchen', 'smells', 'like', 'run', 'speakeasy']
# filtered_tokens ['dont', 'even', 'know', 'ride']
# filtered_tokens ['sadly,', 'yes.', 'think', 'need', 'counciling']
# filtered_tokens ['making', 'ready', "school...don't", 'feel', 'like', 'going,', 'two', 'tests']
# filtered_tokens ['smugness', 'gone.', 'train', 'also', 'failed', 'turn', "i'm", 'heading', 'victoria', 'followed', 'unpleasant', 'tube', 'ride', 'city.']
# filtered_tokens ['anybody', 'know', 'ipod', 'went?']
# filtered_tokens ['aww', 'earthquake', 'italy', 'made', 'sad', 'saw', 'pics', 'news,', 'terrible.']
# filtered_tokens ['never', 'able', 'afford', 'get', 'out.', "i'd", 'much', 'rather', 'go', 'extraction', 'continue', 'deal', 'now.']
# filtered_tokens ['pet', 'care', 'people', 'try', 'run', 'others', 'business?', 'send', 'suspicious', 'e-mails', 'fishing', 'info?']
# filtered_tokens ['&lt;33', "codez....they've", 'mia', 'tho']
# filtered_tokens ['doesnt', 'work', 'cell', 'go', 'sleep!', '=p']
# filtered_tokens ['going', 'nice', 'tomorrow', 'rain', 'comes', 'back.', 'nice', 'weather', 'birthday']
# filtered_tokens ['rock', 'band', 'hard..on', 'expert!!!']
# filtered_tokens ['roomie', 'home', 'day.', 'scratch', 'door.', 'comforter', 'goto', 'large', 'laundromat', 'machines.']
# filtered_tokens ['one', 'hardest', 'thing', 'schedule,', 'one', 'chat', 'end', 'day', 'usually']
# filtered_tokens ['killed', 'character', 'one', 'favorite', 'shows', "i'm", 'upset']
# filtered_tokens ['jealous', 'friends', 'got', 'see', 'new', 'star', 'trek', 'film', 'austin', 'tonight.']
# filtered_tokens ['listening', 'q!', 'got', 'really', 'bad', 'headache', 'drivin', 'lesson', 'ten', 'mins....', 'lucky', 'wana', 'sleeep!']
# filtered_tokens ['shut', 'you...i', 'hungry!', 'britain,', 'home', 'boring', 'suckassy', 'breakfast', 'world!', 'miss', 'dennys!!']
# filtered_tokens ['good', 'morning', 'everybody!', 'pkoi', 'fais', 'pas', 'beau', 'bon', 'coffee', 'time!']
# filtered_tokens ['work']
# filtered_tokens ['essay', 'time....']
# filtered_tokens ['hey', 'u', 'talk', 'mom..', 'r', 'home', 'yet?', 'hope', 'r', 'ok..', 'wish', 'coming', 'home', '4', 'easter..']
# filtered_tokens ['sure', 'wish', 'could', 'go', 'guys', 'tmrw.', 'per', 'usual,', 'school', 'interferes.']
# filtered_tokens ['say', 'what???', 'kal', "penn's", 'leaving', 'house?!', 'noooooo!!!', 'awww...', 'totally', 'missed', 'tonight']
# filtered_tokens ['no!', 'lost', 'loyal']
# filtered_tokens ['played', 'another', 'hand', 'bad', 'lost', 'half', 'stack']
# filtered_tokens ['6.20pm', 'early', 'days', 'looooooong', 'night', 'work']
# filtered_tokens ['sad', 'last', 'season.', 'wanna', 'see', 'spencer', 'calls', 'lauren!']
# filtered_tokens ['im', 'done', 'editing', '&quot;the', 'phipstape&quot;.', 'back', '2', 'crack', 'brew', 'see', 'got.............', 'trees', 'though']
# filtered_tokens ['know', 'half', 'means']
# filtered_tokens ['homework', 'homework', 'homework']
# filtered_tokens ['worked', 'heart', 'today,', 'doubling', 'weight', 'station.', 'result:', 'stiff', 'pulled', 'muscles...', 'ouch!']
# filtered_tokens ['feel', 'bad', 'unfollowing.']
# filtered_tokens ['so...', 'tired...', 'god', 'hate', 'new', 'job,', 'two', 'days']
# filtered_tokens ['sad', 'kutner', 'killed', 'fav', 'show', 'house!']
# filtered_tokens ['happy', 'coach', 'stringer', '(hof', 'c/o', '2009!)...now', 'finish', 'term', 'paper']
# filtered_tokens ['feel', 'like', 'shit.', 'way', 'want', 'spend', "birthday's", 'eve']
# filtered_tokens ['far', '311', 'sites', 'put', 'together,', 'checking', 'updates', 'made......']
# filtered_tokens ['lot', 'mind.', 'needs', 'make', 'moneys.', 'ideas.', 'nowhere', 'hiring!']
# filtered_tokens ['miss']
# filtered_tokens ["i'm", 'sorry', 'hear', 'dog']
# filtered_tokens ['much', 'internet.', 'plagues']
# filtered_tokens ['miss', 'ex', 'soo', 'much']
# filtered_tokens ['sodding', 'm25']
# filtered_tokens ['oh', 'thought', 'pirate', 'bay', 'trial', 'verdict', 'today', ':-s', 'apparently', '10', 'days']
# filtered_tokens ['call', 'back.']
# filtered_tokens ['study', 'hall', 'now,', 'log', 'immediately.']
# filtered_tokens ['tired', 'im', 'crying', 'reason', 'all.', 'im', 'try', 'get', 'hour', 'half', 'tonight.', 'half', 'got', 'last', 'night.']
# filtered_tokens ['totally', 'like...', 'four', 'girl', 'options,', 'none', 'seem', 'viable']
# filtered_tokens ['far', '311', 'veiws', 'sites', 'put', 'together,', 'checking', 'updates', 'made......']
# filtered_tokens ['listening', "bjork's", 'full', 'love...', 'crying']
# filtered_tokens ['omg', 'hills!', 'love', 'money2,', 'aww', 'think', 'becky', 'buckwild', 'goes']
# filtered_tokens ['craving', 'tantan', 'nabe']
# filtered_tokens ["c'mon", 'sean', 'man']
# filtered_tokens ['watching', '&quot;a', 'league', 'own&quot;...makes', 'miss', 'mint', 'chocolate', 'ice', 'cream', 'cones', 'grand', 'fuck.']
# filtered_tokens ['lost', 'phone', 'where.maybe', 'grass,', 'long,', 'hope', 'rain']
# filtered_tokens ['hope', 'referring', 'say', 'hello', 'new', 'stalker', 'lol']
# filtered_tokens ['u', 'sleeping?!', 'ur', 'gonna', 'night', 'ur', 'bike', 'ride?']
# filtered_tokens ['but,', 'but,', 'wanna', 'listen', 'masters', 'too!']
# filtered_tokens ["i've", 'looking', 'good', 'stuff', 'write,', 'also', 'loads', 'uni', 'work']
# filtered_tokens ['feel', 'unloved.', 'dropped', '2', 'tweeters']
# filtered_tokens ['london', 'day', 'thursday,', 'gonna', 'raining,', 'oh', 'fab', 'see', 'much', 'london', 'eye!', 'still', 'robbie', 'care', 'bless']
# filtered_tokens ['completely', 'wiped', 'reloaded', '8900....', 'lost', 'bbm', 'contacts', 'going', 'bed', 'sad.']
# filtered_tokens ['sayyyy', 'whaaaa?', 'invited...']
# filtered_tokens ['sleep', 'bad', 'considering', 'workshop', 'starting', 'today.', 'beginnings', 'sore', 'throat', 'though']
# filtered_tokens ['oh', 'gosh', 'made', 'emotional', 'haha', 'idk', 'why!!!', 'dont', 'want', 'get', 'old']
# filtered_tokens ["we're", 'going', 'post', 'stories', 'manually', 'due', 'twitterfeed', 'problem.', "that's", "we've", 'quiet', 'lately']
# filtered_tokens ['like', 'lukewarm', 'showers']
# filtered_tokens ['contact', 'need', '1099', 'freelance', 'work', 'linux.com', 'throughout', '2008?', 'never', 'got', 'one.']
# filtered_tokens ['connor,', 'me,', 'febi', 'really', 'really', 'mad', 'me??']
# filtered_tokens ['need', 'help?!', 'want', 'buy', 'macbook', 'pro,', 'still', 'inlove', 'old', 'powerbook!']
# filtered_tokens ['man', 'america', 'borez', 'anyway', 'lol', 'realized', 'sent', 'msgs', 'here.', 'idea.', 'flash']
# filtered_tokens ["g'knight", 'lovely', 'ladies.', "i'm", 'sleepy']
# filtered_tokens ['anybody', 'know', 'get', 'electrolytes', 'back', 'order?', 'vitamin', 'work?', 'feel', 'sick.']
# filtered_tokens ['yes,', 'someone', 'reading', 'posts', 'properly']
# filtered_tokens ['almost', 'italian', 'homework!', 'weeeeee....', 'understood', 'doing.']
# filtered_tokens ['turned', 'lights', 'on?', 'time', 'get', 'ip']
# filtered_tokens ['twitter', 'hates', 'us', 'then.']
# filtered_tokens ['hate', 'fact', "i'm", 'genuinely', 'excited', 'last', 'tweet']
# filtered_tokens ["can't", 'sleep', 'either']
# filtered_tokens ['italy', 'earthquake,', 'sad', 'news', 'day.']
# filtered_tokens ['rain', 'today', 'garden', 'really', 'needs', 'quite', 'bad.']
# filtered_tokens ['yawn', 'yawn', 'yawn!!', '10', 'minutes', 'bed']
# filtered_tokens ['ouch', 'sounds', 'sucky']
# filtered_tokens ['great', 'idea', 'itunes', 'promo', 'codes', 'work', 'uk', 'itunes', 'store', 'though']
# filtered_tokens ['*cry*']
# filtered_tokens ['empty', 'rum', 'barrel', 'sad', 'rum', 'barrel.', '*shakes', 'head*', 'horror,', 'horror.']
# filtered_tokens ['sleepless', 'night']
# filtered_tokens ['admitted', 'fake']
# filtered_tokens ['love', 'chutney......']
# filtered_tokens ['got', 'highly', 'bored', 'today', 'scanning', '24', 'pages', 'daddy.', 'it!']
# filtered_tokens ['cooked', 'risotto', 'without', 'me!!???']
# filtered_tokens ['keeeerrrrriiiiii!!!!', 'really', 'nothing', 'better', 'post', 'thing', '224am.....wonderfullll.', 'says', 'alot.']
# filtered_tokens ['yay', 'baseball', 'season!', 'boo', 'yankees', 'losing', 'first', 'game']
# filtered_tokens ['lost', 'sucks', 'work', 'today']
# filtered_tokens ['omg', 'exams', 'killed', 'could', 'know', 'difference', 'haif', 'circle', 'hemisphere', '&lt;/3', '&gt;']
# filtered_tokens ['bed...', 'suddenly', 'feel', 'wish', 'w/me...', 'goodnight', 'twitterfam']
# filtered_tokens ['like', 'goodnights']
# filtered_tokens ['greaaat', 'lappy', 'turn', 'wtffffff']
# filtered_tokens ['stuck', 'traffic', 'then?', 'journey', 'traffic', 'free', 'morning,', 'help.']
# filtered_tokens ['lookin', 'like', 'all-nighter.', 'hate']
# filtered_tokens ['stranger']
# filtered_tokens ['debbugging', 'old', 'vb6', 'code,', 'day', 'could', 'started', 'better']
# filtered_tokens ['quarter', 'percent', 'babe', 'darn']
# filtered_tokens ['coming', 'cold', 'bad', 'allergies.', 'either', 'way,', "i'm", 'miserable!']
# filtered_tokens ["can't", 'believe', 'cutner', 'dead', 'house!', 'sad', 'day.', 'santa', 'rosa,', 'ca']
# filtered_tokens ['damnit', 'really', 'digging', 'season', 'reaper']
# filtered_tokens ['gah,', 'comcast', 'doubled', 'cable/internet', 'bill', 'w/out', 'telling', 'us,', 'quitting.', 'anyone', 'suggest', 'affordable', 'company', 'bay', 'area?']
# filtered_tokens ['another', 'early', 'morn', 'duchess,', 'although', 'managed', 'cross', 'legs', 'time']
# filtered_tokens ['left', 'without', 'saying', 'hi!']
# filtered_tokens ['l', 'want,', "can't", 'sleep']
# filtered_tokens ['xbox', 'shows', 'three', 'red', 'lights,', 'means', 'dead', 'needs', 'fixed', 'month', 'microsoft', 'hq.']
# filtered_tokens ['king', 'sized', 'bed', 'nice', 'sad', 'lonely', 'hubby,', 'puppy,', 'kitty', 'whole', 'conferenceing', 'thing.']
# filtered_tokens ['im', 'boredd.', 'gah', 'wish', 'could', 'sleep', 'get', 'ive', 'toooo', 'muchh', 'cooooffffeeeeeeeee', 'bahaha']
# filtered_tokens ['may', 'butt', 'again.', "i'm", 'done', 'nosey.', 'sorry', 'conversation', 'interesting!']
# filtered_tokens ['fell', 'list...did', 'offend', 'you?']
# filtered_tokens ['18', 'weeks', 'till', 'sisters', 'home..', 'missed', 'call,', 'again!', 'worst', 'feeling', 'world.']
# filtered_tokens ['gonna', 'try', 'get', 'sleep', 'hotel', 'room']
# filtered_tokens ['brilliant', 'idea.', 'bring', 'much', 'think', 'spend', '&amp;', "i'll", 'swap', 'you.', 'bring', 'brolly']
# filtered_tokens ['get', 'autograph', 'shout', 'out!', 'record', 'though.', 'computer', 'dead', "can't", 'listen.']
# filtered_tokens ['rt', 'khloe', 'got', 'fired', 'apprentice']
# filtered_tokens ['biology', 'class.', 'lip', 'hurts']
# filtered_tokens ['sorry', 'next', 'tweet...']
# filtered_tokens ['grr', 'go', 'school', 'today']
# filtered_tokens ['get', 'hd', 'tivo', 'got', 'set', 'tonight', 'order', 'get', 'channels', '40', '59.']
# filtered_tokens ['asked', 'everyone', 'yesterday', 'single', 'tweet', 'back']
# filtered_tokens ['ruddy', 'money!!', 'like', 'it!!', 'still', 'waiting', 'here....', 'oh', 'surprise...', 'state', 'too??', 'hmmm.......', 'seriously!!']
# filtered_tokens ['sad', 'kutner', 'favorite', 'new', 'team!!']
# filtered_tokens ['wow', 'get', '&quot;hello&quot;', 'u', 'suck']
# filtered_tokens ['bedtime,', 'school', 'tomorrow,', 'still', 'books', 'broke', 'suckssss']
# filtered_tokens ['seating', 'helping', 'baby', 'papers...well', 'forcing', 'seat', 'im', 'sleepy']
# filtered_tokens ['synching', 'contacts', 'old', 'mobile', 'iphone.', 'import', 'work', 'well']
# filtered_tokens ["can't", 'concentrate']
# filtered_tokens ["i've", 'spent', '1', 'hour', 'enter', 'bureaucratic', 'nonsense', 'march.', 'waste', 'time']
# filtered_tokens ['nw', 'confused', 'ever!']
# filtered_tokens ['feeling', 'well', 'again.', 'stupid', 'migraine', 'making', 'tummy', 'upset.', 'whole', 'body', 'aches,', 'shoot', 'now.']
# filtered_tokens ['reading', 'buyology', 'bedtime...', 'great', 'premise', 'turning', '&quot;ok&quot;', 'book', 'lots', 'info', 'already', 'knew']
# filtered_tokens ['home!', 'really', 'wana', 'sleep,', 'due', 'wasting', 'free', 'line', 'town', 'assignment', 'finish']
# filtered_tokens ['also', 'send', 'updates', 'plurk', 'upload', 'photos', 'twitter!', 'didnt', 'see', 'updates', 'plurk?', 'zero?']
# filtered_tokens ['omg...', '&quot;the', 'reader&quot;', 'making']
# filtered_tokens ["d'oh!", 'least', 'getting', 'decent', 'exchange', 'rate', 'moment,', 'sterling', 'still', 'getting', 'flogged']
# filtered_tokens ['tried', 'download', 'tweetdeck', 'wont', 'download']
# filtered_tokens ["there's", 'inch', 'snow', 'ground', '(and', 'counting).', "i'm", 'worried', 'poor', 'flowers']
# filtered_tokens ['happy', 'camper?']
# filtered_tokens ['thanks', 'man.', "i'm", 'grateful.', 'feel', 'unworthy', 'attention,', 'though,', "i'm", 'myself...']
# filtered_tokens ['miss', 'u', 'too.', "i'm", 'totally', 'comin', 'back', 'tho!', 'lastnight', 'sooooooo', 'much', 'fun!']
# filtered_tokens ['ohhh.', 'love', 'it.', 'ps', "i'm", 'sad', 'get', 'hang']
# filtered_tokens ['somehow', 'still', 'end', 'place']
# filtered_tokens ['oh', 'sad,', 'poor', 'boy.']

# %% [markdown]
# Users are known to add **repeated trailing symbols** or alphabets as a way to express their emotions. We will make use of Regex to show it as a single occurance. When considering the reduction of alphabets, we have to take into consideration whether the word has been dragged, or if the word does have repeated characters. (eg: kangaroo)
#
# As the common dictionary does not seem to have any words that have 3 consecutive repeated letters, we would tokenise the words to have repeated characters a maximum of 2 times. While this is not a full-proof way of resolving repeated trailing characters, this is the safest way to ensure better classification.

# %%
stop_words = set(stopwords.words("english"))
symbols = set(string.punctuation)

# Checking removal works on a test text
test_tweet4 = ["modified test that stopword removal works. It will remove @testtry", 
               "http not removed but https://www.youtube.com/ and http://www.youtube.com/ removed",
               "The cleaning will show this!!!!!!!!?!!!?!!!!!! with 1 exclaimation",
               "kaaaaaaangarooooooooooooooooooooooooooo will be cleaned up"]

def filter_text4(tweets):
    for tweet in tweets:
        # Tokenizing URLs using Regex
        tweet = re.sub(r"@\S+|(?:http|https)://\S+", "", tweet)
        # Tokenizing repeated symbols using Regex
        tweet = re.sub(r'([!@#$%^&*.]){2,}', r'\1', tweet)
        # Tokenizing repeated characters
        tweet = re.sub(r'([A-Za-z])\1+', r'\1\1', tweet)
        tokens = tweet.lower().split()
        
        filtered_tokens = [token for token in tokens if not (
            # Removing each token if part of symbols
            all(char in symbols for char in token)
            # Removing each token if part of stop_words
            or token in stop_words
        )]
        
        print("filtered_tokens", filtered_tokens)
        
filter_text4(test_tweet4)
# Out:
# filtered_tokens ['modified', 'test', 'stopword', 'removal', 'works.', 'remove']
# filtered_tokens ['http', 'removed', 'removed']
# filtered_tokens ['cleaning', 'show', 'this!?!?!', '1', 'exclaimation']
# filtered_tokens ['kaangaroo', 'cleaned']

# %%
# After improvement of stopwords
tweets = tweets_df["tweet"].tolist()
filter_text4(tweets)
# Out:
# filtered_tokens ['aww,', "that's", 'bummer.', 'shoulda', 'got', 'david', 'carr', 'third', 'day', 'it.', ';d']
# filtered_tokens ['upset', "can't", 'update', 'facebook', 'texting', 'it.', 'might', 'cry', 'result', 'school', 'today', 'also.', 'blah!']
# filtered_tokens ['dived', 'many', 'times', 'ball.', 'managed', 'save', '50%', 'rest', 'go', 'bounds']
# filtered_tokens ['whole', 'body', 'feels', 'itchy', 'like', 'fire']
# filtered_tokens ['no,', 'behaving', 'all.', "i'm", 'mad.', 'here?', "can't", 'see', 'there.']
# filtered_tokens ['whole', 'crew']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['hey', 'long', 'time', 'see!', 'yes.', 'rains', 'bit', ',only', 'bit', 'lol', "i'm", 'fine', 'thanks', "how's"]
# filtered_tokens ['nope']
# filtered_tokens ['que', 'muera']
# filtered_tokens ['spring', 'break', 'plain', 'city.', 'snowing']
# filtered_tokens ['re-pierced', 'ears']
# filtered_tokens ['bear', 'watch', 'it.', 'thought', 'ua', 'loss', 'embarrassing']
# filtered_tokens ['counts,', 'idk', 'either.', 'never', 'talk', 'anymore']
# filtered_tokens ["would've", 'first,', 'gun.', 'really', 'though,', 'zac', "snyder's", 'doucheclown.']
# filtered_tokens ['wish', 'got', 'watch', 'you!', 'miss', 'premiere?!']
# filtered_tokens ["hollis'", 'death', 'scene', 'hurt', 'severely', 'watch', 'film', 'wry', 'directors', 'cut', 'now?']
# filtered_tokens ['file', 'taxes']
# filtered_tokens ['ahh', 'ive', 'always', 'wanted', 'see', 'rent', 'love', 'soundtrack!']
# filtered_tokens ['oh', 'dear.', 'drinking', 'forgotten', 'table', 'drinks?']
# filtered_tokens ['day', 'get', 'much', 'done']
# filtered_tokens ['one', 'friend', 'called', 'me,', 'asked', 'meet', 'mid', 'valley', 'today.but', "i've", 'time', '*sigh*']
# filtered_tokens ['baked', 'cake', 'ated']
# filtered_tokens ['week', 'going', 'hoped']
# filtered_tokens ['blagh', 'class', '8', 'tomorrow']
# filtered_tokens ['hate', 'call', 'wake', 'people']
# filtered_tokens ['going', 'cry', 'sleep', 'watching', 'marley', 'me.']
# filtered_tokens ['im', 'sad', 'miss.lilly']
# filtered_tokens ['ooh.', 'lol', 'leslie.', 'ok', 'leslie', 'get', 'mad']
# filtered_tokens ['meh.', 'almost', 'lover', 'exception.', 'track', 'gets', 'depressed', 'every', 'time.']
# filtered_tokens ['some1', 'hacked', 'account', 'aim', 'make', 'new', 'one']
# filtered_tokens ['want', 'go', 'promote', 'gear', 'groove', 'unfornately', 'ride', 'may', 'b', 'going', 'one', 'anaheim', 'may', 'though']
# filtered_tokens ['thought', 'sleeping', 'option', 'tomorrow', 'realizing', 'not.', 'evaluations', 'morning', 'work', 'afternoon!']
# filtered_tokens ['awe', 'love', 'too!', '1', 'miss']
# filtered_tokens ['cry', 'asian', 'eyes', 'sleep', 'night']
# filtered_tokens ['ok', "i'm", 'sick', 'spent', 'hour', 'sitting', 'shower', 'cause', 'sick', 'stand', 'held', 'back', 'puke', 'like', 'champ.', 'bed']
# filtered_tokens ['ill', 'tell', 'ya', 'story', 'later', 'good', 'day', 'ill', 'workin', 'like', 'three', 'hours.']
# filtered_tokens ['sorry!', 'bed', 'time', 'came', '(gmt+1)']
# filtered_tokens ['either.', 'depressing.', 'think', 'even', 'want', 'know', 'kids', 'suitcases.']
# filtered_tokens ['bed.', 'class', '8-12.', 'work', '12-3.', 'gym', '3-5', '6.', 'class', '6-10.', 'another', 'day', "that's", 'gonna', 'fly', 'by.', 'miss', 'girlfriend']
# filtered_tokens ['really', 'feel', 'like', 'getting', 'today.', 'got', 'study', 'tomorrows', 'practical', 'exam.']
# filtered_tokens ["he's", 'reason', 'teardrops', 'guitar', 'one', 'enough', 'break', 'heart']
# filtered_tokens ['sad,', 'sad,', 'sad.', 'know', 'hate', 'feeling', 'wanna', 'sleep', 'still', "can't!"]
# filtered_tokens ['aww', 'soo', 'wish', 'see', 'finally', 'comfortable!', 'im', 'sad', 'missed']
# filtered_tokens ['falling', 'asleep.', 'heard', 'tracy', "girl's", 'body', 'found.', 'sad', 'heart', 'breaks', 'family.']
# filtered_tokens ['yay!', "i'm", 'happy', 'job!', 'also', 'means', 'less', 'time', 'you.']
# filtered_tokens ['checked', 'user', 'timeline', 'blackberry,', 'looks', 'like', 'twanking', 'still', 'happening', 'ppl', 'still', 'probs', 'w/', 'bgs', 'uids?']
# filtered_tokens ['oh', 'man.was', 'ironing', 'fave', 'top', 'wear', 'meeting.', 'burnt']
# filtered_tokens ['strangely', 'sad', 'lilo', 'samro', 'breaking', 'up.']
# filtered_tokens ['oh!', "i'm", 'sorry', 'think', 'retweeting.']
# filtered_tokens ['broadband', 'plan', "'a", 'massive', 'broken', "promise'", 'via', 'ww.diigo.com/~tautao', 'still', 'waiting', 'broadband']
# filtered_tokens ['wow,', 'tons', 'replies', 'you,', 'may', 'unfollow', 'see', "friends'", 'tweets,', 'scrolling', 'feed', 'lot.']
# filtered_tokens ['duck', 'chicken', 'taking', 'wayy', 'long', 'hatch']
# filtered_tokens ['put', 'vacation', 'photos', 'online', 'yrs', 'ago.', 'pc', 'crashed,', 'forget', 'name', 'site.']
# filtered_tokens ['need', 'hug']
# filtered_tokens ['sure', 'are,', 'pos!', 'much', 'want', 'to,', 'dont', 'think', 'trade', 'away', 'company', 'assets', 'sorry', 'andy!']
# filtered_tokens ['hate', 'happens.']
# filtered_tokens ['sad', 'feeling', 'dallas', 'going', 'show', 'gotta', 'say', 'though,', 'think', 'shows', 'would', 'use', 'music', 'game.', 'mm']
# filtered_tokens ['ugh.92', 'degrees', 'tomorrow']
# filtered_tokens ['u', 'move', 'to?', 'thought', 'u', 'already', 'sd.', 'hmm.', 'random', 'u', 'found', 'me.', 'glad', 'hear', 'yer', 'well.']
# filtered_tokens ['miss', 'ps3,', 'commission', 'wutcha', 'playing?', 'copped', "'blood", "sand'?"]
# filtered_tokens ['leaving', 'parking', 'lot', 'work!']
# filtered_tokens ['life', 'cool.', 'me.']
# filtered_tokens ['sadly', 'though,', "i've", 'never', 'gotten', 'experience', 'post', 'coitus', 'cigarette', 'before,', 'never', 'will.']
# filtered_tokens ['nice', 'day.', 'bad', 'rain', 'comes', 'tomorrow', '5am']
# filtered_tokens ['bad', 'around', 'lost', 'job', "can't", 'even', 'pay', 'phone', 'bill', 'lmao', 'aw', 'shucks']
# filtered_tokens ['damm', 'back', 'school', 'tomorrow']
# filtered_tokens ['mo', 'jobs,', 'money.', 'hell', 'min', 'wage', '4', "f'n", 'clams', 'hour?']
# filtered_tokens ['forever.', 'see', 'soon!']
# filtered_tokens ['agreed,', 'saw', 'failwhale', 'day', 'today.']
# filtered_tokens ['oh!', 'haha.', 'dude', 'dont', 'really', 'look', 'em', 'unless', 'someone', 'says', 'hey', 'added', 'you.', 'sorry', "i'm", 'terrible', 'that.', 'need', 'pop', 'up!']
# filtered_tokens ["i'm", 'sure', 'right.', 'need', 'start', 'working', 'nikster.', 'jared', 'least!']
# filtered_tokens ['really', 'hate', 'people', 'diss', 'bands!', 'trace', 'clearly', 'ugly!']
# filtered_tokens ['gym', 'attire', 'today', 'was:', 'puma', 'singlet,', 'adidas', 'shorts.and', 'black', 'business', 'socks', 'leather', 'shoes', 'lucky', 'run', 'cute', 'girls.']
# filtered_tokens ['show', 'location?!']
# filtered_tokens ['picnic', 'phone', 'smells', 'like', 'citrus.']
# filtered_tokens ['donkey', 'sensitive', 'comments.', 'nevertheless,', "he'd", '(and', "me'd)", 'glad', 'see', 'mug', 'asap.', 'charger', 'still', 'awol.']
# filtered_tokens ['new', 'csi', 'tonight.', 'fml']
# filtered_tokens ['think', 'arms', 'sore', 'tennis']
# filtered_tokens ['wonders', 'someone', 'u', 'like', 'much', 'make', 'unhappy', 'split', 'seccond', 'depressed']
# filtered_tokens ['sleep', 'soon.', 'hate', 'saying', 'bye', 'see', 'tomorrow', 'night.']
# filtered_tokens ['got', 'ur', 'newsletter,', 'fares', 'really', 'unbelievable,', 'shame', 'already', 'booked', 'paid', 'mine']
# filtered_tokens ["missin'", 'boo']
# filtered_tokens ['#itm']
# filtered_tokens ['damn.', 'chalk!', 'chalkboard', 'useless']
# filtered_tokens ['blast', 'getty', 'villa,', 'hates', 'sore', 'throat', 'day.', 'getting', 'worse']
# filtered_tokens ['hey', 'missed', 'ya', 'meeting', 'sup', 'mama']
# filtered_tokens ['tummy', 'hurts.', 'wonder', 'hypnosis', 'anything', 'it?', 'so,', 'working,', 'get', 'it,', 'stop', 'smoking!']
# filtered_tokens ['always', 'fat', 'ones?!']
# filtered_tokens ['sorry,', 'babe!', 'fam', 'annoys', 'too.', 'thankfully,', "they're", 'asleep', 'right', 'now.', 'muahaha.', '*evil', 'laugh*']
# filtered_tokens ['paid', 'attention', 'covered', 'photoshop', 'webpage', 'design', 'class', 'undergrad']
# filtered_tokens ['wednesday', 'b-day!', 'know', '2', 'do!']
# filtered_tokens ['poor', 'cameron', '(the', 'hills)']
# filtered_tokens ['pray', 'please,', 'ex', 'threatening', 'start', 'sh*', 'my/our', 'babies', '1st', 'birthday', 'party.', 'jerk.', 'still', 'headache']
# filtered_tokens ['hmm', 'u', 'really', 'enjoy', 'problems', 'constants', 'u', 'think', 'things', 'find', 'someone', 'ulike']
# filtered_tokens ['strider', 'sick', 'little', 'puppy']
# filtered_tokens ['rylee,grace.wana', 'go', "steve's", 'party', 'not??', 'sadly', 'since', 'easter', 'wnt', 'b', 'able', '2', 'much', 'ohh', 'well.']
# filtered_tokens ['hey,', 'actually', 'one', 'bracket', 'pools!', 'bad', 'one', 'money']
# filtered_tokens ['follow', 'me,', 'either', 'work', 'you!']
# filtered_tokens ['bad', 'nite', 'favorite', 'teams:', 'astros', 'spartans', 'lose.', 'nite', 't.w.', 'good.']
# filtered_tokens ['body', 'missing', 'northern', 'calif.', 'girl', 'found:', 'police', 'found', 'remains', 'missing', 'northern', 'california', 'girl']
# filtered_tokens ['hope', 'increase', 'capacity', 'fast,', 'yesterday', 'pain.', 'got', 'fail', 'whale', '+15', 'times', '2', 'hours.']
# filtered_tokens ['behind', 'classes', 'work']
# filtered_tokens ['watching', '&quot;house&quot;']
# filtered_tokens ['remember', 'bum', 'leg?', 'strikes', 'back', 'time', 'serious']
# filtered_tokens ['cool,', 'will.', 'kinds', 'complaints', 'laptop', 'online', 'overheating,', 'recalls']
# filtered_tokens ['emily', 'glad', 'mommy', 'done', 'training', 'new', 'job.', 'misses', 'her.']
# filtered_tokens ['would', 'rather', 'first', 'party', 'send', 'bad', 'messages', '3rd', 'party', 'send', 'mixed', 'ones', 'sophmore', 'year', 'again?']
# filtered_tokens ['overrated']
# filtered_tokens ['know!', 'heard', 'afternoon', 'wondered', 'thing.', 'moscow', 'behind', 'times']
# filtered_tokens ['laying', 'bed', 'voice.']
# filtered_tokens ["i'm", 'soo', 'sad!', 'killed', 'kutner', 'house', 'whyy']
# filtered_tokens ['sorry', 'tell', 'mea', 'culpa', 'really', 'sorry.']
# filtered_tokens ['make', 'sense', 'me,', 'suicide', 'thing.', 'refuse', 'believe', 'actually', 'happened.']
# filtered_tokens ['hope', 'ok.']
# filtered_tokens ['damn!', 'grind', 'inspirational', 'saddening', 'time.', 'want', 'stop', 'cuz', 'like', 'u', 'do!', 'much', 'love']
# filtered_tokens ['yeah', 'aw', 'know', 'wudnt', 'stand', 'chance']
# filtered_tokens ['ugh.', 'cant', 'sleep.', '1:30am.']
# filtered_tokens ['hanging', 'crooners.', 'wanna', 'sing.', "can't.", 'sucks.']
# filtered_tokens ['aaw', 'miss', 'ya', 'too.', 'im', 'leaving', 'bh', 'tomorrow', '&quot;morning&quot;', 'think.', 'aww', 'wanna', 'go', 'beach', 'w', 'u', 'girls!']
# filtered_tokens ['pissed', "there's", "asba's", 'radio', 'station.']
# filtered_tokens ['wednesday', 'b-day', 'n', 'know', '2', 'do!']
# filtered_tokens ['know', 'life', 'flipped', 'upside', 'thought', 'head', 'ramen', 'sounds', 'good.']
# filtered_tokens ['pain.', 'back', 'sides', 'hurt.', 'mention', 'crying', 'made', 'fail.']
# filtered_tokens ['late', 'night', 'snack,', 'glass', 'oj', 'b/c', "i'm", '&quot;down', 'sickness&quot;,', 'back', 'sleep.ugh', 'hate', 'getting', 'sick.']
# filtered_tokens ['but.', 'but.', 'but.', "i'm", 'big', 'fan', 'camilla', 'belle']
# filtered_tokens ['wah', "can't", 'see', 'clip,', 'must', 'el-stupido', 'work', 'filters.', "can't", 'wait', "'till", 'get', "'puter.", 'something', 'else', '2', 'blame', 'ex', '4.', 'broke', 'mine']
# filtered_tokens ['week', 'seems', 'get', 'longer', 'longer', 'terms', 'much', 'need', 'do.', 'much', "i'm", 'actually', 'going', 'get', 'done']
# filtered_tokens ["i'm", 'cold']
# filtered_tokens ['ehh', "don't.", "weather's", 'gonna', 'take', 'turn', 'ugly', 'tomorrow']
# filtered_tokens ['haha', 'coold', 'd!', 'still', 'go', 'show.', 'incredible', 'stuff']
# filtered_tokens ['hoping', 'tummy', 'rumbles', 'go', 'away', 'soon']
# filtered_tokens ['no,', 'notice.', 'told', "i'd", 'working', 'tomorrow,', 'called', 'agency', 'follow', 'said', 'over.']
# filtered_tokens ['almost', 'bedtime']
# filtered_tokens ["i'm", 'missing', 'babe.', 'long', 'alive', "i'm", 'happy.', 'yawwnn.', "i'm", 'tired', 'love', 'imma', 'try', 'sleep', 'hopefully', 'headstart']
# filtered_tokens ['agh.snow!']
# filtered_tokens ['miss', 'kenny', 'powers']
# filtered_tokens ['thank', 'letting', 'people', 'know,', "i'm", 'sad', 'direct', 'message', 'got', 'actually', 'bridget']
# filtered_tokens ['.and,', 'india', 'missed', '100th', 'test', 'victory', 'n', '10th', 'consecutive', 'win', 'without', 'loss.']
# filtered_tokens ['guess', "that's", 'then.']
# filtered_tokens ['sadly', 'going', 'bed.']
# filtered_tokens ['shame', 'hear', 'stephan']
# filtered_tokens ['hey!', "i'm", 'leavin', 'morning.']
# filtered_tokens ['intending', 'finish', 'editing', '536-page', 'novel', 'manuscript', 'tonight,', 'probably', 'happen.', '12', 'pages', 'left']
# filtered_tokens ['laid', 'around', 'much', 'today.', 'head', 'hurts']
# filtered_tokens ['still', 'read', '9th&amp;10th', 'princess', 'diaries', 'saving', 'francesca', 'made', 'cry', 'end.', 'hmm', 'easy', 'books.']
# filtered_tokens ['nokia', '1110', 'died.']
# filtered_tokens ['mom', 'might', 'breast', 'cancer', 'find', 'anything', 'for.', 'like', 'week', "i'm", 'worried!']
# filtered_tokens ['going', 'sleep.', 'hoping', 'tomorrow', 'better', 'day.']
# filtered_tokens ['lol.', 'wish', 'understood', 'daylight', 'savings', 'ended', 'though', 'breakfast', 'hour', 'later', 'keep', 'waking', 'kids']
# filtered_tokens ['lame']
# filtered_tokens ['understand.', 'really']
# filtered_tokens ['heroes', 'season.']
# filtered_tokens ['living', 'downtown', 'sure', 'much', 'fun.']
# filtered_tokens ['calorie', 'wise', 'wish', 'junk', 'food', 'calorie', 'free!', 'ate', 'thing', 'sour', 'skittles', 'big', 'ass', 'cherry', 'coke!']
# filtered_tokens ['man', 'work', 'hard']
# filtered_tokens ['getting', 'sick', 'time', 'hot', 'tea,', 'studying,', 'sleep']
# filtered_tokens ['getting', 'eyebrows', 'waxed.', 'pain']
# filtered_tokens ['phantasy', 'star', 'yesterday', 'going', 'work.']
# filtered_tokens ['oh', 'got', 'macheist', '3.0', 'apps', 'sweet.', 'get', 'espresso', 'serial', 'though', 'although', 'said', 'sent', 'oh', 'well']
# filtered_tokens ['picked', 'mich', 'st', 'win', 'get', 'go.', 'feeling', 'pretty', 'good', 'pick', 'way', 'until.tonight.', "a's", 'lost']
# filtered_tokens ['alone', 'downstairs.working']
# filtered_tokens ['feel', 'bad']
# filtered_tokens ['me,', 'hates', 'anoop.', 'mean', 'seriously,', 'kinda', 'mean', 'him.']
# filtered_tokens ['yes', 'sprint', '4g', 'baltimore', 'chicago', 'far']
# filtered_tokens ["i'm", 'stuck', 'awake', 'middle', 'night', 'second', 'day', 'row.', 'felt', 'terrible', 'yesterday.']
# filtered_tokens ['thanks', 'bursting', 'bubble']
# filtered_tokens ['going', 'school', 'soon.', "can't", 'find', 'anything', 'wear!', 'gosh', 'hard']
# filtered_tokens ['serious', 'lol']
# filtered_tokens ['page', 'soo', 'long!', 'got', 'deleted', 'sad', 'day', 'history']
# filtered_tokens ['crazy', 'wind', 'today', 'birding']
# filtered_tokens ['currently', 'work.']
# filtered_tokens ['grr.', 'ipods', 'acting', 'weird', 'too!', 'jai', 'ho', 'thinking', 'playing', 'full', 'songs.', 'ughh.']
# filtered_tokens ['send', 'dvd', 'cos', 'missed', 'heaps', 'happy', 'that!']
# filtered_tokens ['see', 'big', 'deal', 'website']
# filtered_tokens ["i'm", 'sorry', 'go', 'this.', 'again.', '#therapyfail']
# filtered_tokens ['far', 'way', 'rail.', 'tips?']
# filtered_tokens ["i'm", 'still', 'swear.', 'keep', 'losing.', 'gaining.', 'losing.', 'gaining.', 'tweeps?', 'heart', 'wrenching.']
# filtered_tokens ['today', 'realized', 'good', 'hiding', 'things,', 'even', "can't", 'find']
# filtered_tokens ['staying', 'friends', 'house.house', 'sitting,', 'neighbors', 'loud-having', 'party']
# filtered_tokens ['danny', 'im', 'upset', 'wasnt', 'watch', 'live', 'chat', 'car.', '3', 'hours', 'trip', 'im', 'soo', 'upset!']
# filtered_tokens ['check', 'mug']
# filtered_tokens ['borders', 'closed', '10']
# filtered_tokens ['downloading', "nin's", 'new', 'album', '&quot;the', 'slip&quot;', 'hell', 'come', 'out?', "i'm", 'behind', 'times', 'days']
# filtered_tokens ['woke', 'already', 'written', 'e-mail.', "i've", 'go', 'early', 'university', 'today', 'teach', '8:30', 'am!']
# filtered_tokens ['watching', 'hill', '.and', 'making', 'sad']
# filtered_tokens ['many', 'channels.', 'yet', 'boring.', 'lazy', 'day', 'may', 'find', 'hobby']
# filtered_tokens ['miss', 'buddy', 'ill', 'ny', '25th']
# filtered_tokens ['love', 'french.', 'tell', 'people', 'south', "i'm", 'qtr.', 'french', 'snarl', 'me.', 'french', 'beautiful', 'people']
# filtered_tokens ['opps.', 'said.', 'still', 'got', 'one', 'day', 'remain', 'problem', 'come']
# filtered_tokens ['activated', 'selfcontrol', 'block', 'early,', 'meaning', "can't", 'check', 'new', 'qc.', 'regularizing', 'internal', 'clock', 'might', 'difficult.', '#fb']
# filtered_tokens ['oh']
# filtered_tokens ['spencer', 'good', 'guy.']
# filtered_tokens ['reese', 'dying', '#ttsc?', 'season', 'finale', 'next', 'week.', '#24', 'boring,', 'madame', 'president', 'crazy', 'woman.']
# filtered_tokens ['hate', 'limited', 'letters,too.hope', 'guys', 'fine?i', 'pray', 'dog,she�s', 'well']
# filtered_tokens ['get', 'shit', 'done', 'today', "i'm", 'screwed']
# filtered_tokens ['wanttss', 'go']
# filtered_tokens ['going', 'sleep', 'tonite.']
# filtered_tokens ['worried', 'tired', 'post', 'tonight']
# filtered_tokens ['get', 'shit', 'done', 'today', "i'm", 'screwed']
# filtered_tokens ['job', 'interview', 'cardiff', 'today,', 'wish', 'luck!', 'got', '3', 'hours', 'sleep']
# filtered_tokens ['show', 'whack.', 'way', 'worse', 'whack,', 'wiggety-whack.']
# filtered_tokens ['really', 'think', 'people', 'choose', 'way.', 'think', 'chose', 'accept', "family's", 'help', 'might', 'dead']
# filtered_tokens ['going', 'kill', 'me,', "i've", 'seen', 'ds9.', "i've", 'waiting', 'till', 'one', 'solid', 'week', 'sitting.']
# filtered_tokens ['think', 'ur', 'right!', 'hahaha!', '4.5', 'hrs', 'now!']
# filtered_tokens ['hate', 'see', 'spartans', 'sad']
# filtered_tokens ['mind', 'body', 'severely', 'protesting', '&quot;getting', 'up&quot;', 'thing.', 'nightmares', 'boot']
# filtered_tokens ["i'm", "goin'", 'follow', 'u,', 'since', 'u', 'lol', 'go', 'angels!']
# filtered_tokens []
# filtered_tokens ['think', 'want', 'read', 'books', 'library']
# filtered_tokens ['nap', 'interrupted', 'many', 'times', 'today', 'going', 'japanese', "'rents", 'again.']
# filtered_tokens ['kind', 'longs', 'bus', 'shows', 'end', 'ghost', 'world', 'right', 'now.', 'ugh.']
# filtered_tokens ['canada', 'canada', 'weird.', "we're", 'supposed', 'get', 'snow', 'wednesday.', 'ugh.']
# filtered_tokens ['awwh', 'babs.', 'look', 'sad', 'underneith', 'shop', 'entrance', "&quot;yesterday's", 'musik&quot;', 'o-:', 'like', 'look', 'new', 'transformer', 'movie']
# filtered_tokens ['sad', "'feet'", 'macbook', 'fell']
# filtered_tokens ["i'm", 'gonna', 'get', 'late', 'tomorrow', '132am', 'here.', 'gonna', 'get', 'tipsy', 'lonesome.', "that's.that's", 'sad']
# filtered_tokens ["i'm", 'sweating', 'forthcoming', 'trip', 'e3.', "can't", 'find', 'someone', 'crash', "i'm", 'there,', 'may', 'screwed.']
# filtered_tokens ['gotten', 'somebody', 'read', 'tweets,', 'cant', 'get', 'make', 'account.']
# filtered_tokens ['omgawd', 'couldnt', 'handle', 'cat', 'heat', 'time', 'd:', 'd:']
# filtered_tokens ['hope', 'make', 'auburn', 'show.', 'looking', 'good']
# filtered_tokens ['*thats', 'people', 'mag', 'haha', 'couldnt', 'fit', 'in.', 'dont', 'think', 'pictures', 'ever', 'made', 'magazine', 'tho!', 'haha']
# filtered_tokens ['congrats!', 'totally', 'forgot', 'submit', 'photos']
# filtered_tokens ['aww,', 'good', 'luck', 'paula!', 'please', 'work', 'hard', 'hope', 'fun', 'new', 'album', 'gonna', 'amazing!', 'xx']
# filtered_tokens ['leaving', '-gets', 'sad-']
# filtered_tokens ['miss', 'twitter.', 'phone', 'broke,', "i'm", 'using', 'stupid', 'nokia', 'phone.', 'ughh,', 'miss', 'advance', 'phone.']
# filtered_tokens ['shooting', 'outside', 'house', ':o', 'kidding!', 'scared']
# filtered_tokens ['tuesday�ll', 'start', 'reflection', '�n', 'lecture', 'stress', 'reducing', 'techniques.', 'sure', 'might', 'become', 'useful', 'us', 'accompaniers']
# filtered_tokens ['tragedy', 'disaster', 'news', 'week']
# filtered_tokens ['yes', 'yes', 'still', 'trying', 'find', 'picture', 'upload', 'correclty.']
# filtered_tokens ['oh', 'red', 'sox', 'game', 'rained', 'out?', 'looking', 'forward', 'opening', 'day']
# filtered_tokens ['still', "can't", 'find', 'keys.']
# filtered_tokens ['know', 'right.', 'dunno', 'going', 'twitter.']
# filtered_tokens ['might', 'getting', 'sore', 'throat']
# filtered_tokens ['home', 'town.', 'mammy', 'called', 'depressd.', 'pls', 'explain', 'parent', 'let', '8yr', 'old', 'child', 'walk', 'alone?', 'hello?', '2009!']
# filtered_tokens ['think', 'need', 'find', 'better', 'anti-depressants.', 'think', 'paxil/wellbutrin', 'combo', 'losing', 'efficacy.']
# filtered_tokens ['restaurant', 'called', 'woodntap', 'competitive', 'eating', 'tourney', 'round', 'tourney', 'time.', 'place', '2nd']
# filtered_tokens ['bathroom.', 'wake', 'lakin.']
# filtered_tokens ['want', 'tacos', 'margarhitas', 'tell', 'gay', 'say', 'hello&lt;3']
# filtered_tokens ['im', 'lonely', 'keep', 'company!', '22', 'female,', 'california']
# filtered_tokens ['bad', 'day', 'betfair', 'office']
# filtered_tokens ['miss', 'him.', "can't", 'wait', 'celebrate', 'tar', 'heel', 'win', 'weekend', 'though!']
# filtered_tokens ["i'm", 'really', 'cold.', 'want', 'go', 'sleep', 'yet', "there's", 'nothing']
# filtered_tokens ['4', 'u?', 'officially', '4', 'go', 'round!']
# filtered_tokens ['monkeys???', 'found', 'twin', 'wont', 'even', 'write', 'back.', "i'm", 'heartbroken']
# filtered_tokens ['aww', 'know', 'felt', 'like', 'yesterday', 'work']
# filtered_tokens ['treaty', 'defined']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['poor', 'john', 'happens', 'play', 'fruit', 'microwave!', 'seriously', 'though', 'seen', 'doctor??', 'xxx']
# filtered_tokens ['missing', 'bff', 'watching', 'home', 'away', 'reminds', '&lt;3', 'it.', 'shout', 'u', 'courts']
# filtered_tokens []
# filtered_tokens ['new', 'video', 'card', 'doa.']
# filtered_tokens ['feeling', 'lost,', 'naked', 'confused', '(jk,', 'sort', 'of).no', 'iphone', 'me.']
# filtered_tokens ['damn', 'late', 'filling', 'appraisal', 'form,', 'people', 'almost', 'sent', 'occupied', 'work']
# filtered_tokens ['missed', 'brent', 'praise', 'band.', 'fun', 'lead', 'guitarist.', '&lt;pout&gt;']
# filtered_tokens ['think', 'much', 'past.', 'cant', 'change', 'it.', 'deserved', 'much', 'wat', 'got.', '.but', 'still', 'thinking', 'gah']
# filtered_tokens ['lost', 'ring.', 'no-where', 'seen']
# filtered_tokens ['oooh!', '*sealclap*', 'see,', 'download', 'shitloads', 'zip', 'folders', '4chan.', 'internet', 'moneys.', 'fuck', 'yeah', 'alicia', '&amp;', 'mikey.']
# filtered_tokens ['still', 'nursing', 'nile', 'glad', 'feeling', 'better.', 'hate', 'baby', 'sick']
# filtered_tokens ['fucked', 'go', 'back', 'ic']
# filtered_tokens ['yoyoyo.', 'internet', 'rude', 'tonight.', 'reconnected', "i'm", 'go', 'bed.']
# filtered_tokens ['well', 'uni', 'stuff', 'netball', 'netbal', "i've", 'done', 'uni', 'stuff']
# filtered_tokens ['poor']
# filtered_tokens ['help', 'forget', '8th', 'april', '&amp;', '13th', 'july!']
# filtered_tokens ['dierks', 'bentley', "comin'", 'columbus,', 'oh!', 'wanna', 'go', 'bad']
# filtered_tokens ['take', 'sidekick', 'back.']
# filtered_tokens ['congrats!', "i'm", 'totally', 'jealous!', 'wish', 'xm', 'working']
# filtered_tokens ['gr8t', 'face', 'itchy']
# filtered_tokens ['poor', 'socks', 'luvv', 'golden', 'retriever!', 'want', 'one', 'sighh']
# filtered_tokens ['saw', 'found', 'tracy', 'girl', 'piece', 'luggage.', 'fucking', 'terrible']
# filtered_tokens ['aaand', 'nausea', 'back.']
# filtered_tokens ['ooh', 'i�m', 'excited', 'even', 'going', '2', 'long', 'love', 'youtube!']
# filtered_tokens ['spent', '1', 'hour', 'reach', 'axis', 'bank', 'find', 'today', 'holiday', 'mahavir', 'jayanti', 'contd.']
# filtered_tokens ['agree.', 'jobros', 'dont', 'update', 'theres', 'often']
# filtered_tokens ['hilarious', 'linked', 'clip', 'lj', 'time', 'ago', 'went', 'back', 'dead', 'link']
# filtered_tokens ['oo', 'with?', '(im', 'neither', 'thats', 'need', 'study']
# filtered_tokens ['tweeted', 'nearly', 'day', 'posted', 'website', 'tonight,', 'hopefully', 'goes', 'well', 'night', 'time!']
# filtered_tokens ['miss', 'bentley']
# filtered_tokens ['seriously', 'needs', 'finish', 'job', 'applications']
# filtered_tokens ['son', 'vincas', 'sick,', 'stay', 'home', 'three', 'tense', 'days', 'work,', 'back', 'holiday', 'kids']
# filtered_tokens ['whinging.', 'client&amp;boss', 'understand', 'english', 'well.', 'rewrote', 'text', 'unreadable.', 'written', 'v.', 'good', 'writer&amp;reviewed', 'correctly.']
# filtered_tokens ['want', 'ever', 'punch', 'me.']
# filtered_tokens ['soo', 'sick', 'snow', 'ughh']
# filtered_tokens []
# filtered_tokens ['work', 'fan', 'upset']
# filtered_tokens ['would', 'like', 'apologize', 'repeated', 'video', 'games', 'live', 'related', 'tweets.', 'going', 'stern', 'discussion', 'koodo', 'soon.', 'stern.']
# filtered_tokens ['cant', 'figure', 'get', 'back', 'pay', 'hotel', 'etc']
# filtered_tokens ['fml:', 'much', 'seniority,', 'bc', 'technological', 'ineptness,', '&quot;register&quot;', 'classes']
# filtered_tokens ['feels', 'like', 'slept', 'day', 'away.', 'looking', 'forward', 'bouts', 'gallbladder.', 'least', 'pills', 'pain.']
# filtered_tokens ['really', 'want', 'old', 'bass', 'back']
# filtered_tokens ['mad', 'tired', 'today.', 'callin', 'early', 'tonight', 'nighty', 'night', 'twittas']
# filtered_tokens ['take', 'easy,', 'good', 'you.']
# filtered_tokens ["i'm", 'afraid', 'bad', 'code.']
# filtered_tokens ['think', "i'm", 'going', 'bed.', 'goodniight.', 'hate']
# filtered_tokens ["i'm", 'here,', 'friend,', 'love', 'you.']
# filtered_tokens ['time', 'notice', 'gone.just', 'needed', 'db2', 'it??']
# filtered_tokens ['bathroom', 'pee!']
# filtered_tokens ['wanted', 'margarita', 'too!']
# filtered_tokens ['yup', 'night', 'workouts', 'r', 'worst', 'unfortunetly', 'work', 'schedule', 'allows', 'go', 'night', 'tough!']
# filtered_tokens ['called', 'hillsong', 'said', 'tell', 'waiting', 'list', 'know', 'looking', 'good']
# filtered_tokens ['0g', 'milky', 'bar', 'left,', 'around', '200ml', 'coke']
# filtered_tokens ['still', 'arrived']
# filtered_tokens ['mraow,', 'feel', 'like', 'dancing,', 'first', 'art', 'school', 'wants', 'rape', 'more.']
# filtered_tokens ['ah!', 'bet', "i've", 'like', 'craving', 'play', 'softball', 'basketball', 'noo', 'time']
# filtered_tokens ['terrified', 'accidentally', 'deleted', 'reference', 'management', 'assignment', 'hopes', 'doesnt', 'get', 'trouble', 'gets', 'back']
# filtered_tokens ['amazon', 's3', 'plugin', 'worked', 'website', 'need', 'php', '5', 'hosting', 'provider', 'php', '4.4', 'sad.']
# filtered_tokens ['argh!', 'suuper', 'sleepy', 'hour', 'ago,', "i'm", 'wide', 'awake.', 'hope', 'stay', 'night.']
# filtered_tokens ['wish', 'was!', 'sold', 'time', 'let', 'know,', 'would', 'love', 'hear', 'to!']
# filtered_tokens ['watched', 'tropic', 'thunder.', 'dreading', 'tomorrow']
# filtered_tokens ["no.he's", 'still', "miss'n."]
# filtered_tokens ['chiefdelphi']
# filtered_tokens ['according', 'bro,', 'new', 'puppy', 'poo', 'fight', 'covered', 'poop', '(picture', 'stolen', 'him)']
# filtered_tokens ['playing', 'game', 'home!', 'new', 'boss', 'call', 'yet.']
# filtered_tokens ['su', 'yin', 'huen', 'tweeted', 'feel', 'unbearable', 'guilt.', 'made', 'staff', 'cry']
# filtered_tokens ['poor', 'joshy', 'sick???', 'damn', 'tejanos!']
# filtered_tokens ['thoughts', 'sandra', "cantu's", 'family', 'difficult', 'sad', 'time']
# filtered_tokens ['know,', 'wanted', 'let', 'everybody', 'know', 'happening']
# filtered_tokens ['michigan', 'who?', 'know', 'them.', '*sigh*', 'shameful!']
# filtered_tokens ['fill', 'two', 'hours']
# filtered_tokens ['cuute!', 'hey,', 'miss', 'na!', 'seeing', 'girls', 'everyday']
# filtered_tokens ['oh!', 'mention', 'it?', '&quot;good', 'moorniing&quot;', 'germany!', 'im', 'back', 'cage.or', 'better.my', 'office']
# filtered_tokens ['throat', 'closing', 'string', 'cheese.', 'good', 'idea']
# filtered_tokens ['aww,', 'sandra', 'cantu', 'found', 'dead', 'suitcase', 'missing', 'children', 'stories', 'never', 'seem', 'go', 'good.', 'poor', 'family.']
# filtered_tokens ['wishing', 'home', 'underneath', 'covers']
# filtered_tokens ['walking', 'home', 'school', 'drains', 'energy']
# filtered_tokens ['agree.', 'shapeshifting', 'copout.', 'excited', "angela's", 'ep,', 'thought', 'week.', 'noah', 'awesome', 'tho!']
# filtered_tokens ['dang!', 'would', 'done', 'knew', 'earlier.', 'outings', 'planned?']
# filtered_tokens ['wish', 'better', 'writing.', 'taking', 'long', 'write', 'paper.']
# filtered_tokens ['.and', 'course.', 'access', 'halo', '3', 'mythic', 'map', 'pack', 're-download.', 'bad', 'news.', 'legendary', 'map', 'pack.', 'ugh.', '600ms.']
# filtered_tokens ['.not', 'yet', 'unfortunately,', 'another', 'weeks', "i've", 'told', 'you?', "i've", 'little', 'bit', 'busy', 'latest', 'project.']
# filtered_tokens ['ha', "sun's", 'already', 'gone']
# filtered_tokens ['day', '2.', 'lot', 'harder', 'day', '1.', "let's", 'see', 'day', '3', 'goes', 'tomorrow.']
# filtered_tokens ['man', 'crush', 'jake', 'peavy', 'let', '#gayforpeavy']
# filtered_tokens ['megafast', 'trip,', 'time', 'day', 'tom/weds?', 'or,', 'going', 'tonight?', 'want', 'see', 'bad.', 'tried', 'warn', 'you,', 'tech', 'fail']
# filtered_tokens ['michigan', 'state', 'make', 'sad']
# filtered_tokens ['omg.', 'mouth', 'much', 'pain', 'wanna', 'sleep', 'untill', 'time', 'take', 'braces', 'off.']
# filtered_tokens ['getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biofuel', 'proposal:', 'getting', 'annoyed', 'easily', 'today', '&gt;&gt;&gt;', 'biof.']
# filtered_tokens ['hey', 'girl.', 'site', 'back.', 'girlyvue', 'back', 'even', 'videos.']
# filtered_tokens ["i'm", 'spending', 'time', 'grandma', 'early', 'tomorrow', "can't", 'leave', 'skittles', 'herself.']
# filtered_tokens ['got', 'home', 'watching', 'michigan', 'state', 'get', 'tromped!']
# filtered_tokens ['oh', 'jew-bus!', 'two', 'years', 'worth', "classes'", 'work', 'alot', 'organize', '&gt;_&lt;', "i'm", 'finishing', 'tonight,', 'possible.my', 'bones', 'ache']
# filtered_tokens ['exchanging', 'me,', 'laptop', 'arrived']
# filtered_tokens ['hope', 'last', 'long.', 'feel', 'miserable!']
# filtered_tokens ['rachel!', 'hang', 'outage', 'neccessary', 'gonna', 'home', 'wekend', 'dumb', 'folk', 'make', 'work', 'im', 'free', 'f', 'sat', '4.']
# filtered_tokens ['fun', '&amp;', 'furious?', 'new', 'mantra', 'bay', '2', 'breakers?', 'getting', '2', 'rambunctious;the', 'city', 'overreacted', '&amp;', 'clamped']
# filtered_tokens ['hubby', '(for', 'reason)', 'thinks', 'important', 'good', 'spot', 'red', 'carpet', 'trek', 'movie', 'premiere.', 'sod!']
# filtered_tokens ['swear', 'matter', 'long', "i've", 'getting', '5am,', 'never', 'gets', 'easier.', 'man', 'eyes', 'hurts', 'wah']
# filtered_tokens ['jeffree!', 'keep', 'hair', 'one', 'color?', 'permanent', 'dye', 'fades', 'within', 'week']
# filtered_tokens ['reaction', 'whoa,', 'see', 'coming']
# filtered_tokens ['still', 'sick.', 'feeling', 'bit', 'better,', 'got', 'new', 'medicine.', 'hope', 'feel', 'good', 'night', 'sleep.', 'ohh,', 'suppose', 'snow!', 'wtf!']
# filtered_tokens ['think', 'maybe', 'get', 'couple', 'hours', 'sleep,', 'hon.', 'productive', 'right', 'ur', 'dog', 'tired?', 'worry']
# filtered_tokens ['thanks', 'lot.', 'learned', 'lot', 'new', 'words', 'find', 'looking', 'for.']
# filtered_tokens ['wish', 'xblm', 'downloads', 'gamertag', "'hitokyri'.", '5', 'gamertag', 'thing', 'nonsense.', "i'm", 'tired']
# filtered_tokens ['new', 'testament', 'test', '9:30']
# filtered_tokens ['tons', 'hay', 'troll?', 'ahh']
# filtered_tokens ['stupid', 'movies', 'watched.', 'mirrors', 'uggh.', 'stoopeed!', 'rip', 'off!']
# filtered_tokens ['love', 'you,', 'buck.']
# filtered_tokens ['last', 'one!', 'still', 'done!']
# filtered_tokens ['homework.']
# filtered_tokens ['understand', 'things', 'get', 'taken', 'away.', 'enough', 'time', 'unfair.', 'want', 'back!', 'like', 'baby']
# filtered_tokens ['scratch', 'that:', 'du', 'heif', '(two', 'half)', 'cookies.', 'tum', "can't", 'take', 'anymore', 'shoog.', 'poots']
# filtered_tokens ['listening', 'sweets', 'first', 'time', 'forever!', 'miss', 'much', 'go', 'chi', 'town', 'visits', 'plz?']
# filtered_tokens ['geez', 'busy', 'afternoon.', 'meetings,', 'emails,', 'meetings', 'email', 'meetings.', '6pm', 'day', 'still', 'going!', 'ah', 'dark']
# filtered_tokens ['dang!', 'another', 'spring', 'break!', 'cool', 'that???', 'bad', 'work', 'week', 'oh', 'well,', 'money', 'phone.', 'ttyl', 'everbody!']
# filtered_tokens ['im', 'afraid', 'ur', 'reply', 'uni', 'ages', 'ago']
# filtered_tokens ['feeling']
# filtered_tokens ['lol', 'emotional', 'ass', 'men!', 'omg', 'late', 'night', 'eating.', 'us', 'broke']
# filtered_tokens ['aww', 'nick!', 'like', 'hair', 'longer,', 'cut', 'off?', 'break.', 'my.', 'heart.']
# filtered_tokens ['wonder', 'jon', 'lost', 'net']
# filtered_tokens ['wow.', 'depressing', 'thing', 'world', 'losing', 'video', 'created', 'matter', 'seconds.', '#fml']
# filtered_tokens ['says', 'stock']
# filtered_tokens ['lmao', 'im', 'sorry', 'poohpot', 'ate', 'all!']
# filtered_tokens ['chance', 'softbelly', '(for', 'loud?']
# filtered_tokens ['time', 'move', 'posterior', 'lose', 'fat.', 'articulation', 'creaking', 'running', 'i�m', 'drool', 'swimming']
# filtered_tokens ['listening', 'nathan', 'cry.']
# filtered_tokens ['today', 'sucked.', "i'm", 'gonna', 'die', 'without', 'chris', 'callum!', 'wahh!']
# filtered_tokens ['stou', 'site', 'update,', 'info', '2/2552', 'exam,', 'open', 'course,', 'must', 'wait', 'mail', 'notices', 'doc.', 'um.']
# filtered_tokens ['sorry.', "i'm", 'feeling', 'kinda', 'yucky', 'myself.', '5am', 'going', 'come', 'quick']
# filtered_tokens ['love', 'scrappy', 'missin', 'already']
# filtered_tokens ['wants', 'hear', "'s", 'song', 'myspace', 'messing']
# filtered_tokens ['bad', 'news', 'dad', 'cancer', 'dying', 'good', 'news', 'new', 'business', 'started', 'life', 'coach', 'practising', 'holistic', 'weight', 'management']
# filtered_tokens ['man.', 'intervention', 'soo', 'sad']
# filtered_tokens ['help!', 'need', 'new', 'boyfriend.', "i'm", 'stuck', 'rut']
# filtered_tokens ['feel', 'like', 'complete', 'idiot.', "i'm", 'one', 'get', 'shit', 'works', 'help']
# filtered_tokens ['saw', 'ad', 'craigslist', 'casting', 'call', 'female', 'host', 'g4.', 'totally', 'psyched!', 'realized', 'hoax']
# filtered_tokens ['pepperoni', 'rolls', 'l.a.?:', 'called', "valentino's", 'said', 'sausage', 'rolls', 'pepperoni', 'rolls']
# filtered_tokens ['yes,', 'be.', 'monday']
# filtered_tokens ['want', 'new', 'gg', 'episode', 'already']
# filtered_tokens ['miss', 'watching', "rocko's", 'modern', 'life.']
# filtered_tokens ['rip', 'sandra.its', 'sad', 'someone', 'something', 'like', 'that??']
# filtered_tokens ['keeping', 'fingers', 'crossed', 'buddy', 'feeling', 'well.']
# filtered_tokens ['wait', 'eat??', 'skinny', 'vegas!', "i'm", 'hungry!']
# filtered_tokens ['tried', 'tweetdeck', 'hated', 'passion.', 'hated', 'me,', "i'm", 'sure.']
# filtered_tokens ['btw', 'iphone', 'acting', 'funny,', 'dying', 'quickly', 'freezing', 'bs.', "i'm", 'admitting', 'anything,', 'sayin']
# filtered_tokens ['sitting', 'wondering', '&quot;ed&quot;', 'still', 'strong', 'hold']
# filtered_tokens ['im', 'sorry', 'got', 'sick.', 'lol.', 'going', 'bed', 'too.', 'night!']
# filtered_tokens ['internet', 'home,', 'drive', 'ox', 'use', 'internet', 'builders!']
# filtered_tokens ['weather', 'canada', 'freezing']
# filtered_tokens ['twiggass', 'range', 'day', "i'm", 'back', 'hopefully', 'good.']
# filtered_tokens []
# filtered_tokens ['anyone', 'reads', 'pray', 'grandma.', 'pain']
# filtered_tokens ['#3', 'woke', 'accident', "&quot;it's", 'pushing,', 'pushing&quot;', 'crying', 'stop', 'wetting', 'pants.']
# filtered_tokens ['home', 'franklin', 'street,', 'almost', 'jumped', 'fire.', 'someone', 'kicked', 'could.', 'jenny', 'lost', 'shoe.']
# filtered_tokens ['hey!', 'changed', 'default.']
# filtered_tokens ['finally', 'gave', 'bored', 'enough', 'start', 'thing.', 'think', '140', 'going', 'problem', 'tho.', 'like', 'myspace', 'status.']
# filtered_tokens ['oonly', 'really', 'lucky,', 'eh?', 'awh', 'definitely', 'early', 'work.']
# filtered_tokens ['buttload', 'homework!']
# filtered_tokens ['needs', 'another', 'copy', 'visual', 'studio', '2008']
# filtered_tokens ['we,', 'school', 'world,', 'week.my', 'school', 'silly', 'anyway.', 'look', 'bright', 'side.', "i'm", 'off,', 'u']
# filtered_tokens ['omg', "i've", 'economics', 'test.', 'dont', 'know', 'things', 'know', 'omg', 'im', 'gonna', 'fail']
# filtered_tokens ['upon', 'time', 'hundred', 'islands', 'pride', 'philippine', 'tourism,', 'coral/clam/rare', 'fish', 'poaching', 'in.', 'kinda', 'sad']
# filtered_tokens ['yeah,', 'apparently', 'really', 'bad', 'taste']
# filtered_tokens ['know!', 'really', 'surprised', 'since', 'everyone', 'recommends', 'youtube.', 'call', 'tomorrow', 'figure', 'out.']
# filtered_tokens ['waiting', 'airport', 'ride', 'get', 'harassed', '2', 'men', 'trying', 'sell', 'ugly', 'hats.', 'me?!', 'want', 'sleep.']
# filtered_tokens ['left', 'ids', 'location', 'go', 'bars', 'fuckk']
# filtered_tokens ["i'm", 'sorry', 'understand', 'last', 'comment']
# filtered_tokens ['announcement?', 'stayed', 'late', 'last', 'night']
# filtered_tokens ['strange,', 'illegal', 'torrents', 'avlbl', 'everywhere,', 'legal', 'dvd', 'stock', 'now???']
# filtered_tokens ['enough', 'say', 'imiss', 'u']
# filtered_tokens ['trolley', 'packed', 'like', 'sardines!', 'padre', 'game', 'remove', 'car?!', 'good', 'call', 'mts']
# filtered_tokens ['jeez,', 'trying', 'help', 'haha.']
# filtered_tokens ['happened', 'saturday', 'night.', 'along', 'glittery', 'green', 'lighter!']
# filtered_tokens ['trying', 'reduce', 'number', 'cigarettes', 'day!']
# filtered_tokens ['yea', 'quiet', 'around', 'cuz', 'everyone', 'work', 'im', 'bored', 'death', 'nobody', 'talk']
# filtered_tokens ['gotta', 'cooking', 'assignment', 'hard']
# filtered_tokens ['okay,', 'applepears,', "i've", 'talked', 'people', "they've", 'before.', 'one', 'ever', 'told', 'me,', 'never']
# filtered_tokens ['know!', "i'm", 'night', 'owl', 'nature,', 'hahaha', 'time', 'zone', 'behind', 'you?', 'almost', '1']
# filtered_tokens ['lol', 'nope!', 'complete', '#camerafail']
# filtered_tokens ['but!', "i'm", 'useless', 'sleep', 'fair!', 'want', 'fun', 'well!']
# filtered_tokens ['pookie', 'uti.', 'nurse', 'gabbie', 'get', 'back', '100!', 'sodas!']
# filtered_tokens ['tweet', 'something', 'damn', 'it!', 'hang', 'please?']
# filtered_tokens []
# filtered_tokens ["i'm", 'behind', 'video', 'games,', 'everything', 'matter.', "i'm", "yesterday's", 'news']
# filtered_tokens ['did,', 'one', 'left', 'got', 'tempted', 'ate', 'soon', 'got', 'home', 'chocolate', 'velvet', '&amp;', 'ate', 'mocha']
# filtered_tokens ['stressing', 'blackberry', 'keeps', 'flashing', 'red', 'alert', 'status', 'reason!', 'faking', 'hate', 'it!']
# filtered_tokens ['wanna', 'wear', 'doc', 'martens', 'out!', 'worn', 'since', 'december.']
# filtered_tokens ['shoe', 'repair', 'shop', 'guy', 'could', 'find', 'shoes!', 'go', 'back', 'see', 'find', 'couple', 'days.']
# filtered_tokens ['really', 'see', 'coming']
# filtered_tokens ['woke', 'vivid,', 'sketchy,', 'not-cool', 'dreams', 'life.', 'time', 'stare', 'wall', 'lights', 'on.']
# filtered_tokens ["it'll", 'take', '3', 'days', 'sister', 'get', 'passport']
# filtered_tokens ['oh', 'yes!', 'miss']
# filtered_tokens ['uh', 'oh.', 'think', 'getting', 'sick']
# filtered_tokens ['good', 'god', 'ruined', 'belly', 'button!']
# filtered_tokens ['watching', 'framed', 'roger', 'rabbit.', 'makes', 'miss', 'toon', 'town.']
# filtered_tokens ['renting.', 'cheap', 'renting,', 'awesome', 'house.', '3', 'buying', 'attempts', 'fall']
# filtered_tokens ['running', 'nose', 'spinning', 'head', 'good', 'combination', 'meeting!']
# filtered_tokens ['negative.', 'lost', 'vote', 'confidence']
# filtered_tokens ['nasty', 'budget', 'due', 'iphone', 'sent', 'apple', 'today.']
# filtered_tokens ['that�s', 'bad']
# filtered_tokens ['dammit,', 'episode', '3', 'kings', 'play', 'reason', 'stopped', 'middle', 'anything']
# filtered_tokens ["i'm", 'upset', 'missed', 'chat', 'quiz', 'online', 'free', 'internet', 'ceased']
# filtered_tokens ["can't", 'believe', 'it!', "i'm", 'disbelief', 'way', 'really.', 'much', 'take', 'people', 'always', 'get', 'hurt', 'others!']
# filtered_tokens ['car', 'show', 'season', 'started', 'without']
# filtered_tokens ['throat', 'raw.']
# filtered_tokens ['get', 'it.', 'persons', 'mind', 'could', 'even', 'ish', 'like', 'this???', 'prayers', 'fam', 'real']
# filtered_tokens ['hate', 'you.', 'need', 'see', 'that.', 'need', 'call', 'therapist', 'now.']
# filtered_tokens ['twilight', 'come', 'yesterday', 'fingers', 'crossed', 'today']
# filtered_tokens ['glad', 'able', 'help', 'feel', 'better.', 'hate', 'see', 'sick', 'love', 'you!']
# filtered_tokens ['tiredd.', 'want', 'sleep', 'assignment', 'finish', 'exam', 'tomorrow', 'study']
# filtered_tokens ['know,', 'thinking.', 'need', 'money']
# filtered_tokens ['omg.its', 'jst', 'teusday']
# filtered_tokens ['umm', 'cant', 'find', 'it.']
# filtered_tokens ['heard', 'found', 'sandra', 'cantu.', '8', 'yrs', 'old']
# filtered_tokens ['ive', 'forgotten', 'snoo-snoo', 'wonder', 'snoo-snoo', 'ever', 'meet', 'again.']
# filtered_tokens ['wow', 'last', 'tweet', 'made', 'seem', 'like', 'giant', 'sexist.sorry']
# filtered_tokens ['bathtub', 'drain', 'fired:', 'haz', '1', 'job', '2', 'do,', '&amp;', 'iz', 'fail.', 'got', 'drano', 'ass,', '&amp;', 'iz', 'still', 'draining.', 'wanna', 'shower,', 'dangit!']
# filtered_tokens ['stuck', 'home']
# filtered_tokens ['mine', '1/10', 'get', 'up?']
# filtered_tokens ['duckling', 'famous', "children's", 'book', 'stolen', "boston's", 'public', 'garden', 'boston', 'globe', 'via', 'oh', 'no!']
# filtered_tokens ['thank', 'you!', 'however,', 'hate', 'list', 'includes', '2', 'convicts.']
# filtered_tokens ['heading', 'altrincham,', 'again!', 'hours', 'install']
# filtered_tokens ['morning!', 'good', 'im', 'bloody', 'knackered!', 'work', 'today', 'helpp!', 'xx']
# filtered_tokens ['garage.', 'park', 'driveway!']
# filtered_tokens ['happened?']
# filtered_tokens ['&quot;on', 'popular', 'music&quot;', 't.w.adorno', 'probably', 'difficult', 'reading', 'ever', 'prescribed,', "i'm", 'actually', 'struggling', 'continue']
# filtered_tokens ['cant', 'see', 'flowers', 'falling', 'dont', 'camera,', 'cellphone']
# filtered_tokens ["we've", 'good.', "i'm", 'liking', 'snow', 'right', 'now,', 'getting', 'used', 'nice', 'spring-like', 'weather.', 'you?']
# filtered_tokens ['pity', 'youtube', 'currently', 'blocked', 'china.', "can't", 'see', 'vids.']
# filtered_tokens ['happened', 'show', 'hightlight', 'life']
# filtered_tokens ['best', 'leather', 'sofa', 'world!', 'office', 'though', 'means', "i'm", 'still', 'working']
# filtered_tokens ['still', '3', 'days', 'internet', 'gets', 'uncapped']
# filtered_tokens ['get', 'better', 'days,', 'could', 'something', 'lodged', 'belly']
# filtered_tokens ['love', 'atekinzz', 'much.', '&amp;&amp;', 'soo', 'miss', 'her.']
# filtered_tokens ['wanna', 'sneak', 'zoo', 'play', 'kitties']
# filtered_tokens ['oh', 'hope', 'getting', 'sick', 'too!']
# filtered_tokens ['dont', 'think', 'cause', 'cousins', 'birthday', 'party']
# filtered_tokens ['sweet', 'little', 'man', 'fell', 'asleep', 'waiting', 'daddy', 'big', 'brother', 'get', 'home!', 'poor', 'baby,', 'missed', 'much', 'today!']
# filtered_tokens ['angel', 'going', 'miss', 'athlete', 'weekend']
# filtered_tokens ['trust', 'hard']
# filtered_tokens ['watched', 'considering', 'today.', 'yaknow.', 'shawnna', 'tomomorrow;i', 'need', 'bestfriend']
# filtered_tokens ['grr', 'want', 'keep', 'reading', 'wont', 'anything', 'left', 'read']
# filtered_tokens ['atekinzz,', 'world', 'you??']
# filtered_tokens ['no!', 'u', 'supposed', 'date']
# filtered_tokens ['pears', '&amp;', 'brie,', 'bottle', 'cabernet,', '&quot;win', 'date', 'tad', 'hamilton&quot;.', 'oh', 'gawwd', 'life', 'flashed', 'forward', "i'm", '40', '75', 'cats']
# filtered_tokens ['crap.', 'need', 'dresses', 'too.']
# filtered_tokens ['yeah!', 'know!', 'horrible!', 'ugh.', 'saddening.']
# filtered_tokens ['geez', 'ur', 'fun']
# filtered_tokens ['wanna', 'punk', 'rock', 'band']
# filtered_tokens ["that's", 'lot', 'angst', 'tuesday', 'afternoon']
# filtered_tokens ["i'm", 'glad', 'britney', 'crazy', 'anymore!', 'one', 'hell', 'show!', "i'm", 'sad', 'over.', 'next', 'up.ap', 'cook', 'county!']
# filtered_tokens ['huuge', 'headache!', 'omg', 'feel', 'like', 'crap!']
# filtered_tokens ['sorry']
# filtered_tokens ['sorry.i', 'rooting', 'too.']
# filtered_tokens ['man,', 'took', 'forever.']
# filtered_tokens ['see.']
# filtered_tokens ['listing', 'items', 'ebay', 'sell!', 'takes', 'forever.meanwhile', 'coleman', 'watching', 'hills', 'season', 'premier', 'without', 'me.']
# filtered_tokens ['got', 'presentation', 'done,', '23', 'slides', 'done.', "i'm", 'crying', 'week', 'hardest', 'weeks.']
# filtered_tokens ['lost', '$160']
# filtered_tokens ['like', 'previously', 'skins', 'thing', 'starts', 'season', 'two.', 'like', 'went', 'straight', 'intro', 'like']
# filtered_tokens ['.i', 'wish', "there.i'm", 'pretty', 'good', 'scaring', 'shit', 'people']
# filtered_tokens ['going', 'sound', 'vain.', 'running', 'fav', 'lip', 'gloss']
# filtered_tokens ['never', 'click', 'link', 'screams,', "&quot;i'm", 'spider,', "i'm", 'spider&quot;.', 'known', 'better.', 'yucky']
# filtered_tokens ['time', 'work', 'get', 'sick?']
# filtered_tokens ['imac', 'came', '$320', 'indonesia', 'states.']
# filtered_tokens ['dammit.', 'need', 'stop', 'buying', 'furniture']
# filtered_tokens ['half', 'asleep', 'turned', 'laptop']
# filtered_tokens ['death', 'peaceful,', 'life', 'however,', 'bites']
# filtered_tokens ['think', 'lost', 'net', 'sure', 'hope']
# filtered_tokens ['test', 'footage', 'girlfriend', '(in', 'hd)', 'dark', 'one', 'underxposed']
# filtered_tokens ['tough', 'game', 'watch', 'tonight', 'state', 'finally', 'going', 'bed', 'also', 'staying', 'watch', 'season', 'premiere', 'hills!']
# filtered_tokens ['seems', 'jruby', 'support', 'hpricot', 'two', 'versions', 'behind']
# filtered_tokens ['unlike', 'sister.i', 'still', 'one']
# filtered_tokens ['fraking', 'app', 'store', 'pissing']
# filtered_tokens ['logging', 'out.', 'need', 'study.']
# filtered_tokens ['anyone', 'else', 'problems', 'accessing', 'ttb???', 'cant', 'get', 'on!']
# filtered_tokens ['strongly', 'dislike', 'people', 'make', 'stupid', 'comments', 'dont', 'know', 'whole', 'story']
# filtered_tokens ["i'm", 'sorry', 'emma,', 'swarley', 'goldfish?', "i'm", 'sad', 'u.']
# filtered_tokens ['tweets', 'already', 'gone,', 'missed', 'guys', 'tonight.']
# filtered_tokens ["can't", 'sleep', 'again.', 'face', 'kinda', 'swollen.', 'let', 'allergic', 'thing', 'get', 'thursday.', 'school', 'tomorrow?', 'doubtful.']
# filtered_tokens ["izzy's", 'cat', 'tree,', "she'll", 'stare', 'down,', 'floor,', 'chases', 'runs.']
# filtered_tokens ['officially', 'banning', 'godaddy.com', 'comp.', 'head', 'hurts', 'small', 'print', 'wasted', '$10', "could've", 'happily', 'gone', 'boba']
# filtered_tokens ['pretty', 'much', 'scary']
# filtered_tokens ['mines', 'too.', "i'm", 'finding', 'well', 'hard', 'get', 'fit.']
# filtered_tokens ['good', 'morning!', 'ready', '2', 'go,', 'want', '2', 'go', 'back', '2', 'bed']
# filtered_tokens ['hates', 'waiting', 'mails']
# filtered_tokens ['wheat', 'bread', 'dollar', 'store', 'toast', 'nicely', 'going', 'taxes', 'calling', 'early', 'night']
# filtered_tokens ['kutner?', 'mean', 'knew', 'something', 'going', 'happen', 'someone', 'sad.', '&lt;3', 'house', 'well', 'done,', "i'm", 'still', 'sad']
# filtered_tokens ['aw', 'ok', 'goonite.']
# filtered_tokens ['ill', 'cant', 'go', 'cinema!']
# filtered_tokens ['fell', 'asleep', 'really', 'mean', '*christina*']
# filtered_tokens ['hey,', 'remember', 'time', 'used', 'friends??', 'ugh.', 'vomit.', 'sick.', 'need', 'sleep']
# filtered_tokens ['lymph', 'nodes', 'massive', 'rahm', "emanuel's", 'balls', 'right']
# filtered_tokens ['oh', 'computer', 'sucks.', 'think', "i'll", 'able', 'listen', 'xbox', '360', 'fancast', 'tonite']
# filtered_tokens ['missing', 'playing', 'trumpet']
# filtered_tokens ['throat', 'still', 'really', 'sore.', 'meant', 'going', '5', 'day', 'camp', 'friday', 'sure']
# filtered_tokens ['know', 'exactly', 'feel!']
# filtered_tokens ['work']
# ...
# filtered_tokens ['what?', 'apparently', '52', 'degress', '11pm', 'washington', 'state.', 'miss', 'winter', 'already']
# filtered_tokens ['bored', 'homee']
# filtered_tokens ['massage', 'great.', 'spilled', 'coke', 'desk', 'lame.', 'watching', 'simpsons', "i've", 'finished', 'hills', 'dvds.']
# filtered_tokens ['wait', 'fanclub', 'chat.', 'even', 'tough', 'favorite']
# filtered_tokens ['mild', 'left', 'inner', 'ear', 'infection.', 'got', 'irritating', '&quot;blocked&quot;', 'feeling', 'since', 'sunday.']
# filtered_tokens ['hey', 'there!', 'nope.', 'cuteness', 'away', 'awhile']
# filtered_tokens ['tuesday']
# filtered_tokens ['haha', 'even', 'yo.', 'know', 'twitter', 'haha']
# filtered_tokens ['someones', 'alarm', 'clock', 'phone', 'woke', '3am.still', 'got', 'headache', 'yesterday', 'night']
# filtered_tokens ['aww', 'poor', 'puppy', 'ok?']
# filtered_tokens ['might', 'break', 'eat', 'buffalo', 'wings', 'tomorrow']
# filtered_tokens ['sittin', 'w/kayla,', 'really', 'really', 'really', 'dis-like', 'brother.', 'know', 'stop.', "i'm", 'waiting', 'day', 'one']
# filtered_tokens ['fed', 'bokkie', 'many', 'birthday', 'treats-sicko']
# filtered_tokens ["'s", 'kinda', 'bummed.', 'agency', 'told', "'look'", 'going', 'for.', 'ladies,', 'please', 'help', 'create', "'look'"]
# filtered_tokens ['work', 'laptop', 'officially', 'dead', 'happy', 'all.']
# filtered_tokens ['goodness,', 'freezing']
# filtered_tokens ['put', 'him!', 'listen', 'mom']
# filtered_tokens ['stucked', 'paris', "can't", 'even', 'travel', 'france', '(for', 'work)']
# filtered_tokens ['think', "there's", 'one', 'close', 'by.', 'last', 'time', 'checked,', 'closest', 'one', '70', 'miles', 'away!']
# filtered_tokens ['aand', 'back', 'literature', 'review', 'least', 'friendly', 'cup', 'coffee', 'keep', 'company.']
# filtered_tokens ['worried', 'get', '$900', 'even', 'though', 'paid', 'buttload', 'tax', 'last', 'year']
# filtered_tokens ['okay,', 'so.', 'still', 'school!']
# filtered_tokens ['phoneless', '.now', 'sleep']
# filtered_tokens ['reeked', 'alcohol', 'dentist', 'morning', 'drunk', 'put', 'tshirt,', 'realised', 'huge', 'stain.', 'dentist', 'looked', 'disgusted']
# filtered_tokens ['really', 'cold']
# filtered_tokens ['cant', 'sleep', 'wants', 'dream!']
# filtered_tokens ["can't", 'sleep', 'hate', 'nights', 'try', 'go', 'bed', 'early', 'stay', 'awake', 'hours.', 'poo!']
# filtered_tokens ['yeah.', 'bad', 'people', 'like', 'certain', 'burrito-eating', 'man', 'exist.']
# filtered_tokens ["that's", 'sad.']
# filtered_tokens ['found', 'mum', 'adopted', 'auntie', 'twitter.', 'check', 'mum', 'tessm64', 'awesome', 'auntie', 'tania38']
# filtered_tokens ['cannot', 'sleep.wide', 'awake.and', 'gotta', 'go', 'work', 'later', 'too.', 'boy,', 'going', 'crappy', 'day.']
# filtered_tokens ['struggling', 'eam', 'law']
# filtered_tokens ["can't", 'sleep', 'like']
# filtered_tokens ['bouts', 'start', '24.', 'poor', 'linny', 'keep', 'eyes', 'open.', 'tired', 'work', 'tomorrow', 'morning.', 'night']
# filtered_tokens ['4', 'year', 'old', '(18', 'year', 'old)', 'driving', 'around', 'twist.i', 'want', 'like']
# filtered_tokens ['well,', 'sucked.']
# filtered_tokens ['place', '3', 'days.any', 'help', 'get', 'packing/painting/cleaning', 'much', 'appreciated.', 'oh.', 'rip', 'wall']
# filtered_tokens ['opening', 'partially', 'frozen', 'beer=', 'beer', 'toaster,', 'oven', 'counter.', 'kitchen', 'smells', 'like', 'run', 'speakeasy']
# filtered_tokens ['dont', 'even', 'know', 'ride']
# filtered_tokens ['sadly,', 'yes.', 'think', 'need', 'counciling']
# filtered_tokens ['making', 'ready', "school.don't", 'feel', 'like', 'going,', 'two', 'tests']
# filtered_tokens ['smugness', 'gone.', 'train', 'also', 'failed', 'turn', "i'm", 'heading', 'victoria', 'followed', 'unpleasant', 'tube', 'ride', 'city.']
# filtered_tokens ['anybody', 'know', 'ipod', 'went?']
# filtered_tokens ['aww', 'earthquake', 'italy', 'made', 'sad', 'saw', 'pics', 'news,', 'terrible.']
# filtered_tokens ['never', 'able', 'afford', 'get', 'out.', "i'd", 'much', 'rather', 'go', 'extraction', 'continue', 'deal', 'now.']
# filtered_tokens ['pet', 'care', 'people', 'try', 'run', 'others', 'business?', 'send', 'suspicious', 'e-mails', 'fishing', 'info?']
# filtered_tokens ['&lt;33', "codez.they've", 'mia', 'tho']
# filtered_tokens ['doesnt', 'work', 'cell', 'go', 'sleep!', '=p']
# filtered_tokens ['going', 'nice', 'tomorrow', 'rain', 'comes', 'back.', 'nice', 'weather', 'birthday']
# filtered_tokens ['rock', 'band', 'hard.on', 'expert!']
# filtered_tokens ['roomie', 'home', 'day.', 'scratch', 'door.', 'comforter', 'goto', 'large', 'laundromat', 'machines.']
# filtered_tokens ['one', 'hardest', 'thing', 'schedule,', 'one', 'chat', 'end', 'day', 'usually']
# filtered_tokens ['killed', 'character', 'one', 'favorite', 'shows', "i'm", 'upset']
# filtered_tokens ['jealous', 'friends', 'got', 'see', 'new', 'star', 'trek', 'film', 'austin', 'tonight.']
# filtered_tokens ['listening', 'q!', 'got', 'really', 'bad', 'headache', 'drivin', 'lesson', 'ten', 'mins.', 'lucky', 'wana', 'sleep!']
# filtered_tokens ['shut', 'you.i', 'hungry!', 'britain,', 'home', 'boring', 'suckassy', 'breakfast', 'world!', 'miss', 'dennys!']
# filtered_tokens ['good', 'morning', 'everybody!', 'pkoi', 'fais', 'pas', 'beau', 'bon', 'coffee', 'time!']
# filtered_tokens ['work']
# filtered_tokens ['essay', 'time.']
# filtered_tokens ['hey', 'u', 'talk', 'mom.', 'r', 'home', 'yet?', 'hope', 'r', 'ok.', 'wish', 'coming', 'home', '4', 'easter.']
# filtered_tokens ['sure', 'wish', 'could', 'go', 'guys', 'tmrw.', 'per', 'usual,', 'school', 'interferes.']
# filtered_tokens ['say', 'what???', 'kal', "penn's", 'leaving', 'house?!', 'noo!', 'aww.', 'totally', 'missed', 'tonight']
# filtered_tokens ['no!', 'lost', 'loyal']
# filtered_tokens ['played', 'another', 'hand', 'bad', 'lost', 'half', 'stack']
# filtered_tokens ['6.20pm', 'early', 'days', 'loong', 'night', 'work']
# filtered_tokens ['sad', 'last', 'season.', 'wanna', 'see', 'spencer', 'calls', 'lauren!']
# filtered_tokens ['im', 'done', 'editing', '&quot;the', 'phipstape&quot;.', 'back', '2', 'crack', 'brew', 'see', 'got.', 'trees', 'though']
# filtered_tokens ['know', 'half', 'means']
# filtered_tokens ['homework', 'homework', 'homework']
# filtered_tokens ['worked', 'heart', 'today,', 'doubling', 'weight', 'station.', 'result:', 'stiff', 'pulled', 'muscles.', 'ouch!']
# filtered_tokens ['feel', 'bad', 'unfollowing.']
# filtered_tokens ['so.', 'tired.', 'god', 'hate', 'new', 'job,', 'two', 'days']
# filtered_tokens ['sad', 'kutner', 'killed', 'fav', 'show', 'house!']
# filtered_tokens ['happy', 'coach', 'stringer', '(hof', 'c/o', '2009!).now', 'finish', 'term', 'paper']
# filtered_tokens ['feel', 'like', 'shit.', 'way', 'want', 'spend', "birthday's", 'eve']
# filtered_tokens ['far', '311', 'sites', 'put', 'together,', 'checking', 'updates', 'made.']
# filtered_tokens ['lot', 'mind.', 'needs', 'make', 'moneys.', 'ideas.', 'nowhere', 'hiring!']
# filtered_tokens ['miss']
# filtered_tokens ["i'm", 'sorry', 'hear', 'dog']
# filtered_tokens ['much', 'internet.', 'plagues']
# filtered_tokens ['miss', 'ex', 'soo', 'much']
# filtered_tokens ['sodding', 'm25']
# filtered_tokens ['oh', 'thought', 'pirate', 'bay', 'trial', 'verdict', 'today', ':-s', 'apparently', '10', 'days']
# filtered_tokens ['call', 'back.']
# filtered_tokens ['study', 'hall', 'now,', 'log', 'immediately.']
# filtered_tokens ['tired', 'im', 'crying', 'reason', 'all.', 'im', 'try', 'get', 'hour', 'half', 'tonight.', 'half', 'got', 'last', 'night.']
# filtered_tokens ['totally', 'like.', 'four', 'girl', 'options,', 'none', 'seem', 'viable']
# filtered_tokens ['far', '311', 'veiws', 'sites', 'put', 'together,', 'checking', 'updates', 'made.']
# filtered_tokens ['listening', "bjork's", 'full', 'love.', 'crying']
# filtered_tokens ['omg', 'hills!', 'love', 'money2,', 'aww', 'think', 'becky', 'buckwild', 'goes']
# filtered_tokens ['craving', 'tantan', 'nabe']
# filtered_tokens ["c'mon", 'sean', 'man']
# filtered_tokens ['watching', '&quot;a', 'league', 'own&quot;.makes', 'miss', 'mint', 'chocolate', 'ice', 'cream', 'cones', 'grand', 'fuck.']
# filtered_tokens ['lost', 'phone', 'where.maybe', 'grass,', 'long,', 'hope', 'rain']
# filtered_tokens ['hope', 'referring', 'say', 'hello', 'new', 'stalker', 'lol']
# filtered_tokens ['u', 'sleeping?!', 'ur', 'gonna', 'night', 'ur', 'bike', 'ride?']
# filtered_tokens ['but,', 'but,', 'wanna', 'listen', 'masters', 'too!']
# filtered_tokens ["i've", 'looking', 'good', 'stuff', 'write,', 'also', 'loads', 'uni', 'work']
# filtered_tokens ['feel', 'unloved.', 'dropped', '2', 'tweeters']
# filtered_tokens ['london', 'day', 'thursday,', 'gonna', 'raining,', 'oh', 'fab', 'see', 'much', 'london', 'eye!', 'still', 'robbie', 'care', 'bless']
# filtered_tokens ['completely', 'wiped', 'reloaded', '8900.', 'lost', 'bbm', 'contacts', 'going', 'bed', 'sad.']
# filtered_tokens ['sayy', 'whaa?', 'invited.']
# filtered_tokens ['sleep', 'bad', 'considering', 'workshop', 'starting', 'today.', 'beginnings', 'sore', 'throat', 'though']
# filtered_tokens ['oh', 'gosh', 'made', 'emotional', 'haha', 'idk', 'why!', 'dont', 'want', 'get', 'old']
# filtered_tokens ["we're", 'going', 'post', 'stories', 'manually', 'due', 'twitterfeed', 'problem.', "that's", "we've", 'quiet', 'lately']
# filtered_tokens ['like', 'lukewarm', 'showers']
# filtered_tokens ['contact', 'need', '1099', 'freelance', 'work', 'linux.com', 'throughout', '2008?', 'never', 'got', 'one.']
# filtered_tokens ['connor,', 'me,', 'febi', 'really', 'really', 'mad', 'me??']
# filtered_tokens ['need', 'help?!', 'want', 'buy', 'macbook', 'pro,', 'still', 'inlove', 'old', 'powerbook!']
# filtered_tokens ['man', 'america', 'borez', 'anyway', 'lol', 'realized', 'sent', 'msgs', 'here.', 'idea.', 'flash']
# filtered_tokens ["g'knight", 'lovely', 'ladies.', "i'm", 'sleepy']
# filtered_tokens ['anybody', 'know', 'get', 'electrolytes', 'back', 'order?', 'vitamin', 'work?', 'feel', 'sick.']
# filtered_tokens ['yes,', 'someone', 'reading', 'posts', 'properly']
# filtered_tokens ['almost', 'italian', 'homework!', 'wee.', 'understood', 'doing.']
# filtered_tokens ['turned', 'lights', 'on?', 'time', 'get', 'ip']
# filtered_tokens ['twitter', 'hates', 'us', 'then.']
# filtered_tokens ['hate', 'fact', "i'm", 'genuinely', 'excited', 'last', 'tweet']
# filtered_tokens ["can't", 'sleep', 'either']
# filtered_tokens ['italy', 'earthquake,', 'sad', 'news', 'day.']
# filtered_tokens ['rain', 'today', 'garden', 'really', 'needs', 'quite', 'bad.']
# filtered_tokens ['yawn', 'yawn', 'yawn!', '10', 'minutes', 'bed']
# filtered_tokens ['ouch', 'sounds', 'sucky']
# filtered_tokens ['great', 'idea', 'itunes', 'promo', 'codes', 'work', 'uk', 'itunes', 'store', 'though']
# filtered_tokens ['*cry*']
# filtered_tokens ['empty', 'rum', 'barrel', 'sad', 'rum', 'barrel.', '*shakes', 'head*', 'horror,', 'horror.']
# filtered_tokens ['sleepless', 'night']
# filtered_tokens ['admitted', 'fake']
# filtered_tokens ['love', 'chutney.']
# filtered_tokens ['got', 'highly', 'bored', 'today', 'scanning', '24', 'pages', 'daddy.', 'it!']
# filtered_tokens ['cooked', 'risotto', 'without', 'me!???']
# filtered_tokens ['keerrii!', 'really', 'nothing', 'better', 'post', 'thing', '224am.wonderfull.', 'says', 'alot.']
# filtered_tokens ['yay', 'baseball', 'season!', 'boo', 'yankees', 'losing', 'first', 'game']
# filtered_tokens ['lost', 'sucks', 'work', 'today']
# filtered_tokens ['omg', 'exams', 'killed', 'could', 'know', 'difference', 'haif', 'circle', 'hemisphere', '&lt;/3', '&gt;']
# filtered_tokens ['bed.', 'suddenly', 'feel', 'wish', 'w/me.', 'goodnight', 'twitterfam']
# filtered_tokens ['like', 'goodnights']
# filtered_tokens ['greaat', 'lappy', 'turn', 'wtff']
# filtered_tokens ['stuck', 'traffic', 'then?', 'journey', 'traffic', 'free', 'morning,', 'help.']
# filtered_tokens ['lookin', 'like', 'all-nighter.', 'hate']
# filtered_tokens ['stranger']
# filtered_tokens ['debbugging', 'old', 'vb6', 'code,', 'day', 'could', 'started', 'better']
# filtered_tokens ['quarter', 'percent', 'babe', 'darn']
# filtered_tokens ['coming', 'cold', 'bad', 'allergies.', 'either', 'way,', "i'm", 'miserable!']
# filtered_tokens ["can't", 'believe', 'cutner', 'dead', 'house!', 'sad', 'day.', 'santa', 'rosa,', 'ca']
# filtered_tokens ['damnit', 'really', 'digging', 'season', 'reaper']
# filtered_tokens ['gah,', 'comcast', 'doubled', 'cable/internet', 'bill', 'w/out', 'telling', 'us,', 'quitting.', 'anyone', 'suggest', 'affordable', 'company', 'bay', 'area?']
# filtered_tokens ['another', 'early', 'morn', 'duchess,', 'although', 'managed', 'cross', 'legs', 'time']
# filtered_tokens ['left', 'without', 'saying', 'hi!']
# filtered_tokens ['l', 'want,', "can't", 'sleep']
# filtered_tokens ['xbox', 'shows', 'three', 'red', 'lights,', 'means', 'dead', 'needs', 'fixed', 'month', 'microsoft', 'hq.']
# filtered_tokens ['king', 'sized', 'bed', 'nice', 'sad', 'lonely', 'hubby,', 'puppy,', 'kitty', 'whole', 'conferenceing', 'thing.']
# filtered_tokens ['im', 'boredd.', 'gah', 'wish', 'could', 'sleep', 'get', 'ive', 'muchh', 'cooffee', 'bahaha']
# filtered_tokens ['may', 'butt', 'again.', "i'm", 'done', 'nosey.', 'sorry', 'conversation', 'interesting!']
# filtered_tokens ['fell', 'list.did', 'offend', 'you?']
# filtered_tokens ['18', 'weeks', 'till', 'sisters', 'home.', 'missed', 'call,', 'again!', 'worst', 'feeling', 'world.']
# filtered_tokens ['gonna', 'try', 'get', 'sleep', 'hotel', 'room']
# filtered_tokens ['brilliant', 'idea.', 'bring', 'much', 'think', 'spend', '&amp;', "i'll", 'swap', 'you.', 'bring', 'brolly']
# filtered_tokens ['get', 'autograph', 'shout', 'out!', 'record', 'though.', 'computer', 'dead', "can't", 'listen.']
# filtered_tokens ['rt', 'khloe', 'got', 'fired', 'apprentice']
# filtered_tokens ['biology', 'class.', 'lip', 'hurts']
# filtered_tokens ['sorry', 'next', 'tweet.']
# filtered_tokens ['grr', 'go', 'school', 'today']
# filtered_tokens ['get', 'hd', 'tivo', 'got', 'set', 'tonight', 'order', 'get', 'channels', '40', '59.']
# filtered_tokens ['asked', 'everyone', 'yesterday', 'single', 'tweet', 'back']
# filtered_tokens ['ruddy', 'money!', 'like', 'it!', 'still', 'waiting', 'here.', 'oh', 'surprise.', 'state', 'too??', 'hmm.', 'seriously!']
# filtered_tokens ['sad', 'kutner', 'favorite', 'new', 'team!']
# filtered_tokens ['wow', 'get', '&quot;hello&quot;', 'u', 'suck']
# filtered_tokens ['bedtime,', 'school', 'tomorrow,', 'still', 'books', 'broke', 'suckss']
# filtered_tokens ['seating', 'helping', 'baby', 'papers.well', 'forcing', 'seat', 'im', 'sleepy']
# filtered_tokens ['synching', 'contacts', 'old', 'mobile', 'iphone.', 'import', 'work', 'well']
# filtered_tokens ["can't", 'concentrate']
# filtered_tokens ["i've", 'spent', '1', 'hour', 'enter', 'bureaucratic', 'nonsense', 'march.', 'waste', 'time']
# filtered_tokens ['nw', 'confused', 'ever!']
# filtered_tokens ['feeling', 'well', 'again.', 'stupid', 'migraine', 'making', 'tummy', 'upset.', 'whole', 'body', 'aches,', 'shoot', 'now.']
# filtered_tokens ['reading', 'buyology', 'bedtime.', 'great', 'premise', 'turning', '&quot;ok&quot;', 'book', 'lots', 'info', 'already', 'knew']
# filtered_tokens ['home!', 'really', 'wana', 'sleep,', 'due', 'wasting', 'free', 'line', 'town', 'assignment', 'finish']
# filtered_tokens ['also', 'send', 'updates', 'plurk', 'upload', 'photos', 'twitter!', 'didnt', 'see', 'updates', 'plurk?', 'zero?']
# filtered_tokens ['omg.', '&quot;the', 'reader&quot;', 'making']
# filtered_tokens ["d'oh!", 'least', 'getting', 'decent', 'exchange', 'rate', 'moment,', 'sterling', 'still', 'getting', 'flogged']
# filtered_tokens ['tried', 'download', 'tweetdeck', 'wont', 'download']
# filtered_tokens ["there's", 'inch', 'snow', 'ground', '(and', 'counting).', "i'm", 'worried', 'poor', 'flowers']
# filtered_tokens ['happy', 'camper?']
# filtered_tokens ['thanks', 'man.', "i'm", 'grateful.', 'feel', 'unworthy', 'attention,', 'though,', "i'm", 'myself.']
# filtered_tokens ['miss', 'u', 'too.', "i'm", 'totally', 'comin', 'back', 'tho!', 'lastnight', 'soo', 'much', 'fun!']
# filtered_tokens ['ohh.', 'love', 'it.', 'ps', "i'm", 'sad', 'get', 'hang']
# filtered_tokens ['somehow', 'still', 'end', 'place']
# filtered_tokens ['oh', 'sad,', 'poor', 'boy.']

# %% [markdown]
# ### 2.2 Baseline performance
# (writeup not needed)

# %% [markdown]
# ### 2.3 Classification approach
# (writeup not needed)

# %% [markdown]
# ### 2.4 Coding style
# (writeup not needed)

# %% [markdown]
# ## III. Conclusions

# %% [markdown]
# ### 3.1 Evaluation

# %% [markdown]
# ### 3.2 Summary and conclusions

# %% [markdown]
# ## Temporary reference list
# * to use citation generator
#
# - Cynthia Van Hee, Jacobs, G., Emmery, C., Desmet, B., Lefever, E., Verhoeven, B., Guy De Pauw, Daelemans, W. and Hoste, V. (2018). Automatic detection of cyberbullying in social media text. PLOS ONE, [online] 13(10), p.e0203794. doi:https://doi.org/10.1371/journal.pone.0203794.
# - Khairy, M., Mahmoud, T.M. and Abd-El-Hafeez, T. (2021). Automatic Detection of Cyberbullying and Abusive Language in Arabic Content on Social Networks: A Survey. Procedia Computer Science, [online] 189, pp.156–166. doi:https://doi.org/10.1016/j.procs.2021.05.080.
